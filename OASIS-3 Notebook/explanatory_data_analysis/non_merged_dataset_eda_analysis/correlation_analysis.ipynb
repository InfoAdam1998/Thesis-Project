# %% [markdown]
# ## Correlation Analysis
#
# Lets check the correlation between variables
#
# Correlation measures the strength and direction of the linear relationship between two variables, but it is normalized to be independent of the units of the variables.

# %%
# Import basic libraries for EDA
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pingouin as pg
from dotenv import load_dotenv
import os

# %%
# Import dataset
load_dotenv()
dataset_path=os.getenv("DATASET_PATH_TWO_P")
dataset = pd.read_csv(dataset_path)
dataset.head()
# Out:
#    Gender        Age  DIAGNOSIS  MMSE   Hip ASM  Hip Contrast  \
# 0       0  65.149895          0  30.0  0.460200     83.371297
# 1       1  67.206024          0  30.0  0.329647    149.712265
# 2       0  58.773440          0  30.0  0.385797    104.769354
# 3       0  55.096508          0  30.0  0.229011    166.953431
# 4       0  48.030117          0  29.0  0.242913     86.816221
#
#    Hip Correlation  Hip Variance   Hip Sum Average  Hip Sum Variance  ...  \
# 0         0.508610      89.066304        10.318461        272.893918  ...
# 1         0.328176     109.824210        13.761403        289.584573  ...
# 2         0.545986     125.678783        15.521177        397.945779  ...
# 3         0.275601     112.186834        18.126786        281.793906  ...
# 4         0.377439      73.484651        13.463920        207.122381  ...
#
#    ERC CONTRAST  ERC CORRELATION  ERC VARIANCE   ERC SUM AVERAGE  \
# 0    245.139997         0.385395     209.332939        41.129640
# 1    221.932844         0.406722     197.689209        42.149774
# 2    283.711655         0.336695     217.002950        41.289080
# 3    231.188679         0.498026     232.827358        33.062621
# 4    245.120671         0.458936     233.016858        44.574015
#
#    ERC SUM VARIANCE  ERC ENTROPY  ERC CLUSTER SHADE  ERCs_thicknessbaseline  \
# 0        592.191757     3.234648       18110.527190                   6.948
# 1        568.823992     3.240436       23801.869010                   7.090
# 2        584.300146     3.069283       17579.374770                   6.832
# 3        700.120751     3.093719        4888.606116                   6.523
# 4        686.946759     3.149858       22134.931110                   8.253
#
#    ERCsVolumebaseline  TOTAL_HIPPOCAMPUS_VOLUME
# 0                2826                    6861.9
# 1                3792                    7378.1
# 2                2964                    7983.5
# 3                3184                    8525.1
# 4                3419                    9320.5
#
# [5 rows x 23 columns]

# %%
# Create a correlation dataframe
dataset_correlation = dataset.corr()
dataset_correlation
# Out:
#                             Gender       Age  DIAGNOSIS      MMSE   Hip ASM  \
# Gender                    1.000000  0.116231   0.082044 -0.042843  0.127672
# Age                       0.116231  1.000000   0.319562 -0.268466  0.321214
# DIAGNOSIS                 0.082044  0.319562   1.000000 -0.647656  0.198150
# MMSE                     -0.042843 -0.268466  -0.647656  1.000000 -0.183133
# Hip ASM                   0.127672  0.321214   0.198150 -0.183133  1.000000
# Hip Contrast             -0.065868 -0.092369  -0.025795  0.045594 -0.486691
# Hip Correlation           0.085064  0.143991   0.002473 -0.027468  0.492731
# Hip Variance             -0.027699 -0.043570  -0.140267  0.138332 -0.258669
# Hip Sum Average          -0.055464 -0.143811  -0.160184  0.149282 -0.454392
# Hip Sum Variance          0.029280  0.036215  -0.121257  0.102149  0.160970
# Hip Entropy              -0.077406 -0.269245  -0.236939  0.201183 -0.661113
# Hip Clusterhade           0.034475  0.011089  -0.007235 -0.005839 -0.034699
# ERC ASM                   0.241133  0.150117   0.114038 -0.070168  0.143720
# ERC CONTRAST             -0.214254  0.151857   0.282156 -0.299704  0.109706
# ERC CORRELATION           0.193034 -0.113391  -0.267101  0.282246 -0.056373
# ERC VARIANCE             -0.031170  0.044303  -0.041171  0.018136  0.080189
# ERC SUM AVERAGE          -0.234279 -0.116676  -0.067870  0.045044 -0.140598
# ERC SUM VARIANCE          0.086658 -0.041121  -0.189267  0.176831  0.014331
# ERC ENTROPY              -0.107463 -0.201378  -0.277818  0.230808 -0.158743
# ERC CLUSTER SHADE        -0.189932 -0.079260  -0.014408  0.009339 -0.119652
# ERCs_thicknessbaseline   -0.040095 -0.346216  -0.473150  0.421976 -0.225495
# ERCsVolumebaseline        0.299045 -0.194850  -0.338509  0.356734 -0.115935
# TOTAL_HIPPOCAMPUS_VOLUME  0.083613 -0.484433  -0.532900  0.479053 -0.311712
#
#                           Hip Contrast  Hip Correlation  Hip Variance   \
# Gender                       -0.065868         0.085064      -0.027699
# Age                          -0.092369         0.143991      -0.043570
# DIAGNOSIS                    -0.025795         0.002473      -0.140267
# MMSE                          0.045594        -0.027468       0.138332
# Hip ASM                      -0.486691         0.492731      -0.258669
# Hip Contrast                  1.000000        -0.861838       0.455792
# Hip Correlation              -0.861838         1.000000      -0.037310
# Hip Variance                  0.455792        -0.037310       1.000000
# Hip Sum Average               0.693716        -0.369258       0.800772
# Hip Sum Variance             -0.408371         0.716537       0.626353
# Hip Entropy                  -0.183602         0.262627       0.212510
# Hip Clusterhade               0.481889        -0.272443       0.319233
# ERC ASM                      -0.040525         0.078669      -0.008208
# ERC CONTRAST                 -0.062009         0.031599      -0.099881
# ERC CORRELATION               0.018973         0.033267       0.138731
# ERC VARIANCE                 -0.064729         0.108107       0.095614
# ERC SUM AVERAGE               0.041408        -0.090764      -0.028314
# ERC SUM VARIANCE             -0.025833         0.081815       0.141049
# ERC ENTROPY                   0.051084        -0.059953       0.082016
# ERC CLUSTER SHADE             0.047332        -0.100858      -0.060969
# ERCs_thicknessbaseline        0.070504        -0.068445       0.129899
# ERCsVolumebaseline            0.047754        -0.052571       0.050912
# TOTAL_HIPPOCAMPUS_VOLUME      0.104580        -0.118697       0.163555
#
#                           Hip Sum Average  Hip Sum Variance  ...  \
# Gender                          -0.055464          0.029280  ...
# Age                             -0.143811          0.036215  ...
# DIAGNOSIS                       -0.160184         -0.121257  ...
# MMSE                             0.149282          0.102149  ...
# Hip ASM                         -0.454392          0.160970  ...
# Hip Contrast                     0.693716         -0.408371  ...
# Hip Correlation                 -0.369258          0.716537  ...
# Hip Variance                     0.800772          0.626353  ...
# Hip Sum Average                  1.000000          0.213663  ...
# Hip Sum Variance                 0.213663          1.000000  ...
# Hip Entropy                      0.207348          0.378736  ...
# Hip Clusterhade                  0.639901         -0.094654  ...
# ERC ASM                         -0.044996          0.027074  ...
# ERC CONTRAST                    -0.102066         -0.048124  ...
# ERC CORRELATION                  0.103503          0.125657  ...
# ERC VARIANCE                     0.022997          0.154746  ...
# ERC SUM AVERAGE                  0.019008         -0.065303  ...
# ERC SUM VARIANCE                 0.075862          0.167275  ...
# ERC ENTROPY                      0.105170          0.039370  ...
# ERC CLUSTER SHADE               -0.007981         -0.103979  ...
# ERCs_thicknessbaseline           0.175476          0.071468  ...
# ERCsVolumebaseline               0.075596          0.010389  ...
# TOTAL_HIPPOCAMPUS_VOLUME         0.222843          0.076140  ...
#
#                           ERC CONTRAST  ERC CORRELATION  ERC VARIANCE   \
# Gender                       -0.214254         0.193034      -0.031170
# Age                           0.151857        -0.113391       0.044303
# DIAGNOSIS                     0.282156        -0.267101      -0.041171
# MMSE                         -0.299704         0.282246       0.018136
# Hip ASM                       0.109706        -0.056373       0.080189
# Hip Contrast                 -0.062009         0.018973      -0.064729
# Hip Correlation               0.031599         0.033267       0.108107
# Hip Variance                 -0.099881         0.138731       0.095614
# Hip Sum Average              -0.102066         0.103503       0.022997
# Hip Sum Variance             -0.048124         0.125657       0.154746
# Hip Entropy                  -0.080887         0.075834       0.004432
# Hip Clusterhade              -0.047365         0.051327       0.011979
# ERC ASM                      -0.316948         0.364855       0.028758
# ERC CONTRAST                  1.000000        -0.845566       0.126391
# ERC CORRELATION              -0.845566         1.000000       0.398280
# ERC VARIANCE                  0.126391         0.398280       1.000000
# ERC SUM AVERAGE               0.374303        -0.547658      -0.272222
# ERC SUM VARIANCE             -0.421911         0.818446       0.846041
# ERC ENTROPY                  -0.186568         0.219538       0.185063
# ERC CLUSTER SHADE             0.333587        -0.647713      -0.549962
# ERCs_thicknessbaseline       -0.380202         0.364720       0.085888
# ERCsVolumebaseline           -0.564483         0.493748      -0.021086
# TOTAL_HIPPOCAMPUS_VOLUME     -0.391090         0.352394       0.019813
#
#                           ERC SUM AVERAGE  ERC SUM VARIANCE  ERC ENTROPY  \
# Gender                          -0.234279          0.086658    -0.107463
# Age                             -0.116676         -0.041121    -0.201378
# DIAGNOSIS                       -0.067870         -0.189267    -0.277818
# MMSE                             0.045044          0.176831     0.230808
# Hip ASM                         -0.140598          0.014331    -0.158743
# Hip Contrast                     0.041408         -0.025833     0.051084
# Hip Correlation                 -0.090764          0.081815    -0.059953
# Hip Variance                    -0.028314          0.141049     0.082016
# Hip Sum Average                  0.019008          0.075862     0.105170
# Hip Sum Variance                -0.065303          0.167275     0.039370
# Hip Entropy                      0.100245          0.047515     0.140297
# Hip Clusterhade                 -0.048013          0.036399    -0.012408
# ERC ASM                         -0.911490          0.196621    -0.785342
# ERC CONTRAST                     0.374303         -0.421911    -0.186568
# ERC CORRELATION                 -0.547658          0.818446     0.219538
# ERC VARIANCE                    -0.272222          0.846041     0.185063
# ERC SUM AVERAGE                  1.000000         -0.449963     0.546520
# ERC SUM VARIANCE                -0.449963          1.000000     0.269408
# ERC ENTROPY                      0.546520          0.269408     1.000000
# ERC CLUSTER SHADE                0.927548         -0.681927     0.282032
# ERCs_thicknessbaseline           0.305100          0.282830     0.518828
# ERCsVolumebaseline              -0.018258          0.284097     0.253300
# TOTAL_HIPPOCAMPUS_VOLUME         0.140900          0.228291     0.367228
#
#                           ERC CLUSTER SHADE  ERCs_thicknessbaseline  \
# Gender                            -0.189932               -0.040095
# Age                               -0.079260               -0.346216
# DIAGNOSIS                         -0.014408               -0.473150
# MMSE                               0.009339                0.421976
# Hip ASM                           -0.119652               -0.225495
# Hip Contrast                       0.047332                0.070504
# Hip Correlation                   -0.100858               -0.068445
# Hip Variance                      -0.060969                0.129899
# Hip Sum Average                   -0.007981                0.175476
# Hip Sum Variance                  -0.103979                0.071468
# Hip Entropy                        0.063879                0.212802
# Hip Clusterhade                   -0.044562                0.042205
# ERC ASM                           -0.718593               -0.343816
# ERC CONTRAST                       0.333587               -0.380202
# ERC CORRELATION                   -0.647713                0.364720
# ERC VARIANCE                      -0.549962                0.085888
# ERC SUM AVERAGE                    0.927548                0.305100
# ERC SUM VARIANCE                  -0.681927                0.282830
# ERC ENTROPY                        0.282032                0.518828
# ERC CLUSTER SHADE                  1.000000                0.187345
# ERCs_thicknessbaseline             0.187345                1.000000
# ERCsVolumebaseline                -0.038194                0.541536
# TOTAL_HIPPOCAMPUS_VOLUME           0.072766                0.609730
#
#                           ERCsVolumebaseline  TOTAL_HIPPOCAMPUS_VOLUME
# Gender                              0.299045                  0.083613
# Age                                -0.194850                 -0.484433
# DIAGNOSIS                          -0.338509                 -0.532900
# MMSE                                0.356734                  0.479053
# Hip ASM                            -0.115935                 -0.311712
# Hip Contrast                        0.047754                  0.104580
# Hip Correlation                    -0.052571                 -0.118697
# Hip Variance                        0.050912                  0.163555
# Hip Sum Average                     0.075596                  0.222843
# Hip Sum Variance                    0.010389                  0.076140
# Hip Entropy                         0.089772                  0.276580
# Hip Clusterhade                     0.032441                  0.032116
# ERC ASM                             0.014455                 -0.176494
# ERC CONTRAST                       -0.564483                 -0.391090
# ERC CORRELATION                     0.493748                  0.352394
# ERC VARIANCE                       -0.021086                  0.019813
# ERC SUM AVERAGE                    -0.018258                  0.140900
# ERC SUM VARIANCE                    0.284097                  0.228291
# ERC ENTROPY                         0.253300                  0.367228
# ERC CLUSTER SHADE                  -0.038194                  0.072766
# ERCs_thicknessbaseline              0.541536                  0.609730
# ERCsVolumebaseline                  1.000000                  0.551697
# TOTAL_HIPPOCAMPUS_VOLUME            0.551697                  1.000000
#
# [23 rows x 23 columns]

# %% [markdown]
# Now lets visualize it for better comprehension instead.

# %%
# Plot a heatmap
plt.figure(figsize=(20, 20))  

sns.heatmap(dataset_correlation, 
            annot = True, 
            fmt = ".3f", 
            cmap = "coolwarm",
            square = True,
            linewidths = 0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# This is much better. We can clearly see which variables are correlated in a positive/negative manner. How about we set a threshold and filter only the correlated variables that are above .7 and -.7?
#
# *Check what was the threshold in paper*

# %%
plt.figure(figsize=(20, 20))  

sns.heatmap(dataset_correlation, 
            annot = True, 
            fmt = ".3f", 
            cmap = "coolwarm",
            square = True,
            linewidths = 0.5,
            mask = (dataset_correlation < 0.7) & (dataset_correlation > -0.7))
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Great. Now lets create a simple pair correlation report between each variable

# %%
correlation_pairs = pg.pairwise_corr(data = dataset)

correlation_report = correlation_pairs[correlation_pairs["r"].abs() > 0.7]

correlation_report[["X", "Y", "r"]].sort_values("r", ascending = False)
# Out:
#                    X                  Y         r
# 234  ERC SUM AVERAGE  ERC CLUSTER SHADE  0.927548
# 226    ERC VARIANCE    ERC SUM VARIANCE  0.846041
# 219  ERC CORRELATION   ERC SUM VARIANCE  0.818446
# 133    Hip Variance     Hip Sum Average  0.800772
# 119  Hip Correlation   Hip Sum Variance  0.716537
# 204          ERC ASM  ERC CLUSTER SHADE -0.718593
# 203          ERC ASM        ERC ENTROPY -0.785342
# 208     ERC CONTRAST    ERC CORRELATION -0.845566
# 100     Hip Contrast    Hip Correlation -0.861838
# 201          ERC ASM    ERC SUM AVERAGE -0.911490

# %% [markdown]
# Now lets plot the positive and negative correlated variables first using scatterplots

# %%
# Plot scatterplot based on the above correlation report
fig, axs = plt.subplots(5,2, figsize = (25, 20))

sns.scatterplot(data = dataset, x = "ERC SUM AVERAGE", y = "ERC CLUSTER SHADE", ax = axs[0][0])
sns.scatterplot(data = dataset, x = "ERC VARIANCE ", y = "ERC SUM VARIANCE", ax = axs[0][1])

sns.scatterplot(data = dataset, x = "ERC CORRELATION", y = "ERC SUM VARIANCE", ax = axs[1][0])
sns.scatterplot(data = dataset, x = "Hip Variance ", y = "Hip Sum Average", ax = axs[1][1])

sns.scatterplot(data = dataset, x = "Hip Correlation", y = "Hip Sum Variance", ax = axs[2][0])
sns.scatterplot(data = dataset, x = "ERC ASM", y = "ERC CLUSTER SHADE", ax = axs[2][1])

sns.scatterplot(data = dataset, x = "ERC ASM", y = "ERC ENTROPY", ax = axs[3][0])
sns.scatterplot(data = dataset, x = "ERC CONTRAST", y = "Hip Correlation", ax = axs[3][1])

sns.scatterplot(data = dataset, x = "Hip Contrast", y = "ERC SUM AVERAGE", ax = axs[4][0])
sns.scatterplot(data = dataset, x = "Hip Contrast", y = "ERC SUM AVERAGE", ax = axs[4][1])

plt.show()

# %% [markdown]
# How about by target?

# %%
# Plot scatterplot based on the above correlation report
fig, axs = plt.subplots(5, 2, figsize = (25, 20))

sns.scatterplot(data=dataset, x="ERC SUM AVERAGE", y="ERC CLUSTER SHADE", hue="DIAGNOSIS", size="DIAGNOSIS", ax=axs[0][0])
sns.scatterplot(data=dataset, x="ERC VARIANCE ", y="ERC SUM VARIANCE", hue="DIAGNOSIS", size="DIAGNOSIS", ax=axs[0][1])

sns.scatterplot(data=dataset, x="ERC CORRELATION", y="ERC SUM VARIANCE", hue="DIAGNOSIS", size="DIAGNOSIS", ax=axs[1][0])
sns.scatterplot(data=dataset, x="Hip Variance ", y="Hip Sum Average", hue="DIAGNOSIS", size="DIAGNOSIS", ax=axs[1][1])

sns.scatterplot(data=dataset, x="Hip Correlation", y="Hip Sum Variance", hue="DIAGNOSIS", size="DIAGNOSIS", ax=axs[2][0])
sns.scatterplot(data=dataset, x="ERC ASM", y="ERC CLUSTER SHADE", hue="DIAGNOSIS", size="DIAGNOSIS", ax=axs[2][1])

sns.scatterplot(data=dataset, x="ERC ASM", y="ERC ENTROPY", hue="DIAGNOSIS", size="DIAGNOSIS", ax=axs[3][0])
sns.scatterplot(data=dataset, x="ERC CONTRAST", y="Hip Correlation", hue="DIAGNOSIS", size="DIAGNOSIS", ax=axs[3][1])

sns.scatterplot(data=dataset, x="Hip Contrast", y="ERC SUM AVERAGE", hue="DIAGNOSIS", size="DIAGNOSIS", ax=axs[4][0])
sns.scatterplot(data=dataset, x="Hip Contrast", y="ERC SUM AVERAGE", hue="DIAGNOSIS", size="DIAGNOSIS", ax=axs[4][1])

plt.tight_layout()
plt.show()

# %% [markdown]
# This is fantastic! Isnt this more efficient instead of manually checking each column name in the pairplot?
#
# We can now understand how each variable is affected to one another.
#
# But how about the **target**? Lets narrow it down to see which features are strongly correlated with the target

# %%
# Check correlation between each variable and target
correlation_with_target = dataset.corr()["DIAGNOSIS"].sort_values(ascending=False)
correlation_with_target
# Out:
# DIAGNOSIS                   1.000000
# Age                         0.319562
# ERC CONTRAST                0.282156
# Hip ASM                     0.198150
# ERC ASM                     0.114038
# Gender                      0.082044
# Hip Correlation             0.002473
# Hip Clusterhade            -0.007235
# ERC CLUSTER SHADE          -0.014408
# Hip Contrast               -0.025795
# ERC VARIANCE               -0.041171
# ERC SUM AVERAGE            -0.067870
# Hip Sum Variance           -0.121257
# Hip Variance               -0.140267
# Hip Sum Average            -0.160184
# ERC SUM VARIANCE           -0.189267
# Hip Entropy                -0.236939
# ERC CORRELATION            -0.267101
# ERC ENTROPY                -0.277818
# ERCsVolumebaseline         -0.338509
# ERCs_thicknessbaseline     -0.473150
# TOTAL_HIPPOCAMPUS_VOLUME   -0.532900
# MMSE                       -0.647656
# Name: DIAGNOSIS, dtype: float64

# %% [markdown]
# Lets plot it

# %%
# Plot target correlaton using bar
plt.figure(figsize=(15,15))

correlation_with_target.plot(kind = "barh", 
                             color = "#5e76fe",
                             edgecolor = "black")
# Out:
# <Axes: >

# %% [markdown]
# I believe we have a solid understanding now regarding our target feature. This will help us a lot when performing feature selection and further understand overall feature importance.
