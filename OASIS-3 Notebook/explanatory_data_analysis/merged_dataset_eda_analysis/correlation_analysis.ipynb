# %% [markdown]
# ## Correlation Analysis
#
# Lets check the correlation between variables
#
# Correlation measures the strength and direction of the linear relationship between two variables, but it is normalized to be independent of the units of the variables.

# %%
# Import basic libraries for EDA
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pingouin as pg
from dotenv import load_dotenv
import os

# %%
# Import dataset
load_dotenv()
dataset_path=os.getenv("DATASET_PATH_TWO_M")
dataset = pd.read_csv(dataset_path)
dataset.head()
# Out:
#    Gender        Age  DIAGNOSIS  MMSE   Hip ASM  Hip Contrast  \
# 0       0  65.149895          0  30.0  0.460200     83.371297
# 1       1  67.206024          0  30.0  0.329647    149.712265
# 2       0  58.773440          0  30.0  0.385797    104.769354
# 3       0  55.096508          0  30.0  0.229011    166.953431
# 4       0  48.030117          0  29.0  0.242913     86.816221
#
#    Hip Correlation  Hip Variance   Hip Sum Average  Hip Sum Variance  ...  \
# 0         0.508610      89.066304        10.318461        272.893918  ...
# 1         0.328176     109.824210        13.761403        289.584573  ...
# 2         0.545986     125.678783        15.521177        397.945779  ...
# 3         0.275601     112.186834        18.126786        281.793906  ...
# 4         0.377439      73.484651        13.463920        207.122381  ...
#
#    ERC CONTRAST  ERC CORRELATION  ERC VARIANCE   ERC SUM AVERAGE  \
# 0    245.139997         0.385395     209.332939        41.129640
# 1    221.932844         0.406722     197.689209        42.149774
# 2    283.711655         0.336695     217.002950        41.289080
# 3    231.188679         0.498026     232.827358        33.062621
# 4    245.120671         0.458936     233.016858        44.574015
#
#    ERC SUM VARIANCE  ERC ENTROPY  ERC CLUSTER SHADE  ERCs_thicknessbaseline  \
# 0        592.191757     3.234648       18110.527190                   6.948
# 1        568.823992     3.240436       23801.869010                   7.090
# 2        584.300146     3.069283       17579.374770                   6.832
# 3        700.120751     3.093719        4888.606116                   6.523
# 4        686.946759     3.149858       22134.931110                   8.253
#
#    ERCsVolumebaseline  TOTAL_HIPPOCAMPUS_VOLUME
# 0              2826.0                    6861.9
# 1              3792.0                    7378.1
# 2              2964.0                    7983.5
# 3              3184.0                    8525.1
# 4              3419.0                    9320.5
#
# [5 rows x 23 columns]

# %%
# Create a correlation dataframe
dataset_correlation = dataset.corr()
dataset_correlation
# Out:
#                             Gender       Age  DIAGNOSIS      MMSE   Hip ASM  \
# Gender                    1.000000  0.056116   0.052143 -0.031737  0.023665
# Age                       0.056116  1.000000   0.275878 -0.227406 -0.207893
# DIAGNOSIS                 0.052143  0.275878   1.000000 -0.693833 -0.122697
# MMSE                     -0.031737 -0.227406  -0.693833  1.000000  0.018654
# Hip ASM                   0.023665 -0.207893  -0.122697  0.018654  1.000000
# Hip Contrast             -0.031675  0.148505   0.110831 -0.037777 -0.629179
# Hip Correlation           0.046828  0.187961   0.044008 -0.041766  0.075850
# Hip Variance             -0.015866  0.354592   0.163131 -0.068091 -0.773146
# Hip Sum Average           0.013798  0.305402   0.166288 -0.055087 -0.914064
# Hip Sum Variance         -0.003576  0.364714   0.153677 -0.067533 -0.659070
# Hip Entropy              -0.002913  0.265544   0.145545 -0.036617 -0.939624
# Hip Clusterhade           0.058068  0.194593   0.139049 -0.053538 -0.663498
# ERC ASM                   0.122579  0.241305   0.188979 -0.124265 -0.209883
# ERC CONTRAST             -0.101476 -0.022704   0.196090 -0.249173  0.381439
# ERC CORRELATION           0.106369  0.036065  -0.194039  0.252584 -0.337187
# ERC VARIANCE              0.003641 -0.004532  -0.055448  0.036653  0.144681
# ERC SUM AVERAGE          -0.151506 -0.232654  -0.173471  0.114986  0.244957
# ERC SUM VARIANCE          0.051401 -0.003565  -0.179708  0.191142 -0.077138
# ERC ENTROPY              -0.072017 -0.215773  -0.289886  0.242586  0.032824
# ERC CLUSTER SHADE        -0.146728 -0.183913  -0.097464  0.055725  0.211981
# ERCs_thicknessbaseline   -0.017309 -0.458300  -0.365521  0.251570  0.771810
# ERCsVolumebaseline        0.086159 -0.407442  -0.404008  0.334197  0.649144
# TOTAL_HIPPOCAMPUS_VOLUME  0.003393 -0.523915  -0.421364  0.306835  0.712072
#
#                           Hip Contrast  Hip Correlation  Hip Variance   \
# Gender                       -0.031675         0.046828      -0.015866
# Age                           0.148505         0.187961       0.354592
# DIAGNOSIS                     0.110831         0.044008       0.163131
# MMSE                         -0.037777        -0.041766      -0.068091
# Hip ASM                      -0.629179         0.075850      -0.773146
# Hip Contrast                  1.000000        -0.604936       0.632724
# Hip Correlation              -0.604936         1.000000       0.175786
# Hip Variance                  0.632724         0.175786       1.000000
# Hip Sum Average               0.623652         0.048183       0.831939
# Hip Sum Variance              0.320059         0.488911       0.936980
# Hip Entropy                   0.419621         0.232221       0.795575
# Hip Clusterhade               0.492825        -0.086140       0.462511
# ERC ASM                       0.180919         0.165408       0.395767
# ERC CONTRAST                 -0.239080        -0.053787      -0.365350
# ERC CORRELATION               0.206758         0.100547       0.376224
# ERC VARIANCE                 -0.093033         0.066377      -0.037894
# ERC SUM AVERAGE              -0.187355        -0.172061      -0.406250
# ERC SUM VARIANCE              0.046429         0.093355       0.170342
# ERC ENTROPY                  -0.078717        -0.112832      -0.207711
# ERC CLUSTER SHADE            -0.145017        -0.164285      -0.346718
# ERCs_thicknessbaseline       -0.454050        -0.186082      -0.783987
# ERCsVolumebaseline           -0.385714        -0.159075      -0.663551
# TOTAL_HIPPOCAMPUS_VOLUME     -0.427560        -0.201012      -0.748282
#
#                           Hip Sum Average  Hip Sum Variance  ...  \
# Gender                           0.013798         -0.003576  ...
# Age                              0.305402          0.364714  ...
# DIAGNOSIS                        0.166288          0.153677  ...
# MMSE                            -0.055087         -0.067533  ...
# Hip ASM                         -0.914064         -0.659070  ...
# Hip Contrast                     0.623652          0.320059  ...
# Hip Correlation                  0.048183          0.488911  ...
# Hip Variance                     0.831939          0.936980  ...
# Hip Sum Average                  1.000000          0.738964  ...
# Hip Sum Variance                 0.738964          1.000000  ...
# Hip Entropy                      0.922329          0.781858  ...
# Hip Clusterhade                  0.811338          0.347783  ...
# ERC ASM                          0.250195          0.404317  ...
# ERC CONTRAST                    -0.387009         -0.340888  ...
# ERC CORRELATION                  0.362142          0.367019  ...
# ERC VARIANCE                    -0.112401         -0.008215  ...
# ERC SUM AVERAGE                 -0.299754         -0.413285  ...
# ERC SUM VARIANCE                 0.112098          0.185114  ...
# ERC ENTROPY                     -0.059906         -0.219621  ...
# ERC CLUSTER SHADE               -0.275045         -0.358594  ...
# ERCs_thicknessbaseline          -0.843771         -0.750719  ...
# ERCsVolumebaseline              -0.708846         -0.635913  ...
# TOTAL_HIPPOCAMPUS_VOLUME        -0.796104         -0.720513  ...
#
#                           ERC CONTRAST  ERC CORRELATION  ERC VARIANCE   \
# Gender                       -0.101476         0.106369       0.003641
# Age                          -0.022704         0.036065      -0.004532
# DIAGNOSIS                     0.196090        -0.194039      -0.055448
# MMSE                         -0.249173         0.252584       0.036653
# Hip ASM                       0.381439        -0.337187       0.144681
# Hip Contrast                 -0.239080         0.206758      -0.093033
# Hip Correlation              -0.053787         0.100547       0.066377
# Hip Variance                 -0.365350         0.376224      -0.037894
# Hip Sum Average              -0.387009         0.362142      -0.112401
# Hip Sum Variance             -0.340888         0.367019      -0.008215
# Hip Entropy                  -0.383925         0.353710      -0.127970
# Hip Clusterhade              -0.255713         0.234858      -0.080294
# ERC ASM                      -0.392310         0.406873      -0.097530
# ERC CONTRAST                  1.000000        -0.869293       0.226714
# ERC CORRELATION              -0.869293         1.000000       0.243499
# ERC VARIANCE                  0.226714         0.243499       1.000000
# ERC SUM AVERAGE               0.435323        -0.547995      -0.085089
# ERC SUM VARIANCE             -0.377078         0.755031       0.803973
# ERC ENTROPY                  -0.049537         0.093954       0.203914
# ERC CLUSTER SHADE             0.385702        -0.639283      -0.391886
# ERCs_thicknessbaseline        0.223472        -0.195570       0.150047
# ERCsVolumebaseline           -0.032177         0.031363       0.093195
# TOTAL_HIPPOCAMPUS_VOLUME      0.176650        -0.160245       0.121100
#
#                           ERC SUM AVERAGE  ERC SUM VARIANCE  ERC ENTROPY  \
# Gender                          -0.151506          0.051401    -0.072017
# Age                             -0.232654         -0.003565    -0.215773
# DIAGNOSIS                       -0.173471         -0.179708    -0.289886
# MMSE                             0.114986          0.191142     0.242586
# Hip ASM                          0.244957         -0.077138     0.032824
# Hip Contrast                    -0.187355          0.046429    -0.078717
# Hip Correlation                 -0.172061          0.093355    -0.112832
# Hip Variance                    -0.406250          0.170342    -0.207711
# Hip Sum Average                 -0.299754          0.112098    -0.059906
# Hip Sum Variance                -0.413285          0.185114    -0.219621
# Hip Entropy                     -0.295251          0.094550    -0.064076
# Hip Clusterhade                 -0.136708          0.068076     0.046122
# ERC ASM                         -0.919036          0.136716    -0.826940
# ERC CONTRAST                     0.435323         -0.377078    -0.049537
# ERC CORRELATION                 -0.547995          0.755031     0.093954
# ERC VARIANCE                    -0.085089          0.803973     0.203914
# ERC SUM AVERAGE                  1.000000         -0.333264     0.634566
# ERC SUM VARIANCE                -0.333264          1.000000     0.240846
# ERC ENTROPY                      0.634566          0.240846     1.000000
# ERC CLUSTER SHADE                0.916981         -0.593421     0.364466
# ERCs_thicknessbaseline           0.451738          0.027919     0.315302
# ERCsVolumebaseline               0.298818          0.121137     0.280736
# TOTAL_HIPPOCAMPUS_VOLUME         0.393339          0.023676     0.286432
#
#                           ERC CLUSTER SHADE  ERCs_thicknessbaseline  \
# Gender                            -0.146728               -0.017309
# Age                               -0.183913               -0.458300
# DIAGNOSIS                         -0.097464               -0.365521
# MMSE                               0.055725                0.251570
# Hip ASM                            0.211981                0.771810
# Hip Contrast                      -0.145017               -0.454050
# Hip Correlation                   -0.164285               -0.186082
# Hip Variance                      -0.346718               -0.783987
# Hip Sum Average                   -0.275045               -0.843771
# Hip Sum Variance                  -0.358594               -0.750719
# Hip Entropy                       -0.262065               -0.829598
# Hip Clusterhade                   -0.146926               -0.577251
# ERC ASM                           -0.718856               -0.428394
# ERC CONTRAST                       0.385702                0.223472
# ERC CORRELATION                   -0.639283               -0.195570
# ERC VARIANCE                      -0.391886                0.150047
# ERC SUM AVERAGE                    0.916981                0.451738
# ERC SUM VARIANCE                  -0.593421                0.027919
# ERC ENTROPY                        0.364466                0.315302
# ERC CLUSTER SHADE                  1.000000                0.359819
# ERCs_thicknessbaseline             0.359819                1.000000
# ERCsVolumebaseline                 0.228858                0.843127
# TOTAL_HIPPOCAMPUS_VOLUME           0.313418                0.921857
#
#                           ERCsVolumebaseline  TOTAL_HIPPOCAMPUS_VOLUME
# Gender                              0.086159                  0.003393
# Age                                -0.407442                 -0.523915
# DIAGNOSIS                          -0.404008                 -0.421364
# MMSE                                0.334197                  0.306835
# Hip ASM                             0.649144                  0.712072
# Hip Contrast                       -0.385714                 -0.427560
# Hip Correlation                    -0.159075                 -0.201012
# Hip Variance                       -0.663551                 -0.748282
# Hip Sum Average                    -0.708846                 -0.796104
# Hip Sum Variance                   -0.635913                 -0.720513
# Hip Entropy                        -0.695889                 -0.774461
# Hip Clusterhade                    -0.481381                 -0.549319
# ERC ASM                            -0.277659                 -0.373569
# ERC CONTRAST                       -0.032177                  0.176650
# ERC CORRELATION                     0.031363                 -0.160245
# ERC VARIANCE                        0.093195                  0.121100
# ERC SUM AVERAGE                     0.298818                  0.393339
# ERC SUM VARIANCE                    0.121137                  0.023676
# ERC ENTROPY                         0.280736                  0.286432
# ERC CLUSTER SHADE                   0.228858                  0.313418
# ERCs_thicknessbaseline              0.843127                  0.921857
# ERCsVolumebaseline                  1.000000                  0.848557
# TOTAL_HIPPOCAMPUS_VOLUME            0.848557                  1.000000
#
# [23 rows x 23 columns]

# %% [markdown]
# Now lets visualize it for better comprehension instead.

# %%
# Plot a heatmap
plt.figure(figsize=(20, 20))  

sns.heatmap(dataset_correlation, 
            annot = True, 
            fmt = ".3f", 
            cmap = "coolwarm",
            square = True,
            linewidths = 0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# This is much better. We can clearly see which variables are correlated in a positive/negative manner. How about we set a threshold and filter only the correlated variables that are above .7 and -.7?
#
# *Check what was the threshold in paper*

# %%
plt.figure(figsize=(20, 20))  

sns.heatmap(dataset_correlation, 
            annot = True, 
            fmt = ".3f", 
            cmap = "coolwarm",
            square = True,
            linewidths = 0.5,
            mask = (dataset_correlation < 0.7) & (dataset_correlation > -0.7))
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Great. Now lets create a simple pair correlation report between each variable

# %%
correlation_pairs = pg.pairwise_corr(data = dataset)

correlation_report = correlation_pairs[correlation_pairs["r"].abs() > 0.9]

correlation_report[["X", "Y", "r"]].sort_values("r", ascending = False)
# Out:
#                           X                         Y         r
# 134           Hip Variance           Hip Sum Variance  0.936980
# 149         Hip Sum Average               Hip Entropy  0.922329
# 251  ERCs_thicknessbaseline  TOTAL_HIPPOCAMPUS_VOLUME  0.921857
# 234         ERC SUM AVERAGE         ERC CLUSTER SHADE  0.916981
# 85                  Hip ASM           Hip Sum Average -0.914064
# 201                 ERC ASM           ERC SUM AVERAGE -0.919036
# 87                  Hip ASM               Hip Entropy -0.939624

# %%
dataset.columns
# Out:
# Index(['Gender', 'Age', 'DIAGNOSIS', 'MMSE', 'Hip ASM', 'Hip Contrast',
#        'Hip Correlation', 'Hip Variance ', 'Hip Sum Average',
#        'Hip Sum Variance', 'Hip Entropy', 'Hip Clusterhade', 'ERC ASM',
#        'ERC CONTRAST', 'ERC CORRELATION', 'ERC VARIANCE ', 'ERC SUM AVERAGE',
#        'ERC SUM VARIANCE', 'ERC ENTROPY', 'ERC CLUSTER SHADE',
#        'ERCs_thicknessbaseline', 'ERCsVolumebaseline',
#        'TOTAL_HIPPOCAMPUS_VOLUME'],
#       dtype='object')

# %%
# Plot scatterplot based on the above correlation report
fig, axs = plt.subplots(4, 2, figsize=(25, 20))

sns.scatterplot(data=dataset, x="Hip Variance ", y="Hip Sum Variance", ax=axs[0][0])
sns.scatterplot(data=dataset, x="Hip Sum Average", y="Hip Entropy", ax=axs[0][1])

sns.scatterplot(data=dataset, x="ERCs_thicknessbaseline", y="TOTAL_HIPPOCAMPUS_VOLUME", ax=axs[1][0])
sns.scatterplot(data=dataset, x="ERC SUM AVERAGE", y="ERC CLUSTER SHADE", ax=axs[1][1])

sns.scatterplot(data=dataset, x="Hip ASM", y="Hip Sum Average", ax=axs[2][0])
sns.scatterplot(data=dataset, x="ERC ASM", y="ERC SUM AVERAGE", ax=axs[2][1])

sns.scatterplot(data=dataset, x="Hip ASM", y="Hip Entropy", ax=axs[3][0])

fig.delaxes(axs[3][1])

plt.show()

# %% [markdown]
# Now lets plot the positive and negative correlated variables first using scatterplots

# %%
# Plot scatterplot based on the above correlation report
fig, axs = plt.subplots(5,2, figsize = (25, 20))

sns.scatterplot(data = dataset, x = "ERC SUM AVERAGE", y = "ERC CLUSTER SHADE", ax = axs[0][0])
sns.scatterplot(data = dataset, x = "ERC VARIANCE ", y = "ERC SUM VARIANCE", ax = axs[0][1])

sns.scatterplot(data = dataset, x = "ERC CORRELATION", y = "ERC SUM VARIANCE", ax = axs[1][0])
sns.scatterplot(data = dataset, x = "Hip Variance ", y = "Hip Sum Average", ax = axs[1][1])

sns.scatterplot(data = dataset, x = "Hip Correlation", y = "Hip Sum Variance", ax = axs[2][0])
sns.scatterplot(data = dataset, x = "ERC ASM", y = "ERC CLUSTER SHADE", ax = axs[2][1])

sns.scatterplot(data = dataset, x = "ERC ASM", y = "ERC ENTROPY", ax = axs[3][0])
sns.scatterplot(data = dataset, x = "ERC CONTRAST", y = "Hip Correlation", ax = axs[3][1])

sns.scatterplot(data = dataset, x = "Hip Contrast", y = "ERC SUM AVERAGE", ax = axs[4][0])
sns.scatterplot(data = dataset, x = "Hip Contrast", y = "ERC SUM AVERAGE", ax = axs[4][1])

plt.show()

# %% [markdown]
# How about by target?

# %%
# Plot scatterplot based on the above correlation report
fig, axs = plt.subplots(5, 2, figsize = (25, 20))

sns.scatterplot(data=dataset, x="ERC SUM AVERAGE", y="ERC CLUSTER SHADE", hue="DIAGNOSIS", size="DIAGNOSIS", ax=axs[0][0])
sns.scatterplot(data=dataset, x="ERC VARIANCE ", y="ERC SUM VARIANCE", hue="DIAGNOSIS", size="DIAGNOSIS", ax=axs[0][1])

sns.scatterplot(data=dataset, x="ERC CORRELATION", y="ERC SUM VARIANCE", hue="DIAGNOSIS", size="DIAGNOSIS", ax=axs[1][0])
sns.scatterplot(data=dataset, x="Hip Variance ", y="Hip Sum Average", hue="DIAGNOSIS", size="DIAGNOSIS", ax=axs[1][1])

sns.scatterplot(data=dataset, x="Hip Correlation", y="Hip Sum Variance", hue="DIAGNOSIS", size="DIAGNOSIS", ax=axs[2][0])
sns.scatterplot(data=dataset, x="ERC ASM", y="ERC CLUSTER SHADE", hue="DIAGNOSIS", size="DIAGNOSIS", ax=axs[2][1])

sns.scatterplot(data=dataset, x="ERC ASM", y="ERC ENTROPY", hue="DIAGNOSIS", size="DIAGNOSIS", ax=axs[3][0])
sns.scatterplot(data=dataset, x="ERC CONTRAST", y="Hip Correlation", hue="DIAGNOSIS", size="DIAGNOSIS", ax=axs[3][1])

sns.scatterplot(data=dataset, x="Hip Contrast", y="ERC SUM AVERAGE", hue="DIAGNOSIS", size="DIAGNOSIS", ax=axs[4][0])
sns.scatterplot(data=dataset, x="Hip Contrast", y="ERC SUM AVERAGE", hue="DIAGNOSIS", size="DIAGNOSIS", ax=axs[4][1])

plt.tight_layout()
plt.show()

# %% [markdown]
# This is fantastic! Isnt this more efficient instead of manually checking each column name in the pairplot?
#
# We can now understand how each variable is affected to one another.
#
# But how about the **target**? Lets narrow it down to see which features are strongly correlated with the target

# %%
# Check correlation between each variable and target
correlation_with_target = dataset.corr()["DIAGNOSIS"].sort_values(ascending=False)
correlation_with_target
# Out:
# DIAGNOSIS                   1.000000
# Age                         0.275878
# ERC CONTRAST                0.196090
# ERC ASM                     0.188979
# Hip Sum Average             0.166288
# Hip Variance                0.163131
# Hip Sum Variance            0.153677
# Hip Entropy                 0.145545
# Hip Clusterhade             0.139049
# Hip Contrast                0.110831
# Gender                      0.052143
# Hip Correlation             0.044008
# ERC VARIANCE               -0.055448
# ERC CLUSTER SHADE          -0.097464
# Hip ASM                    -0.122697
# ERC SUM AVERAGE            -0.173471
# ERC SUM VARIANCE           -0.179708
# ERC CORRELATION            -0.194039
# ERC ENTROPY                -0.289886
# ERCs_thicknessbaseline     -0.365521
# ERCsVolumebaseline         -0.404008
# TOTAL_HIPPOCAMPUS_VOLUME   -0.421364
# MMSE                       -0.693833
# Name: DIAGNOSIS, dtype: float64

# %% [markdown]
# Lets plot it

# %%
# Plot target correlaton using bar
plt.figure(figsize=(15,15))

correlation_with_target.plot(kind = "barh", 
                             color = "#5e76fe",
                             edgecolor = "black")
# Out:
# <Axes: >

# %% [markdown]
# I believe we have a solid understanding now regarding our target feature. This will help us a lot when performing feature selection and further understand overall feature importance.
