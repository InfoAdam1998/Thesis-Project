# %% [markdown]
# # Initialize Notebook
#
# ### Data-preprocessing

# %%
# Import basic libraries for EDA
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from dotenv import load_dotenv
import os
import pingouin as pg

# %%
# Import dataset
load_dotenv()
dataset_path=os.getenv("DATASET_PATH")
dataset_ADNI = pd.read_csv(dataset_path)
dataset_ADNI.head()
# Out:
#    RID  Gender  Ageatscreening  Diagnosis  MMSE0m  HipsASMbaseline  \
# 0    3       0         81.3479          3    20.0              NaN
# 1    4       0         67.6904          1    27.0             0.06
# 2    5       0         73.8027          0    29.0             0.10
# 3    8       1         84.5945          0    28.0             0.08
# 4   10       1         73.9726          3    24.0             0.11
#
#    HipsContrastbaseline  HipsCorelationbaseline  HipsVariancebaseline  \
# 0                158.27                    0.63                218.30
# 1                147.64                    0.55                173.64
# 2                199.66                    0.55                222.27
# 3                184.21                    0.53                201.55
# 4                233.02                    0.48                229.88
#
#    HipsSumAveragebaseline  ...  ERCsContrastbaseline  ERCsCorelationbaseline  \
# 0                   28.37  ...                253.10                    0.40
# 1                   44.72  ...                220.88                    0.48
# 2                   41.18  ...                220.37                    0.54
# 3                   43.04  ...                198.42                    0.54
# 4                   39.46  ...                196.55                    0.53
#
#    ERCsVariancebaseline  ERCsSumAveragebaseline  ERCsSumVariancebaseline  \
# 0                208.65                   23.39                   581.50
# 1                215.70                   33.74                   641.90
# 2                232.18                   29.18                   708.36
# 3                220.48                   26.68                   683.50
# 4                210.63                   26.60                   645.95
#
#    ERCsEntropybaseline  ERCsClusterShadebaseline  ERCs_thicknessbaseline  \
# 0                  NaN                  -2568.19                    2.31
# 1                 3.33                   4113.01                    2.76
# 2                 2.87                  -1388.41                    3.18
# 3                 2.77                  -2506.55                    2.68
# 4                 2.72                  -1164.02                    2.64
#
#    ERCsVolumebaseline  HipposcampusVolumebaseline
# 0              1176.0                      3047.0
# 1              1942.0                      3449.0
# 2              2044.0                      3441.0
# 3              1959.0                      2875.0
# 4              1397.0                      2700.0
#
# [5 rows x 24 columns]

# %%
# Import dataset
load_dotenv()
dataset_path=os.getenv("DATASET_PATH_TWO_P")
dataset = pd.read_csv(dataset_path)
dataset.head()
# Out:
#    Gender        Age  DIAGNOSIS  MMSE   Hip ASM  Hip Contrast  \
# 0       0  65.149895          0  30.0  0.460200     83.371297
# 1       1  67.206024          0  30.0  0.329647    149.712265
# 2       0  58.773440          0  30.0  0.385797    104.769354
# 3       0  55.096508          0  30.0  0.229011    166.953431
# 4       0  48.030117          0  29.0  0.242913     86.816221
#
#    Hip Correlation  Hip Variance   Hip Sum Average  Hip Sum Variance  ...  \
# 0         0.508610      89.066304        10.318461        272.893918  ...
# 1         0.328176     109.824210        13.761403        289.584573  ...
# 2         0.545986     125.678783        15.521177        397.945779  ...
# 3         0.275601     112.186834        18.126786        281.793906  ...
# 4         0.377439      73.484651        13.463920        207.122381  ...
#
#    ERC CONTRAST  ERC CORRELATION  ERC VARIANCE   ERC SUM AVERAGE  \
# 0    245.139997         0.385395     209.332939        41.129640
# 1    221.932844         0.406722     197.689209        42.149774
# 2    283.711655         0.336695     217.002950        41.289080
# 3    231.188679         0.498026     232.827358        33.062621
# 4    245.120671         0.458936     233.016858        44.574015
#
#    ERC SUM VARIANCE  ERC ENTROPY  ERC CLUSTER SHADE  ERCs_thicknessbaseline  \
# 0        592.191757     3.234648       18110.527190                   6.948
# 1        568.823992     3.240436       23801.869010                   7.090
# 2        584.300146     3.069283       17579.374770                   6.832
# 3        700.120751     3.093719        4888.606116                   6.523
# 4        686.946759     3.149858       22134.931110                   8.253
#
#    ERCsVolumebaseline  TOTAL_HIPPOCAMPUS_VOLUME
# 0                2826                    6861.9
# 1                3792                    7378.1
# 2                2964                    7983.5
# 3                3184                    8525.1
# 4                3419                    9320.5
#
# [5 rows x 23 columns]

# %%
dataset_ADNI = dataset_ADNI.drop(["RID"], axis=1)

# %%
rename_dict = {
    'Ageatscreening': 'Age',
    'Diagnosis': 'DIAGNOSIS',
    'MMSE0m': 'MMSE',
    'HipsASMbaseline': 'Hip ASM',
    'HipsContrastbaseline': 'Hip Contrast',
    'HipsCorelationbaseline': 'Hip Correlation',
    'HipsVariancebaseline': 'Hip Variance ',
    'HipsSumAveragebaseline': 'Hip Sum Average',
    'HipsSumVariancebaseline': 'Hip Sum Variance',
    'HipsEntropybaseline': 'Hip Entropy',
    'HipsClusterShadebaseline': 'Hip Clusterhade',
    'ERCsASMbaseline': 'ERC ASM',
    'ERCsContrastbaseline': 'ERC CONTRAST',
    'ERCsCorelationbaseline': 'ERC CORRELATION',
    'ERCsVariancebaseline': 'ERC VARIANCE ',
    'ERCsSumAveragebaseline': 'ERC SUM AVERAGE',
    'ERCsSumVariancebaseline': 'ERC SUM VARIANCE',
    'ERCsEntropybaseline': 'ERC ENTROPY',
    'ERCsClusterShadebaseline': 'ERC CLUSTER SHADE',
    'HipposcampusVolumebaseline': 'TOTAL_HIPPOCAMPUS_VOLUME'
}

dataset_ADNI.rename(columns=rename_dict, inplace=True)

# %%
dataset = pd.concat([dataset, dataset_ADNI], axis=0, ignore_index=True)

# %%
dataset
# Out:
#       Gender        Age  DIAGNOSIS  MMSE   Hip ASM  Hip Contrast  \
# 0          0  65.149895          0  30.0  0.460200     83.371297
# 1          1  67.206024          0  30.0  0.329647    149.712265
# 2          0  58.773440          0  30.0  0.385797    104.769354
# 3          0  55.096508          0  30.0  0.229011    166.953431
# 4          0  48.030117          0  29.0  0.242913     86.816221
# ...      ...        ...        ...   ...       ...           ...
# 1349       1  75.641100          3  26.0  0.180000    173.840000
# 1350       0  71.271200          3  21.0  0.220000    174.020000
# 1351       1  79.854800          3  23.0  0.190000    199.310000
# 1352       1  62.745200          3  24.0  0.050000    142.050000
# 1353       0  85.084900          3  20.0  0.150000    147.660000
#
#       Hip Correlation  Hip Variance   Hip Sum Average  Hip Sum Variance  ...  \
# 0            0.508610      89.066304        10.318461        272.893918  ...
# 1            0.328176     109.824210        13.761403        289.584573  ...
# 2            0.545986     125.678783        15.521177        397.945779  ...
# 3            0.275601     112.186834        18.126786        281.793906  ...
# 4            0.377439      73.484651        13.463920        207.122381  ...
# ...               ...            ...              ...               ...  ...
# 1349         0.590000     215.040000        33.840000        686.330000  ...
# 1350         0.580000     211.070000        30.560000        670.240000  ...
# 1351         0.560000     229.630000        33.130000        719.200000  ...
# 1352         0.500000     147.120000        46.210000        446.420000  ...
# 1353         0.570000     180.780000        31.820000        575.460000  ...
#
#       ERC CONTRAST  ERC CORRELATION  ERC VARIANCE   ERC SUM AVERAGE  \
# 0       245.139997         0.385395     209.332939        41.129640
# 1       221.932844         0.406722     197.689209        42.149774
# 2       283.711655         0.336695     217.002950        41.289080
# 3       231.188679         0.498026     232.827358        33.062621
# 4       245.120671         0.458936     233.016858        44.574015
# ...            ...              ...            ...              ...
# 1349    281.150000         0.370000     222.730000        27.940000
# 1350    224.780000         0.470000     205.490000        27.360000
# 1351    220.410000         0.480000     214.970000        27.160000
# 1352    217.380000         0.510000     220.550000        32.540000
# 1353    287.610000         0.390000     233.070000        29.950000
#
#       ERC SUM VARIANCE  ERC ENTROPY  ERC CLUSTER SHADE  \
# 0           592.191757     3.234648       18110.527190
# 1           568.823992     3.240436       23801.869010
# 2           584.300146     3.069283       17579.374770
# 3           700.120751     3.093719        4888.606116
# 4           686.946759     3.149858       22134.931110
# ...                ...          ...                ...
# 1349        609.750000     2.840000       -1924.490000
# 1350        597.200000     2.770000        1146.390000
# 1351        639.470000     2.790000        -919.840000
# 1352        664.840000     3.090000        5289.890000
# 1353        644.680000     2.950000        -467.360000
#
#       ERCs_thicknessbaseline  ERCsVolumebaseline  TOTAL_HIPPOCAMPUS_VOLUME
# 0                      6.948              2826.0                    6861.9
# 1                      7.090              3792.0                    7378.1
# 2                      6.832              2964.0                    7983.5
# 3                      6.523              3184.0                    8525.1
# 4                      8.253              3419.0                    9320.5
# ...                      ...                 ...                       ...
# 1349                   1.940              1112.0                    2705.0
# 1350                   2.440              1526.0                    2913.0
# 1351                   1.990              1215.0                    2273.0
# 1352                   3.270              2321.0                    3739.0
# 1353                   2.450              1819.0                    3631.0
#
# [1354 rows x 23 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1354 entries, 0 to 1353
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Gender                    1354 non-null   int64
#  1   Age                       1354 non-null   float64
#  2   DIAGNOSIS                 1354 non-null   int64
#  3   MMSE                      1341 non-null   float64
#  4   Hip ASM                   1327 non-null   float64
#  5   Hip Contrast              1338 non-null   float64
#  6   Hip Correlation           1332 non-null   float64
#  7   Hip Variance              1344 non-null   float64
#  8   Hip Sum Average           1351 non-null   float64
#  9   Hip Sum Variance          1345 non-null   float64
#  10  Hip Entropy               1329 non-null   float64
#  11  Hip Clusterhade           1334 non-null   float64
#  12  ERC ASM                   1350 non-null   float64
#  13  ERC CONTRAST              1336 non-null   float64
#  14  ERC CORRELATION           1326 non-null   float64
#  15  ERC VARIANCE              1340 non-null   float64
#  16  ERC SUM AVERAGE           1343 non-null   float64
#  17  ERC SUM VARIANCE          1341 non-null   float64
#  18  ERC ENTROPY               1345 non-null   float64
#  19  ERC CLUSTER SHADE         1320 non-null   float64
#  20  ERCs_thicknessbaseline    1317 non-null   float64
#  21  ERCsVolumebaseline        1340 non-null   float64
#  22  TOTAL_HIPPOCAMPUS_VOLUME  1335 non-null   float64
# dtypes: float64(21), int64(2)
# memory usage: 243.4 KB

# %%
# Export to CSV
dataset.to_csv('C:/Users/steve/Desktop/Notebooks/Thesis-Project/datasets/processed/merged_dataset.csv', index=False)
