# %% [markdown]
# ## TPE Tuning

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from dotenv import load_dotenv
import os

from sklearn.pipeline import Pipeline
from feature_engine.selection import DropConstantFeatures, DropDuplicateFeatures, SelectByShuffling

from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from boruta import BorutaPy
from sklearn.experimental import enable_iterative_imputer
from sklearn.model_selection import train_test_split
from sklearn.impute import IterativeImputer
from sklearn.ensemble import ExtraTreesRegressor

from sklearn.tree import DecisionTreeRegressor

import xgboost as xgb
from xgboost import XGBClassifier
from ngboost import NGBClassifier
from ngboost.distns import k_categorical

from sklearn.model_selection import StratifiedKFold, cross_validate, cross_val_score
from sklearn.metrics import accuracy_score, roc_auc_score, recall_score, precision_score, f1_score, balanced_accuracy_score

import optuna

# %%
# Import dataset
load_dotenv()
dataset_path=os.getenv("DATASET_PATH")
dataset = pd.read_csv(dataset_path)
dataset.head()
# Out:
#    RID  Gender  Ageatscreening  Diagnosis  MMSE0m  HipsASMbaseline  \
# 0    3       0         81.3479          3    20.0              NaN
# 1    4       0         67.6904          1    27.0             0.06
# 2    5       0         73.8027          0    29.0             0.10
# 3    8       1         84.5945          0    28.0             0.08
# 4   10       1         73.9726          3    24.0             0.11
#
#    HipsContrastbaseline  HipsCorelationbaseline  HipsVariancebaseline  \
# 0                158.27                    0.63                218.30
# 1                147.64                    0.55                173.64
# 2                199.66                    0.55                222.27
# 3                184.21                    0.53                201.55
# 4                233.02                    0.48                229.88
#
#    HipsSumAveragebaseline  ...  ERCsContrastbaseline  ERCsCorelationbaseline  \
# 0                   28.37  ...                253.10                    0.40
# 1                   44.72  ...                220.88                    0.48
# 2                   41.18  ...                220.37                    0.54
# 3                   43.04  ...                198.42                    0.54
# 4                   39.46  ...                196.55                    0.53
#
#    ERCsVariancebaseline  ERCsSumAveragebaseline  ERCsSumVariancebaseline  \
# 0                208.65                   23.39                   581.50
# 1                215.70                   33.74                   641.90
# 2                232.18                   29.18                   708.36
# 3                220.48                   26.68                   683.50
# 4                210.63                   26.60                   645.95
#
#    ERCsEntropybaseline  ERCsClusterShadebaseline  ERCs_thicknessbaseline  \
# 0                  NaN                  -2568.19                    2.31
# 1                 3.33                   4113.01                    2.76
# 2                 2.87                  -1388.41                    3.18
# 3                 2.77                  -2506.55                    2.68
# 4                 2.72                  -1164.02                    2.64
#
#    ERCsVolumebaseline  HipposcampusVolumebaseline
# 0              1176.0                      3047.0
# 1              1942.0                      3449.0
# 2              2044.0                      3441.0
# 3              1959.0                      2875.0
# 4              1397.0                      2700.0
#
# [5 rows x 24 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    dataset.drop("Diagnosis", axis=1),  
    dataset["Diagnosis"],  
    test_size=0.3,  
    random_state=42,  
)

# %%
imputer_missForest = IterativeImputer(
    estimator=ExtraTreesRegressor(random_state=42),
    random_state=42,
)

imputer_missForest.fit(X_train)
X_train_missForest = imputer_missForest.transform(X_train)
X_test_missForest = imputer_missForest.transform(X_test)
# Out:
# c:\Users\steve\Desktop\Notebooks\Thesis-Project\venv\Lib\site-packages\sklearn\impute\_iterative.py:895: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(

# %%
X_train_missForest_t = pd.DataFrame(
    X_train_missForest, 
    columns=X_train.columns, 
    index=X_train.index  # Critical fix
)
X_test_missForest_t = pd.DataFrame(
    X_test_missForest, 
    columns=X_test.columns, 
    index=X_test.index  # Critical fix
)

# %%
pipe = Pipeline([
    ('constant', DropConstantFeatures(tol=1, variables=None, missing_values='raise')),
    ('quasi-constant', DropConstantFeatures(tol=0.998, variables=None, missing_values='raise')),
    ('duplicated', DropDuplicateFeatures()),
])

pipe.fit(X_train_missForest_t)
# Out:
# Pipeline(steps=[('constant', DropConstantFeatures()),
#                 ('quasi-constant', DropConstantFeatures(tol=0.998)),
#                 ('duplicated', DropDuplicateFeatures())])

# %%
X_train_t = pipe.transform(X_train_missForest_t)
X_test_t = pipe.transform(X_test_missForest_t)

X_train_t.shape, X_test_t.shape
# Out:
# ((425, 23), (183, 23))

# %%
model = RandomForestClassifier(random_state=42,)

# let's initialize Boruta
sel = BorutaPy(
    verbose=2,
    estimator=model,
    n_estimators='auto',
)

sel.fit(X_train_t.values, y_train.values)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	23
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	23
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	23
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	23
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	23
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	23
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	23
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	7
# Tentative: 	7
# Rejected: 	9
# Iteration: 	9 / 100
# Confirmed: 	7
# Tentative: 	7
# Rejected: 	9
# Iteration: 	10 / 100
# Confirmed: 	7
# Tentative: 	7
# Rejected: 	9
# Iteration: 	11 / 100
# Confirmed: 	7
# Tentative: 	7
# Rejected: 	9
# Iteration: 	12 / 100
# Confirmed: 	8
# Tentative: 	4
# Rejected: 	11
# Iteration: 	13 / 100
# Confirmed: 	8
# Tentative: 	4
# Rejected: 	11
# Iteration: 	14 / 100
# Confirmed: 	8
# Tentative: 	4
# Rejected: 	11
# Iteration: 	15 / 100
# Confirmed: 	8
# Tentative: 	4
# Rejected: 	11
# Iteration: 	16 / 100
# Confirmed: 	8
# Tentative: 	4
# Rejected: 	11
# Iteration: 	17 / 100
# Confirmed: 	8
# Tentative: 	4
# Rejected: 	11
# Iteration: 	18 / 100
# Confirmed: 	8
# Tentative: 	4
# Rejected: 	11
# Iteration: 	19 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	20 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	21 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	22 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	23 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	24 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	25 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	26 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	27 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	28 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	29 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	30 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	31 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	32 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	33 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	34 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	35 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	36 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	37 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	38 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	39 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	40 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	41 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	42 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	43 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	44 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	45 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	46 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	47 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	48 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	49 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	50 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	51 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	52 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	53 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	54 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	55 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	56 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	57 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	58 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	59 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	60 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	61 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	62 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	63 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	64 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	65 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	66 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	67 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	68 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	69 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	70 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	71 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	72 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	73 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	74 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	75 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	76 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	77 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	78 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	79 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	80 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	81 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	82 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	83 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	84 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	85 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	86 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	87 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	88 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	89 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	90 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	91 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	92 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	93 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	94 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	95 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	96 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	97 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	98 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	99 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	8
# Tentative: 	1
# Rejected: 	14
# BorutaPy(estimator=RandomForestClassifier(n_estimators=46,
#                                           random_state=RandomState(MT19937) at 0x19A76E4FD40),
#          n_estimators='auto',
#          random_state=RandomState(MT19937) at 0x19A76E4FD40, verbose=2)

# %%
# Store selected feature names before transformation
selected_features = X_train_t.columns[sel.support_]
selected_features
# Out:
# Index(['RID', 'Ageatscreening', 'MMSE0m', 'HipsEntropybaseline',
#        'ERCsContrastbaseline', 'ERCs_thicknessbaseline', 'ERCsVolumebaseline',
#        'HipposcampusVolumebaseline'],
#       dtype='object')

# %%
# Transform training and test sets using selected features
X_train_t = X_train_t[selected_features]
X_test_t = X_test_t[selected_features]

X_train_t.shape, X_test_t.shape
# Out:
# ((425, 8), (183, 8))

# %% [markdown]
# ## TPE

# %%
def objective(trial):
    
    
    skf = StratifiedKFold(n_splits=10,
                             shuffle=True,
                             random_state=42,
        )
        
    rf_n_estimators = trial.suggest_int("rf_n_estimators", 100, 500)
    rf_criterion = trial.suggest_categorical("rf_criterion", ['gini', 'entropy'])
    rf_max_depth = trial.suggest_int("rf_max_depth", 3, 4)
    rf_min_samples_split = trial.suggest_float("rf_min_samples_split", 0.001, 0.2)
    rf_max_features = trial.suggest_categorical("rf_max_features", ["sqrt", "log2"])
    rf_min_samples_leaf = trial.suggest_float("rf_min_samples_leaf", 0.001, 0.1)
    rf_class_weight = trial.suggest_categorical("rf_class_weight", ["balanced", "balanced_subsample"])
        
    model = RandomForestClassifier(n_estimators=rf_n_estimators, 
                                   criterion=rf_criterion,
                                   max_depth=rf_max_depth,
                                   min_samples_split=rf_min_samples_split,
                                   max_features=rf_max_features,
                                   min_samples_leaf=rf_min_samples_leaf,
                                   random_state=42, 
                                   class_weight=rf_class_weight)

    score = cross_val_score(model, X_train_t, y_train, scoring="balanced_accuracy", cv=skf)
    
    accuracy = score.mean()
    
    return accuracy

# %%
study = optuna.create_study(
    direction="maximize",
    sampler=optuna.samplers.TPESampler(),
)

study.optimize(objective, n_trials=20)
# Out:
# [I 2025-03-16 00:24:14,598] A new study created in memory with name: no-name-661e2232-c369-46f7-bb18-a5697c59b8a8
# [I 2025-03-16 00:24:30,049] Trial 0 finished with value: 0.5481990231990232 and parameters: {'rf_n_estimators': 419, 'rf_criterion': 'entropy', 'rf_max_depth': 4, 'rf_min_samples_split': 0.19631812044319888, 'rf_max_features': 'log2', 'rf_min_samples_leaf': 0.08358682146831943, 'rf_class_weight': 'balanced_subsample'}. Best is trial 0 with value: 0.5481990231990232.
# [I 2025-03-16 00:24:42,246] Trial 1 finished with value: 0.5445299145299145 and parameters: {'rf_n_estimators': 412, 'rf_criterion': 'gini', 'rf_max_depth': 4, 'rf_min_samples_split': 0.12592016451533375, 'rf_max_features': 'sqrt', 'rf_min_samples_leaf': 0.09423095320086437, 'rf_class_weight': 'balanced'}. Best is trial 0 with value: 0.5481990231990232.
# [I 2025-03-16 00:24:53,140] Trial 2 finished with value: 0.5303632478632478 and parameters: {'rf_n_estimators': 302, 'rf_criterion': 'entropy', 'rf_max_depth': 3, 'rf_min_samples_split': 0.11114869032878039, 'rf_max_features': 'sqrt', 'rf_min_samples_leaf': 0.07165740886839461, 'rf_class_weight': 'balanced'}. Best is trial 0 with value: 0.5481990231990232.
# [I 2025-03-16 00:25:10,530] Trial 3 finished with value: 0.5571978021978021 and parameters: {'rf_n_estimators': 475, 'rf_criterion': 'gini', 'rf_max_depth': 4, 'rf_min_samples_split': 0.07836530513848823, 'rf_max_features': 'log2', 'rf_min_samples_leaf': 0.0108243886895814, 'rf_class_weight': 'balanced_subsample'}. Best is trial 3 with value: 0.5571978021978021.
# [I 2025-03-16 00:25:18,565] Trial 4 finished with value: 0.5427045177045177 and parameters: {'rf_n_estimators': 227, 'rf_criterion': 'entropy', 'rf_max_depth': 4, 'rf_min_samples_split': 0.11136249769906081, 'rf_max_features': 'log2', 'rf_min_samples_leaf': 0.07700637259943997, 'rf_class_weight': 'balanced'}. Best is trial 3 with value: 0.5571978021978021.
# [I 2025-03-16 00:25:35,895] Trial 5 finished with value: 0.5659920634920634 and parameters: {'rf_n_estimators': 361, 'rf_criterion': 'gini', 'rf_max_depth': 3, 'rf_min_samples_split': 0.04074104956371625, 'rf_max_features': 'sqrt', 'rf_min_samples_leaf': 0.06894623366824346, 'rf_class_weight': 'balanced_subsample'}. Best is trial 5 with value: 0.5659920634920634.
# [I 2025-03-16 00:25:41,172] Trial 6 finished with value: 0.5634401709401707 and parameters: {'rf_n_estimators': 158, 'rf_criterion': 'gini', 'rf_max_depth': 3, 'rf_min_samples_split': 0.006021778916298782, 'rf_max_features': 'sqrt', 'rf_min_samples_leaf': 0.08671560341584565, 'rf_class_weight': 'balanced'}. Best is trial 5 with value: 0.5659920634920634.
# [I 2025-03-16 00:26:00,186] Trial 7 finished with value: 0.5443498168498169 and parameters: {'rf_n_estimators': 497, 'rf_criterion': 'entropy', 'rf_max_depth': 3, 'rf_min_samples_split': 0.08146352764025676, 'rf_max_features': 'log2', 'rf_min_samples_leaf': 0.05476913289655949, 'rf_class_weight': 'balanced'}. Best is trial 5 with value: 0.5659920634920634.
# [I 2025-03-16 00:26:06,313] Trial 8 finished with value: 0.5479029304029304 and parameters: {'rf_n_estimators': 160, 'rf_criterion': 'gini', 'rf_max_depth': 3, 'rf_min_samples_split': 0.06497071605954727, 'rf_max_features': 'sqrt', 'rf_min_samples_leaf': 0.09976287800962576, 'rf_class_weight': 'balanced'}. Best is trial 5 with value: 0.5659920634920634.
# [I 2025-03-16 00:26:20,721] Trial 9 finished with value: 0.5524023199023198 and parameters: {'rf_n_estimators': 415, 'rf_criterion': 'gini', 'rf_max_depth': 4, 'rf_min_samples_split': 0.09365004990235946, 'rf_max_features': 'sqrt', 'rf_min_samples_leaf': 0.07252306865248985, 'rf_class_weight': 'balanced_subsample'}. Best is trial 5 with value: 0.5659920634920634.
# [I 2025-03-16 00:26:33,617] Trial 10 finished with value: 0.5632722832722832 and parameters: {'rf_n_estimators': 312, 'rf_criterion': 'gini', 'rf_max_depth': 3, 'rf_min_samples_split': 0.020083041129778198, 'rf_max_features': 'sqrt', 'rf_min_samples_leaf': 0.03271969168381267, 'rf_class_weight': 'balanced_subsample'}. Best is trial 5 with value: 0.5659920634920634.
# [I 2025-03-16 00:26:39,200] Trial 11 finished with value: 0.5606562881562881 and parameters: {'rf_n_estimators': 132, 'rf_criterion': 'gini', 'rf_max_depth': 3, 'rf_min_samples_split': 0.0010924765925972432, 'rf_max_features': 'sqrt', 'rf_min_samples_leaf': 0.05315826415883347, 'rf_class_weight': 'balanced_subsample'}. Best is trial 5 with value: 0.5659920634920634.
# [I 2025-03-16 00:26:48,782] Trial 12 finished with value: 0.5588095238095236 and parameters: {'rf_n_estimators': 217, 'rf_criterion': 'gini', 'rf_max_depth': 3, 'rf_min_samples_split': 0.03102996612567817, 'rf_max_features': 'sqrt', 'rf_min_samples_leaf': 0.061774281152170145, 'rf_class_weight': 'balanced_subsample'}. Best is trial 5 with value: 0.5659920634920634.
# [I 2025-03-16 00:26:59,379] Trial 13 finished with value: 0.564545177045177 and parameters: {'rf_n_estimators': 347, 'rf_criterion': 'gini', 'rf_max_depth': 3, 'rf_min_samples_split': 0.03634249798546263, 'rf_max_features': 'sqrt', 'rf_min_samples_leaf': 0.034171389026481154, 'rf_class_weight': 'balanced'}. Best is trial 5 with value: 0.5659920634920634.
# [I 2025-03-16 00:27:10,639] Trial 14 finished with value: 0.5635531135531135 and parameters: {'rf_n_estimators': 355, 'rf_criterion': 'gini', 'rf_max_depth': 3, 'rf_min_samples_split': 0.047328103923660075, 'rf_max_features': 'sqrt', 'rf_min_samples_leaf': 0.03439652240969325, 'rf_class_weight': 'balanced'}. Best is trial 5 with value: 0.5659920634920634.
# [I 2025-03-16 00:27:24,770] Trial 15 finished with value: 0.5632539682539682 and parameters: {'rf_n_estimators': 362, 'rf_criterion': 'gini', 'rf_max_depth': 3, 'rf_min_samples_split': 0.14462508136955632, 'rf_max_features': 'sqrt', 'rf_min_samples_leaf': 0.03603570107967126, 'rf_class_weight': 'balanced_subsample'}. Best is trial 5 with value: 0.5659920634920634.
# [I 2025-03-16 00:27:36,272] Trial 16 finished with value: 0.5599206349206349 and parameters: {'rf_n_estimators': 251, 'rf_criterion': 'gini', 'rf_max_depth': 3, 'rf_min_samples_split': 0.051310884131143174, 'rf_max_features': 'sqrt', 'rf_min_samples_leaf': 0.008365372854255218, 'rf_class_weight': 'balanced_subsample'}. Best is trial 5 with value: 0.5659920634920634.
# [I 2025-03-16 00:27:46,965] Trial 17 finished with value: 0.5654945054945054 and parameters: {'rf_n_estimators': 358, 'rf_criterion': 'gini', 'rf_max_depth': 3, 'rf_min_samples_split': 0.03636610165440044, 'rf_max_features': 'sqrt', 'rf_min_samples_leaf': 0.021929694482869484, 'rf_class_weight': 'balanced'}. Best is trial 5 with value: 0.5659920634920634.
# [I 2025-03-16 00:27:57,656] Trial 18 finished with value: 0.5364896214896214 and parameters: {'rf_n_estimators': 268, 'rf_criterion': 'entropy', 'rf_max_depth': 3, 'rf_min_samples_split': 0.06185601267713879, 'rf_max_features': 'log2', 'rf_min_samples_leaf': 0.02413691551390464, 'rf_class_weight': 'balanced'}. Best is trial 5 with value: 0.5659920634920634.
# [I 2025-03-16 00:28:14,642] Trial 19 finished with value: 0.5653571428571428 and parameters: {'rf_n_estimators': 451, 'rf_criterion': 'gini', 'rf_max_depth': 3, 'rf_min_samples_split': 0.15861431473211224, 'rf_max_features': 'sqrt', 'rf_min_samples_leaf': 0.0015430900638642234, 'rf_class_weight': 'balanced_subsample'}. Best is trial 5 with value: 0.5659920634920634.

# %%
study.best_params
# Out:
# {'rf_n_estimators': 361,
#  'rf_criterion': 'gini',
#  'rf_max_depth': 3,
#  'rf_min_samples_split': 0.04074104956371625,
#  'rf_max_features': 'sqrt',
#  'rf_min_samples_leaf': 0.06894623366824346,
#  'rf_class_weight': 'balanced_subsample'}

# %%
study.best_value
# Out:
# 0.5659920634920634

# %%
r = study.trials_dataframe()
r.head()
# Out:
#    number     value             datetime_start          datetime_complete  \
# 0       0  0.548199 2025-03-16 00:24:14.601242 2025-03-16 00:24:30.048419
# 1       1  0.544530 2025-03-16 00:24:30.050538 2025-03-16 00:24:42.245096
# 2       2  0.530363 2025-03-16 00:24:42.247095 2025-03-16 00:24:53.139963
# 3       3  0.557198 2025-03-16 00:24:53.142047 2025-03-16 00:25:10.530809
# 4       4  0.542705 2025-03-16 00:25:10.531826 2025-03-16 00:25:18.564188
#
#                 duration params_rf_class_weight params_rf_criterion  \
# 0 0 days 00:00:15.447177     balanced_subsample             entropy
# 1 0 days 00:00:12.194558               balanced                gini
# 2 0 days 00:00:10.892868               balanced             entropy
# 3 0 days 00:00:17.388762     balanced_subsample                gini
# 4 0 days 00:00:08.032362               balanced             entropy
#
#    params_rf_max_depth params_rf_max_features  params_rf_min_samples_leaf  \
# 0                    4                   log2                    0.083587
# 1                    4                   sqrt                    0.094231
# 2                    3                   sqrt                    0.071657
# 3                    4                   log2                    0.010824
# 4                    4                   log2                    0.077006
#
#    params_rf_min_samples_split  params_rf_n_estimators     state
# 0                     0.196318                     419  COMPLETE
# 1                     0.125920                     412  COMPLETE
# 2                     0.111149                     302  COMPLETE
# 3                     0.078365                     475  COMPLETE
# 4                     0.111362                     227  COMPLETE

# %%
fig = optuna.visualization.matplotlib.plot_optimization_history(study)
# Out:
# C:\Users\steve\AppData\Local\Temp\ipykernel_5848\2278197192.py:1: ExperimentalWarning: plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.
#   fig = optuna.visualization.matplotlib.plot_optimization_history(study)

# %%
optuna.visualization.matplotlib.plot_param_importances(study)
# Out:
# C:\Users\steve\AppData\Local\Temp\ipykernel_5848\1036994904.py:1: ExperimentalWarning: plot_param_importances is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_param_importances(study)
# <Axes: title={'left': 'Hyperparameter Importances'}, xlabel='Hyperparameter Importance', ylabel='Hyperparameter'>

# %%
optuna.visualization.matplotlib.plot_slice(
    study,
    params=["rf_n_estimators", "rf_criterion", "rf_max_depth", 
            'rf_min_samples_split', 'rf_max_features', 'rf_min_samples_leaf',
            'rf_class_weight'],
)
# Out:
# C:\Users\steve\AppData\Local\Temp\ipykernel_5848\3879122787.py:1: ExperimentalWarning: plot_slice is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_slice(
# array([<Axes: xlabel='rf_class_weight', ylabel='Objective Value'>,
#        <Axes: xlabel='rf_criterion'>, <Axes: xlabel='rf_max_depth'>,
#        <Axes: xlabel='rf_max_features'>,
#        <Axes: xlabel='rf_min_samples_leaf'>,
#        <Axes: xlabel='rf_min_samples_split'>,
#        <Axes: xlabel='rf_n_estimators'>], dtype=object)

# %%
optuna.visualization.matplotlib.plot_edf([study])
# Out:
# C:\Users\steve\AppData\Local\Temp\ipykernel_5848\2601326980.py:1: ExperimentalWarning: plot_edf is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_edf([study])
# <Axes: title={'center': 'Empirical Distribution Function Plot'}, xlabel='Objective Value', ylabel='Cumulative Probability'>

# %% [markdown]
# ## Classification

# %%
def run_model(classifier_name, sel_method, X_train, y_train):
        
        model = RandomForestClassifier(n_estimators=study.best_params["rf_n_estimators"], 
                                       criterion=study.best_params["rf_criterion"],
                                       max_depth=study.best_params["rf_max_depth"],
                                       min_samples_split=study.best_params["rf_min_samples_split"],
                                       max_features=study.best_params["rf_max_features"],
                                       min_samples_leaf=study.best_params["rf_min_samples_leaf"],
                                       random_state=42, 
                                       class_weight=study.best_params["rf_class_weight"])
        
        if sel_method == "Boruta":
                sel_method = "Boruta" 
        else: 
                sel_method = "Complete"
        
        skf = StratifiedKFold(n_splits=10,
                             shuffle=True,
                             random_state=42,
        )
        
        cross_val_results = cross_validate(model,
                                           X_train,
                                           y_train,
                                           cv=skf,
                                           scoring="balanced_accuracy",
                                           return_train_score=True,
        )
               
        # Calculate the metrics for training and testing
        mean_train = [round(np.mean(cross_val_results["train_score"]), 3)]
        std_train = [round(np.std(cross_val_results["train_score"]), 3)]
        mean_test = [round(np.mean(cross_val_results["test_score"]), 3)]
        std_test = [round(np.std(cross_val_results["test_score"]), 3)]
        time = round(np.mean(cross_val_results["fit_time"]), 3)
                
        cv_metrics_df = pd.DataFrame({
                "Feature Selection": sel_method,
                "Classifier": classifier_name,
                "Fit Time": time,
                "Total Features": len(X_train.columns),
                "Metric": "balanced_accuracy",
                "Mean Train": mean_train,
                "Std Train": std_train,
                "Mean Test": mean_test,
                "Std Test": std_test,
        })
        
        fit_model = model.fit(X_train, y_train)
        
        return fit_model, cv_metrics_df

# %%
trained_rf_n, metrics_rf_n = run_model("Random Forest", "Complete", X_train_missForest_t, y_train)
trained_rf_t, metrics_rf_t = run_model("Random Forest", "Boruta", X_train_t, y_train)

# %%
import time

def eval_model(classifier_name, model, X_train, X_test, y_train, y_test):
        
        start_time = time.time()
        # Get predicted probabilities for ROC AUC
        pred_train_proba = model.predict_proba(X_train)
        pred_test_proba = model.predict_proba(X_test)
        
        # Get predicted accuracy values
        pred_train = model.predict(X_train)
        pred_test = model.predict(X_test)
        
        # Calculate metrics
        metrics_train = {
                "accuracy": round(accuracy_score(y_train, pred_train), 3),
                "balanced_accuracy": round(balanced_accuracy_score(y_train, pred_train), 3),
                "precision": round(precision_score(y_train, pred_train, average="weighted"), 3),
                "recall": round(recall_score(y_train, pred_train, average="weighted"), 3),
                "f1_weighted": round(f1_score(y_train, pred_train, average="weighted"), 3),
                "roc_auc_ovr_weighted": round(roc_auc_score(y_train, pred_train_proba, average="weighted", multi_class="ovr"),3,),
        }
        
        metrics_test = {
                "accuracy": round(accuracy_score(y_test, pred_test), 3),
                "balanced_accuracy": round(balanced_accuracy_score(y_test, pred_test), 3),
                "precision": round(precision_score(y_test, pred_test, average="weighted"), 3),
                "recall": round(recall_score(y_test, pred_test, average="weighted"), 3),
                "f1_weighted": round(f1_score(y_test, pred_test, average="weighted"), 3),
                "roc_auc_ovr_weighted": round(roc_auc_score(y_test, pred_test_proba, average="weighted", multi_class="ovr"),3,),
        }
                
        elapsed_time = time.time() - start_time
    
        # Create the DataFrame without additional rounding
        pred_metrics_df = pd.DataFrame({
                "Feature Selection": "Boruta",
                "Classifier": classifier_name,
                "Classification Time": round(elapsed_time, 3),
                "Total Features": len(X_train.columns),
                "Metric": metrics_train.keys(),
                "Train data": metrics_train.values(),
                "Test data": metrics_test.values(),
    })
        
        return pred_metrics_df

# %%
results = "all"
prediction_df_report = None

if results == "all":
    
    pred_rf_n = eval_model("Random Forest", trained_rf_n, X_train_missForest_t, X_test_missForest_t, y_train, y_test)
    pred_rf_t = eval_model("Random Forest", trained_rf_t, X_train_t, X_test_t, y_train, y_test)
    
    prediction_df = pd.concat([pred_rf_n, pred_rf_t])
    prediction_df_report = prediction_df.set_index(["Feature Selection", "Classifier", "Classification Time", "Total Features", "Metric"])
        
elif results == "filtered":
    
    pred_rf_t = eval_model("Random Forest", trained_rf_t, X_train_t, X_test_t, y_train, y_test)
  
    prediction_df = pd.concat([pred_rf_t])
    prediction_df_report = prediction_df.set_index(["Feature Selection", "Classifier", "Classification Time", "Total Features", "Metric"])

prediction_df_report
# Out:
#                                                                                          Train data  \
# Feature Selection Classifier    Classification Time Total Features Metric
# Boruta            Random Forest 0.690               23             accuracy                   0.706
#                                                                    balanced_accuracy          0.690
#                                                                    precision                  0.710
#                                                                    recall                     0.706
#                                                                    f1_weighted                0.684
#                                                                    roc_auc_ovr_weighted       0.871
#                                 0.617               8              accuracy                   0.675
#                                                                    balanced_accuracy          0.666
#                                                                    precision                  0.683
#                                                                    recall                     0.675
#                                                                    f1_weighted                0.652
#                                                                    roc_auc_ovr_weighted       0.870
#
#                                                                                          Test data
# Feature Selection Classifier    Classification Time Total Features Metric
# Boruta            Random Forest 0.690               23             accuracy                  0.514
#                                                                    balanced_accuracy         0.523
#                                                                    precision                 0.509
#                                                                    recall                    0.514
#                                                                    f1_weighted               0.492
#                                                                    roc_auc_ovr_weighted      0.777
#                                 0.617               8              accuracy                  0.519
#                                                                    balanced_accuracy         0.532
#                                                                    precision                 0.514
#                                                                    recall                    0.519
#                                                                    f1_weighted               0.501
#                                                                    roc_auc_ovr_weighted      0.802

# %% [markdown]
# ### Export model

# %%
trained_rf_t
# Out:
# RandomForestClassifier(class_weight='balanced_subsample', max_depth=3,
#                        min_samples_leaf=0.06894623366824346,
#                        min_samples_split=0.04074104956371625, n_estimators=361,
#                        random_state=42)

# %%
import pickle

with open("rf_model.pkl", "wb") as file:
    pickle.dump(trained_rf_t, file)
    
print("Random Forest model saved successfully!")
# Out:
# Random Forest model saved successfully!
