# %% [markdown]
# ## TPE Tuning

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from dotenv import load_dotenv
import os

from sklearn.pipeline import Pipeline
from feature_engine.selection import DropConstantFeatures, DropDuplicateFeatures, SelectByShuffling

from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from boruta import BorutaPy
from sklearn.experimental import enable_iterative_imputer
from sklearn.model_selection import train_test_split
from sklearn.impute import IterativeImputer
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import BayesianRidge

from sklearn.tree import DecisionTreeRegressor

import xgboost as xgb
from xgboost import XGBClassifier
from ngboost import NGBClassifier
from ngboost.distns import k_categorical

from sklearn.model_selection import StratifiedKFold, cross_validate, cross_val_score
from sklearn.metrics import accuracy_score, roc_auc_score, recall_score, precision_score, f1_score, balanced_accuracy_score

import optuna

# %%
# Import dataset
load_dotenv()
dataset_path=os.getenv("DATASET_PATH_TWO_P")
dataset = pd.read_csv(dataset_path)
dataset.head()
# Out:
#    Gender        Age  DIAGNOSIS  MMSE   Hip ASM  Hip Contrast  \
# 0       0  64.585900          0  27.0  0.377501    128.715226
# 1       0  68.076660          2  20.0  0.657212     51.830551
# 2       1  76.221760          1  28.0  0.520032     86.558742
# 3       0  73.221085          0  30.0  0.396133     60.731686
# 4       0  45.872690          0  30.0  0.404800    108.808540
#
#    Hip Correlation  Hip Variance   Hip Sum Average  Hip Sum Variance  ...  \
# 0         0.422342     115.630163        15.181458        333.805425  ...
# 1         0.557254      84.225204         8.530596        285.070266  ...
# 2         0.594543     123.662642        13.400504        408.091827  ...
# 3         0.596733     122.546512        15.571183        429.454361  ...
# 4         0.520363      98.065558        13.483247        283.453692  ...
#
#    ERC CONTRAST  ERC CORRELATION  ERC VARIANCE   ERC SUM AVERAGE  \
# 0    286.270009         0.289728     206.373786        44.577974
# 1    282.873623         0.310507     206.276556        39.697933
# 2    244.274039         0.370189     201.216707        46.081559
# 3    226.713342         0.517430     232.983710        30.461877
# 4    202.074647         0.354851     169.528802        50.680275
#
#    ERC SUM VARIANCE  ERC ENTROPY  ERC CLUSTER SHADE  ERCs_thicknessbaseline  \
# 0        539.225137     3.320292       22924.739100                  3.3445
# 1        542.232602     2.864138       18182.687670                  2.9605
# 2        560.592790     3.415186       28045.350990                  3.3145
# 3        705.221498     2.937422        1196.160472                  3.1505
# 4        476.040561     3.017047       47743.254120                  3.5420
#
#    ERCsVolumebaseline  TOTAL_HIPPOCAMPUS_VOLUME
# 0                2251                    7338.2
# 1                2924                    5438.6
# 2                4042                    8434.4
# 3                3485                    7476.2
# 4                3964                    8021.8
#
# [5 rows x 23 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    dataset.drop("DIAGNOSIS", axis=1),  
    dataset["DIAGNOSIS"],  
    test_size=0.3,  
    random_state=42,  
)

X_train.shape, X_test.shape
# Out:
# ((508, 22), (219, 22))

# %%
imputer_knn = IterativeImputer(
    estimator=BayesianRidge(),
    random_state=42,
)

imputer_knn.fit(X_train)
X_train_knn = imputer_knn.transform(X_train)
X_test_knn = imputer_knn.transform(X_test)

# %%
X_train_knn_t = pd.DataFrame(
    X_train_knn, 
    columns=X_train.columns, 
    index=X_train.index  # Critical fix
)
X_test_knn_t = pd.DataFrame(
    X_test_knn, 
    columns=X_test.columns, 
    index=X_test.index  # Critical fix
)

# %%
pipe = Pipeline([
    ('constant', DropConstantFeatures(tol=1, variables=None, missing_values='raise')),
    ('quasi-constant', DropConstantFeatures(tol=0.998, variables=None, missing_values='raise')),
    ('duplicated', DropDuplicateFeatures()),
])

pipe.fit(X_train_knn_t)
# Out:
# Pipeline(steps=[('constant', DropConstantFeatures()),
#                 ('quasi-constant', DropConstantFeatures(tol=0.998)),
#                 ('duplicated', DropDuplicateFeatures())])

# %%
X_train_t = pipe.transform(X_train_knn_t)
X_test_t = pipe.transform(X_test_knn_t)

X_train_t.shape, X_test_t.shape
# Out:
# ((508, 22), (219, 22))

# %%
sel = ['Gender', 'Age', 'MMSE', 'Hip ASM', 'Hip Contrast', 'Hip Correlation',
       'Hip Variance ', 'Hip Sum Average', 'Hip Sum Variance', 'Hip Entropy',
       'Hip Clusterhade', 'ERC ASM', 'ERC CONTRAST', 'ERC CORRELATION',
       'ERC VARIANCE ', 'ERC SUM VARIANCE', 'ERC ENTROPY', 'ERC CLUSTER SHADE',
       'ERCs_thicknessbaseline', 'ERCsVolumebaseline',
       'TOTAL_HIPPOCAMPUS_VOLUME']

# %%
selected_features = [col for col in sel if col in X_train_t.columns]
selected_features
# Out:
# ['Gender',
#  'Age',
#  'MMSE',
#  'Hip ASM',
#  'Hip Contrast',
#  'Hip Correlation',
#  'Hip Variance ',
#  'Hip Sum Average',
#  'Hip Sum Variance',
#  'Hip Entropy',
#  'Hip Clusterhade',
#  'ERC ASM',
#  'ERC CONTRAST',
#  'ERC CORRELATION',
#  'ERC VARIANCE ',
#  'ERC SUM VARIANCE',
#  'ERC ENTROPY',
#  'ERC CLUSTER SHADE',
#  'ERCs_thicknessbaseline',
#  'ERCsVolumebaseline',
#  'TOTAL_HIPPOCAMPUS_VOLUME']

# %%
# Transform training and test sets using selected features
X_train_t = X_train_t[selected_features]
X_test_t = X_test_t[selected_features]

X_train_t.shape, X_test_t.shape
# Out:
# ((508, 21), (219, 21))

# %% [markdown]
# ## TPE

# %%
def objective(trial):
        
    skf = StratifiedKFold(n_splits=10,
                             shuffle=True,
                             random_state=42,
        )
            
    xgb_n_estimators = trial.suggest_int("xgb_n_estimators", 100, 500)
    xgb_max_depth = trial.suggest_int("xgb_max_depth", 2, 5)
    xgb_learning_rate = trial.suggest_float("xgb_learning_rate", 0.01, 0.2)
    xgb_subsample = trial.suggest_float("xgb_subsample", 0.5, 1.0)
    xgb_colsample_bytree = trial.suggest_float("xgb_colsample_bytree", 0.6, 1.0)
    xgb_min_child_weight = trial.suggest_int("xgb_min_child_weight", 1, 6)
    xgb_gamma = trial.suggest_float("xgb_gamma", 0.0, 2.0)

    model = XGBClassifier(
        n_estimators=xgb_n_estimators,
        max_depth=xgb_max_depth,
        learning_rate=xgb_learning_rate,
        subsample=xgb_subsample,
        colsample_bytree=xgb_colsample_bytree,
        min_child_weight=xgb_min_child_weight,
        gamma=xgb_gamma,
        objective="multi:softprob",
        num_class=len(set(y_train))
    )

    score = cross_val_score(model, X_train_t, y_train, scoring="balanced_accuracy", cv=skf)
    
    accuracy = score.mean()
    
    return accuracy

# %%
study = optuna.create_study(
    direction="maximize",
    sampler=optuna.samplers.TPESampler(),
)

study.optimize(objective, n_trials=20)
# Out:
# [I 2025-08-04 21:46:11,490] A new study created in memory with name: no-name-934a1e0a-57b3-4125-9e9b-67ee72b7eb34
# [I 2025-08-04 21:46:41,655] Trial 0 finished with value: 0.5556835064729801 and parameters: {'xgb_n_estimators': 307, 'xgb_max_depth': 5, 'xgb_learning_rate': 0.12003587228576781, 'xgb_subsample': 0.5763935273503815, 'xgb_colsample_bytree': 0.8805391802182789, 'xgb_min_child_weight': 3, 'xgb_gamma': 1.858793925434792}. Best is trial 0 with value: 0.5556835064729801.
# [I 2025-08-04 21:47:15,121] Trial 1 finished with value: 0.5395396353291091 and parameters: {'xgb_n_estimators': 456, 'xgb_max_depth': 2, 'xgb_learning_rate': 0.036833731519174726, 'xgb_subsample': 0.577339556996504, 'xgb_colsample_bytree': 0.8833919852041843, 'xgb_min_child_weight': 4, 'xgb_gamma': 1.987950756706978}. Best is trial 0 with value: 0.5556835064729801.
# [I 2025-08-04 21:47:35,063] Trial 2 finished with value: 0.556016207595155 and parameters: {'xgb_n_estimators': 428, 'xgb_max_depth': 2, 'xgb_learning_rate': 0.0689669922018639, 'xgb_subsample': 0.6857469578869926, 'xgb_colsample_bytree': 0.6475394202040509, 'xgb_min_child_weight': 4, 'xgb_gamma': 0.5861715172810738}. Best is trial 2 with value: 0.556016207595155.
# [I 2025-08-04 21:47:44,117] Trial 3 finished with value: 0.5344372602267339 and parameters: {'xgb_n_estimators': 174, 'xgb_max_depth': 4, 'xgb_learning_rate': 0.12949917225199026, 'xgb_subsample': 0.5971081968877398, 'xgb_colsample_bytree': 0.7927051911134697, 'xgb_min_child_weight': 5, 'xgb_gamma': 1.83931006346236}. Best is trial 2 with value: 0.556016207595155.
# [I 2025-08-04 21:48:04,024] Trial 4 finished with value: 0.5430014224751067 and parameters: {'xgb_n_estimators': 397, 'xgb_max_depth': 2, 'xgb_learning_rate': 0.09064271254622006, 'xgb_subsample': 0.728370645292321, 'xgb_colsample_bytree': 0.8421569956454208, 'xgb_min_child_weight': 1, 'xgb_gamma': 0.8043140950832772}. Best is trial 2 with value: 0.556016207595155.
# [I 2025-08-04 21:48:10,018] Trial 5 finished with value: 0.5310465968360706 and parameters: {'xgb_n_estimators': 104, 'xgb_max_depth': 2, 'xgb_learning_rate': 0.03139938512802553, 'xgb_subsample': 0.5582302276723501, 'xgb_colsample_bytree': 0.8027375384972437, 'xgb_min_child_weight': 6, 'xgb_gamma': 0.3916574990841737}. Best is trial 2 with value: 0.556016207595155.
# [I 2025-08-04 21:48:29,195] Trial 6 finished with value: 0.5405452821242296 and parameters: {'xgb_n_estimators': 457, 'xgb_max_depth': 4, 'xgb_learning_rate': 0.1338887368763239, 'xgb_subsample': 0.6299228027555289, 'xgb_colsample_bytree': 0.7815677844255159, 'xgb_min_child_weight': 6, 'xgb_gamma': 1.825966307155365}. Best is trial 2 with value: 0.556016207595155.
# [I 2025-08-04 21:48:43,565] Trial 7 finished with value: 0.5389417647312384 and parameters: {'xgb_n_estimators': 382, 'xgb_max_depth': 5, 'xgb_learning_rate': 0.11361509009254041, 'xgb_subsample': 0.8583253052541663, 'xgb_colsample_bytree': 0.7120208805627425, 'xgb_min_child_weight': 6, 'xgb_gamma': 1.4721635160677546}. Best is trial 2 with value: 0.556016207595155.
# [I 2025-08-04 21:48:57,211] Trial 8 finished with value: 0.54047329626277 and parameters: {'xgb_n_estimators': 311, 'xgb_max_depth': 3, 'xgb_learning_rate': 0.0322841511015423, 'xgb_subsample': 0.6618835791741517, 'xgb_colsample_bytree': 0.8659857508991381, 'xgb_min_child_weight': 3, 'xgb_gamma': 1.5959036042056183}. Best is trial 2 with value: 0.556016207595155.
# [I 2025-08-04 21:49:10,704] Trial 9 finished with value: 0.5578180093969568 and parameters: {'xgb_n_estimators': 495, 'xgb_max_depth': 5, 'xgb_learning_rate': 0.12516873210972193, 'xgb_subsample': 0.7293408105987877, 'xgb_colsample_bytree': 0.959741519604856, 'xgb_min_child_weight': 3, 'xgb_gamma': 0.3539507379036535}. Best is trial 9 with value: 0.5578180093969568.
# [I 2025-08-04 21:49:21,436] Trial 10 finished with value: 0.5342381137117981 and parameters: {'xgb_n_estimators': 238, 'xgb_max_depth': 5, 'xgb_learning_rate': 0.1900429473301481, 'xgb_subsample': 0.9878723375429133, 'xgb_colsample_bytree': 0.9890515430166452, 'xgb_min_child_weight': 1, 'xgb_gamma': 0.024860553614721836}. Best is trial 9 with value: 0.5578180093969568.
# [I 2025-08-04 21:49:33,687] Trial 11 finished with value: 0.550082546661494 and parameters: {'xgb_n_estimators': 495, 'xgb_max_depth': 3, 'xgb_learning_rate': 0.07629297350976809, 'xgb_subsample': 0.7972578643010566, 'xgb_colsample_bytree': 0.6098546364593754, 'xgb_min_child_weight': 4, 'xgb_gamma': 0.7079887307062108}. Best is trial 9 with value: 0.5578180093969568.
# [I 2025-08-04 21:49:43,675] Trial 12 finished with value: 0.5440939264623477 and parameters: {'xgb_n_estimators': 402, 'xgb_max_depth': 3, 'xgb_learning_rate': 0.1658766946847626, 'xgb_subsample': 0.7262567733987013, 'xgb_colsample_bytree': 0.9982373813873688, 'xgb_min_child_weight': 2, 'xgb_gamma': 0.37733670783904916}. Best is trial 9 with value: 0.5578180093969568.
# [I 2025-08-04 21:49:55,268] Trial 13 finished with value: 0.5444282081124187 and parameters: {'xgb_n_estimators': 500, 'xgb_max_depth': 4, 'xgb_learning_rate': 0.06352409416354239, 'xgb_subsample': 0.8569535327285186, 'xgb_colsample_bytree': 0.6070007924156339, 'xgb_min_child_weight': 2, 'xgb_gamma': 1.1785689076041859}. Best is trial 9 with value: 0.5578180093969568.
# [I 2025-08-04 21:50:06,396] Trial 14 finished with value: 0.544373248846933 and parameters: {'xgb_n_estimators': 340, 'xgb_max_depth': 3, 'xgb_learning_rate': 0.06104360906276887, 'xgb_subsample': 0.6810692832198683, 'xgb_colsample_bytree': 0.6855746228652104, 'xgb_min_child_weight': 4, 'xgb_gamma': 0.3994565516890417}. Best is trial 9 with value: 0.5578180093969568.
# [I 2025-08-04 21:50:39,471] Trial 15 finished with value: 0.5411632685316896 and parameters: {'xgb_n_estimators': 444, 'xgb_max_depth': 4, 'xgb_learning_rate': 0.14221541859766745, 'xgb_subsample': 0.5055425906538733, 'xgb_colsample_bytree': 0.9362649124670543, 'xgb_min_child_weight': 5, 'xgb_gamma': 0.03331491107929585}. Best is trial 9 with value: 0.5578180093969568.
# [I 2025-08-04 21:50:57,223] Trial 16 finished with value: 0.5428180093969568 and parameters: {'xgb_n_estimators': 234, 'xgb_max_depth': 2, 'xgb_learning_rate': 0.09229436991950551, 'xgb_subsample': 0.7921403736807955, 'xgb_colsample_bytree': 0.7077145694097983, 'xgb_min_child_weight': 3, 'xgb_gamma': 0.660471913582463}. Best is trial 9 with value: 0.5578180093969568.
# [I 2025-08-04 21:51:38,707] Trial 17 finished with value: 0.544731238415449 and parameters: {'xgb_n_estimators': 351, 'xgb_max_depth': 5, 'xgb_learning_rate': 0.16352197874751867, 'xgb_subsample': 0.9287209315930263, 'xgb_colsample_bytree': 0.6521771297244155, 'xgb_min_child_weight': 2, 'xgb_gamma': 1.006961016223618}. Best is trial 9 with value: 0.5578180093969568.
# [I 2025-08-04 21:51:58,977] Trial 18 finished with value: 0.5533795278532121 and parameters: {'xgb_n_estimators': 425, 'xgb_max_depth': 4, 'xgb_learning_rate': 0.09929483053110921, 'xgb_subsample': 0.778837269537038, 'xgb_colsample_bytree': 0.7476642505077831, 'xgb_min_child_weight': 5, 'xgb_gamma': 0.2629697056199476}. Best is trial 9 with value: 0.5578180093969568.
# [I 2025-08-04 21:52:30,060] Trial 19 finished with value: 0.5426026983921721 and parameters: {'xgb_n_estimators': 480, 'xgb_max_depth': 3, 'xgb_learning_rate': 0.015435588745351517, 'xgb_subsample': 0.7015731779765395, 'xgb_colsample_bytree': 0.9260799078076135, 'xgb_min_child_weight': 3, 'xgb_gamma': 0.5584825979476729}. Best is trial 9 with value: 0.5578180093969568.

# %%
study.best_params
# Out:
# {'xgb_n_estimators': 495,
#  'xgb_max_depth': 5,
#  'xgb_learning_rate': 0.12516873210972193,
#  'xgb_subsample': 0.7293408105987877,
#  'xgb_colsample_bytree': 0.959741519604856,
#  'xgb_min_child_weight': 3,
#  'xgb_gamma': 0.3539507379036535}

# %%
study.best_value
# Out:
# 0.5578180093969568

# %%
r = study.trials_dataframe()
r.head()
# Out:
#    number     value             datetime_start          datetime_complete  \
# 0       0  0.555684 2025-08-04 21:46:11.524414 2025-08-04 21:46:41.652380
# 1       1  0.539540 2025-08-04 21:46:41.664617 2025-08-04 21:47:15.121069
# 2       2  0.556016 2025-08-04 21:47:15.123169 2025-08-04 21:47:35.059456
# 3       3  0.534437 2025-08-04 21:47:35.065585 2025-08-04 21:47:44.116802
# 4       4  0.543001 2025-08-04 21:47:44.119804 2025-08-04 21:48:04.024304
#
#                 duration  params_xgb_colsample_bytree  params_xgb_gamma  \
# 0 0 days 00:00:30.127966                     0.880539          1.858794
# 1 0 days 00:00:33.456452                     0.883392          1.987951
# 2 0 days 00:00:19.936287                     0.647539          0.586172
# 3 0 days 00:00:09.051217                     0.792705          1.839310
# 4 0 days 00:00:19.904500                     0.842157          0.804314
#
#    params_xgb_learning_rate  params_xgb_max_depth  \
# 0                  0.120036                     5
# 1                  0.036834                     2
# 2                  0.068967                     2
# 3                  0.129499                     4
# 4                  0.090643                     2
#
#    params_xgb_min_child_weight  params_xgb_n_estimators  params_xgb_subsample  \
# 0                            3                      307              0.576394
# 1                            4                      456              0.577340
# 2                            4                      428              0.685747
# 3                            5                      174              0.597108
# 4                            1                      397              0.728371
#
#       state
# 0  COMPLETE
# 1  COMPLETE
# 2  COMPLETE
# 3  COMPLETE
# 4  COMPLETE

# %%
fig = optuna.visualization.matplotlib.plot_optimization_history(study)
# Out:
# C:\Users\steve\AppData\Local\Temp\ipykernel_19484\2278197192.py:1: ExperimentalWarning: plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.
#   fig = optuna.visualization.matplotlib.plot_optimization_history(study)

# %%
optuna.visualization.matplotlib.plot_param_importances(study)
# Out:
# C:\Users\steve\AppData\Local\Temp\ipykernel_19484\1036994904.py:1: ExperimentalWarning: plot_param_importances is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_param_importances(study)
# <Axes: title={'left': 'Hyperparameter Importances'}, xlabel='Hyperparameter Importance', ylabel='Hyperparameter'>

# %%
optuna.visualization.matplotlib.plot_slice(
    study,
    params=["xgb_n_estimators", "xgb_max_depth", "xgb_learning_rate", 
            'xgb_subsample', 'xgb_colsample_bytree', 'xgb_min_child_weight',
            'xgb_gamma'],
)
# Out:
# C:\Users\steve\AppData\Local\Temp\ipykernel_19484\1403512554.py:1: ExperimentalWarning: plot_slice is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_slice(
# array([<Axes: xlabel='xgb_colsample_bytree', ylabel='Objective Value'>,
#        <Axes: xlabel='xgb_gamma'>, <Axes: xlabel='xgb_learning_rate'>,
#        <Axes: xlabel='xgb_max_depth'>,
#        <Axes: xlabel='xgb_min_child_weight'>,
#        <Axes: xlabel='xgb_n_estimators'>, <Axes: xlabel='xgb_subsample'>],
#       dtype=object)

# %%
optuna.visualization.matplotlib.plot_edf([study])
# Out:
# C:\Users\steve\AppData\Local\Temp\ipykernel_19484\2601326980.py:1: ExperimentalWarning: plot_edf is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_edf([study])
# <Axes: title={'center': 'Empirical Distribution Function Plot'}, xlabel='Objective Value', ylabel='Cumulative Probability'>

# %% [markdown]
# ## Classification

# %%
def run_model(classifier_name, sel_method, X_train, y_train):
        
        model = XGBClassifier(
                n_estimators=study.best_params["xgb_n_estimators"],
                max_depth=study.best_params["xgb_max_depth"],
                learning_rate=study.best_params["xgb_learning_rate"],
                subsample=study.best_params["xgb_subsample"],
                colsample_bytree=study.best_params["xgb_colsample_bytree"],
                min_child_weight=study.best_params["xgb_min_child_weight"],
                gamma=study.best_params["xgb_gamma"],
                objective="multi:softprob",
                num_class=len(set(y_train))
        )

        if sel_method == "Boruta":
                sel_method = "Boruta" 
        else: 
                sel_method = "Complete"
        
        skf = StratifiedKFold(n_splits=10,
                             shuffle=True,
                             random_state=42,
        )
        
        cross_val_results = cross_validate(model,
                                           X_train,
                                           y_train,
                                           cv=skf,
                                           scoring="balanced_accuracy",
                                           return_train_score=True,
        )
               
        # Calculate the metrics for training and testing
        mean_train = [round(np.mean(cross_val_results["train_score"]), 3)]
        std_train = [round(np.std(cross_val_results["train_score"]), 3)]
        mean_test = [round(np.mean(cross_val_results["test_score"]), 3)]
        std_test = [round(np.std(cross_val_results["test_score"]), 3)]
        time = round(np.mean(cross_val_results["fit_time"]), 3)
                
        cv_metrics_df = pd.DataFrame({
                "Feature Selection": sel_method,
                "Classifier": classifier_name,
                "Fit Time": time,
                "Total Features": len(X_train.columns),
                "Metric": "balanced_accuracy",
                "Mean Train": mean_train,
                "Std Train": std_train,
                "Mean Test": mean_test,
                "Std Test": std_test,
        })
        
        fit_model = model.fit(X_train, y_train)
        
        return fit_model, cv_metrics_df

# %%
trained_xgb_n, metrics_xgb_n = run_model("XGBoost", "Complete", X_train_knn_t, y_train)
trained_xgb_t, metrics_xgb_t = run_model("XGBoost", "Boruta", X_train_t, y_train)

# %%
validation_df = pd.concat([metrics_xgb_n, metrics_xgb_t])
validation_df_report = validation_df.set_index(["Classifier", "Metric", "Feature Selection", "Fit Time", "Total Features"])
validation_df_report
# Out:
#                                                                         Mean Train  \
# Classifier Metric            Feature Selection Fit Time Total Features
# XGBoost    balanced_accuracy Complete          1.902    22                     1.0
#                              Boruta            1.663    21                     1.0
#
#                                                                         Std Train  \
# Classifier Metric            Feature Selection Fit Time Total Features
# XGBoost    balanced_accuracy Complete          1.902    22                    0.0
#                              Boruta            1.663    21                    0.0
#
#                                                                         Mean Test  \
# Classifier Metric            Feature Selection Fit Time Total Features
# XGBoost    balanced_accuracy Complete          1.902    22                  0.558
#                              Boruta            1.663    21                  0.558
#
#                                                                         Std Test
# Classifier Metric            Feature Selection Fit Time Total Features
# XGBoost    balanced_accuracy Complete          1.902    22                 0.041
#                              Boruta            1.663    21                 0.042

# %%
from sklearn.utils import resample

def bootstrap_ci(model, X, y, metric_fn, n_iterations, ci=0.95, use_proba=False):
    scores = []
    n = len(X)
    for _ in range(n_iterations):
        X_resampled, y_resampled = resample(X, y, n_samples=n, stratify=y)
        try:
            y_pred = model.predict_proba(X_resampled) if use_proba else model.predict(X_resampled)
            score = metric_fn(y_resampled, y_pred)
            if not np.isnan(score):
                scores.append(score)
        except Exception:
            # Skip this bootstrap sample if error occurs (e.g. missing class for roc_auc)
            continue
    if len(scores) == 0:
        return (np.nan, np.nan)
    lower = np.percentile(scores, (1 - ci) / 2 * 100)
    upper = np.percentile(scores, (1 + ci) / 2 * 100)
    std_dev = np.std(scores)
    return round(lower, 3), round(upper, 3), round(std_dev, 3)

# %%
from sklearn.metrics import confusion_matrix

def compute_specificity(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    total = cm.sum()
    tp = np.diag(cm)
    fp = cm.sum(axis=0) - tp
    fn = cm.sum(axis=1) - tp
    tn = total - (tp + fp + fn)
    specificity = tn / (tn + fp)
    return round(np.nanmean(specificity), 3)

# %%
import time

def eval_model(classifier_name, model, X_train, X_test, y_train, y_test):
        
        if isinstance(X_train, np.ndarray):
                columns = X_train.shape[1]
        else:
                columns = len(X_train.columns)        
        
        start_time = time.time()
        # Get predicted probabilities for ROC AUC
        pred_train_proba = model.predict_proba(X_train)
        pred_test_proba = model.predict_proba(X_test)
        
        # Get predicted accuracy values
        pred_train = model.predict(X_train)
        pred_test = model.predict(X_test)
        
        # Calculate metrics
        # Calculate metrics
        metrics_train = {
                "accuracy": accuracy_score(y_train, pred_train),
                "balanced_accuracy": balanced_accuracy_score(y_train, pred_train),
                "precision_macro": precision_score(y_train, pred_train, average="macro", zero_division=0),
                "recall_macro": recall_score(y_train, pred_train, average="macro", zero_division=0),
                "f1_macro": f1_score(y_train, pred_train, average="macro", zero_division=0),
                "roc_auc_macro": roc_auc_score(y_train, pred_train_proba, average="macro", multi_class="ovr"),
                "specificity_macro": compute_specificity(y_train, pred_train),
        }

        metrics_test = {
                "accuracy": accuracy_score(y_test, pred_test),
                "balanced_accuracy": balanced_accuracy_score(y_test, pred_test),
                "precision_macro": precision_score(y_test, pred_test, average="macro", zero_division=0),
                "recall_macro": recall_score(y_test, pred_test, average="macro", zero_division=0),
                "f1_macro": f1_score(y_test, pred_test, average="macro", zero_division=0),
                "roc_auc_macro": roc_auc_score(y_test, pred_test_proba, average="macro", multi_class="ovr"),
                "specificity_macro": compute_specificity(y_test, pred_test),
        }
                
        elapsed_time = time.time() - start_time
        
        # Metric functions for bootstrap CI (exclude ROC AUC here)
        metric_fns = {
                "accuracy": accuracy_score,
                "balanced_accuracy": balanced_accuracy_score,
                "precision_macro": lambda yt, yp: precision_score(yt, yp, average="macro", zero_division=0),
                "recall_macro": lambda yt, yp: recall_score(yt, yp, average="macro", zero_division=0),
                "f1_macro": lambda yt, yp: f1_score(yt, yp, average="macro", zero_division=0),
                "roc_auc_macro": lambda yt, yp: roc_auc_score(yt, yp, average="macro", multi_class="ovr"),
                "specificity_macro": lambda yt, yp: compute_specificity(yt, yp),
        }

        # Bootstrap confidence intervals
        ci_test = {
                m: bootstrap_ci(
                model, X_test, y_test, fn,
                n_iterations=1000,
                use_proba=(m == "roc_auc_macro")
                )
                for m, fn in metric_fns.items()
        }

        # Separate CI bounds and std with clear variable names
        ci_bounds = []
        std_values = []
                
        for lower, upper, std in ci_test.values():
                ci_bounds.append(f"[{round(lower, 3)}, {round(upper, 3)}]")
                std_values.append(round(std, 3)) 
                
        # Round metric values
        train_rounded = [round(score, 3) for score in metrics_train.values()]
        test_rounded = [round(score, 3) for score in metrics_test.values()] 
    
        # Create the DataFrame without additional rounding
        pred_metrics_df = pd.DataFrame({
                "Feature Selection": "Spearman",
                "Classifier": classifier_name,
                "Classification Time": round(elapsed_time, 3),
                "Total Features": columns,
                "Metric": list(metrics_train.keys()),      
                "Train data": train_rounded,
                "Test data": test_rounded,
                "95% CI": ci_bounds,
                "Std Dev": std_values,
        })
        
        return pred_metrics_df

# %%
results = "all"
prediction_df_report = None

if results == "all":
    
    pred_xgb_n = eval_model("XGBoost", trained_xgb_n, X_train_knn_t, X_test_knn_t, y_train, y_test)
    pred_xgb_t = eval_model("XGBoost", trained_xgb_t, X_train_t, X_test_t, y_train, y_test)
    
    prediction_df = pd.concat([pred_xgb_n, pred_xgb_t])
    prediction_df_report = prediction_df.set_index(["Feature Selection", "Classifier", "Classification Time", "Total Features", "Metric"])
        
elif results == "filtered":

    pred_xgb_t = eval_model("XGBoost", trained_xgb_t, X_train_t, X_test_t, y_train, y_test)
    
    prediction_df = pd.concat([pred_xgb_t])
    prediction_df_report = prediction_df.set_index(["Feature Selection", "Classifier", "Classification Time", "Total Features", "Metric"])

prediction_df_report
# Out:
#                                                                                    Train data  \
# Feature Selection Classifier Classification Time Total Features Metric
# Spearman          XGBoost    0.166               22             accuracy                  1.0
#                                                                 balanced_accuracy         1.0
#                                                                 precision_macro           1.0
#                                                                 recall_macro              1.0
#                                                                 f1_macro                  1.0
#                                                                 roc_auc_macro             1.0
#                                                                 specificity_macro         1.0
#                              0.245               21             accuracy                  1.0
#                                                                 balanced_accuracy         1.0
#                                                                 precision_macro           1.0
#                                                                 recall_macro              1.0
#                                                                 f1_macro                  1.0
#                                                                 roc_auc_macro             1.0
#                                                                 specificity_macro         1.0
#
#                                                                                    Test data  \
# Feature Selection Classifier Classification Time Total Features Metric
# Spearman          XGBoost    0.166               22             accuracy               0.785
#                                                                 balanced_accuracy      0.547
#                                                                 precision_macro        0.490
#                                                                 recall_macro           0.547
#                                                                 f1_macro               0.516
#                                                                 roc_auc_macro          0.784
#                                                                 specificity_macro      0.830
#                              0.245               21             accuracy               0.808
#                                                                 balanced_accuracy      0.569
#                                                                 precision_macro        0.503
#                                                                 recall_macro           0.569
#                                                                 f1_macro               0.533
#                                                                 roc_auc_macro          0.780
#                                                                 specificity_macro      0.846
#
#                                                                                            95% CI  \
# Feature Selection Classifier Classification Time Total Features Metric
# Spearman          XGBoost    0.166               22             accuracy            [0.74, 0.822]
#                                                                 balanced_accuracy  [0.501, 0.592]
#                                                                 precision_macro    [0.452, 0.528]
#                                                                 recall_macro       [0.501, 0.594]
#                                                                 f1_macro           [0.476, 0.553]
#                                                                 roc_auc_macro      [0.725, 0.846]
#                                                                 specificity_macro  [0.793, 0.865]
#                              0.245               21             accuracy           [0.767, 0.845]
#                                                                 balanced_accuracy  [0.523, 0.613]
#                                                                 precision_macro    [0.466, 0.541]
#                                                                 recall_macro       [0.523, 0.608]
#                                                                 f1_macro           [0.497, 0.568]
#                                                                 roc_auc_macro      [0.722, 0.841]
#                                                                 specificity_macro  [0.811, 0.879]
#
#                                                                                    Std Dev
# Feature Selection Classifier Classification Time Total Features Metric
# Spearman          XGBoost    0.166               22             accuracy             0.022
#                                                                 balanced_accuracy    0.024
#                                                                 precision_macro      0.019
#                                                                 recall_macro         0.024
#                                                                 f1_macro             0.020
#                                                                 roc_auc_macro        0.030
#                                                                 specificity_macro    0.018
#                              0.245               21             accuracy             0.019
#                                                                 balanced_accuracy    0.022
#                                                                 precision_macro      0.018
#                                                                 recall_macro         0.021
#                                                                 f1_macro             0.019
#                                                                 roc_auc_macro        0.030
#                                                                 specificity_macro    0.017

# %% [markdown]
# ### Export model

# %%
trained_xgb_t.save_model("xgboost_model.json")
