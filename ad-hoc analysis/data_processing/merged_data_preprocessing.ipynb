# %% [markdown]
# # Initialize Notebook
#
# ### Data-preprocessing

# %%
# Import basic libraries for EDA
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from dotenv import load_dotenv
import os
import pingouin as pg

# %%
# Import dataset
load_dotenv()
dataset_path=os.getenv("DATASET_PATH_L")
dataset_ADNI = pd.read_csv(dataset_path)
dataset_ADNI.head()
# Out:
#     RID  Gender  Ageatscreening  Diagnosis  MMSE0m  HipsASMbaseline  \
# 0  1140       0         84.5123          1    25.0         0.150000
# 1  1051       1         75.3699          1    26.0         0.097733
# 2    15       0         80.9068          0    29.0         0.100000
# 3   680       0         77.8932          0    28.0         0.110000
# 4   324       1         75.3534          1    24.0         0.140000
#
#    HipsContrastbaseline  HipsCorelationbaseline  HipsVariancebaseline  \
# 0            169.300000                0.610000            223.340000
# 1            175.103337                0.562332            197.321714
# 2            161.280000                0.540000            174.530000
# 3            235.890000                0.510000            231.560000
# 4            192.290000                0.550000            218.500000
#
#    HipsSumAveragebaseline  ...  ERCsContrastbaseline  ERCsCorelationbaseline  \
# 0               36.000000  ...            227.925000                0.495000
# 1               42.533788  ...            222.355754                0.500577
# 2               35.940000  ...            221.760000                0.445000
# 3               41.660000  ...            217.450000                0.540000
# 4               35.280000  ...            269.565000                0.390000
#
#    ERCsVariancebaseline  ERCsSumAveragebaseline  ERCsSumVariancebaseline  \
# 0            223.250000               27.445000               665.065000
# 1            218.584302               30.381415               651.981453
# 2                   NaN               30.565000                      NaN
# 3            236.750000               30.465000               729.545000
# 4            219.405000               26.560000               608.050000
#
#    ERCsEntropybaseline  ERCsClusterShadebaseline  ERCs_thicknessbaseline  \
# 0             2.725000               -516.185000                2.638340
# 1             3.154282               2595.481588                3.146500
# 2             3.120000               4287.780000                2.897730
# 3             3.010000               -741.895000                2.734850
# 4             2.565000                456.550000                2.444245
#
#    ERCsVolumebaseline  HipposcampusVolumebaseline
# 0              2397.0                     3164.85
# 1              1662.5                     2648.30
# 2              2188.0                     3602.50
# 3              2292.5                     3267.45
# 4              1082.0                     2550.50
#
# [5 rows x 24 columns]

# %%
# Import dataset
load_dotenv()
dataset_path=os.getenv("DATASET_PATH_TWO_PL")
dataset = pd.read_csv(dataset_path)
dataset.head()
# Out:
#    Label  Gender        Age  DIAGNOSIS  MMSE   Hip ASM  Hip Contrast  \
# 0  30879       0  64.585900          0  27.0  0.377501    128.715226
# 1  31129       0  68.076660          2  20.0  0.657212     51.830551
# 2  30605       1  76.221760          1  28.0  0.520032     86.558742
# 3  30039       0  73.221085          0  30.0  0.396133     60.731686
# 4  30079       0  45.872690          0  30.0  0.404800    108.808540
#
#    Hip Correlation  Hip Variance   Hip Sum Average  ...  ERC CONTRAST  \
# 0         0.422342     115.630163        15.181458  ...    286.270009
# 1         0.557254      84.225204         8.530596  ...    282.873623
# 2         0.594543     123.662642        13.400504  ...    244.274039
# 3         0.596733     122.546512        15.571183  ...    226.713342
# 4         0.520363      98.065558        13.483247  ...    202.074647
#
#    ERC CORRELATION  ERC VARIANCE   ERC SUM AVERAGE  ERC SUM VARIANCE  \
# 0         0.289728     206.373786        44.577974        539.225137
# 1         0.310507     206.276556        39.697933        542.232602
# 2         0.370189     201.216707        46.081559        560.592790
# 3         0.517430     232.983710        30.461877        705.221498
# 4         0.354851     169.528802        50.680275        476.040561
#
#    ERC ENTROPY  ERC CLUSTER SHADE  ERCs_thicknessbaseline  ERCsVolumebaseline  \
# 0     3.320292       22924.739100                  3.3445                2251
# 1     2.864138       18182.687670                  2.9605                2924
# 2     3.415186       28045.350990                  3.3145                4042
# 3     2.937422        1196.160472                  3.1505                3485
# 4     3.017047       47743.254120                  3.5420                3964
#
#    TOTAL_HIPPOCAMPUS_VOLUME
# 0                    7338.2
# 1                    5438.6
# 2                    8434.4
# 3                    7476.2
# 4                    8021.8
#
# [5 rows x 24 columns]

# %%
rename_dict = {
    'RID': 'Label',
    'Ageatscreening': 'Age',
    'Diagnosis': 'DIAGNOSIS',
    'MMSE0m': 'MMSE',
    'HipsASMbaseline': 'Hip ASM',
    'HipsContrastbaseline': 'Hip Contrast',
    'HipsCorelationbaseline': 'Hip Correlation',
    'HipsVariancebaseline': 'Hip Variance ',
    'HipsSumAveragebaseline': 'Hip Sum Average',
    'HipsSumVariancebaseline': 'Hip Sum Variance',
    'HipsEntropybaseline': 'Hip Entropy',
    'HipsClusterShadebaseline': 'Hip Clusterhade',
    'ERCsASMbaseline': 'ERC ASM',
    'ERCsContrastbaseline': 'ERC CONTRAST',
    'ERCsCorelationbaseline': 'ERC CORRELATION',
    'ERCsVariancebaseline': 'ERC VARIANCE ',
    'ERCsSumAveragebaseline': 'ERC SUM AVERAGE',
    'ERCsSumVariancebaseline': 'ERC SUM VARIANCE',
    'ERCsEntropybaseline': 'ERC ENTROPY',
    'ERCsClusterShadebaseline': 'ERC CLUSTER SHADE',
    'HipposcampusVolumebaseline': 'TOTAL_HIPPOCAMPUS_VOLUME'
}

dataset_ADNI.rename(columns=rename_dict, inplace=True)

# %%
dataset = pd.concat([dataset, dataset_ADNI], axis=0, ignore_index=True)

# then shuffle rows in-place (or assign back to combined)
dataset = dataset.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
dataset
# Out:
#       Label  Gender       Age  DIAGNOSIS  MMSE   Hip ASM  Hip Contrast  \
# 0     31140       0  87.18412          2  25.0  0.576119     41.516993
# 1      1318       1  83.02190          1  29.0  0.104620    190.636798
# 2      1035       0  87.32600          0  30.0  0.110000           NaN
# 3       436       0  85.15340          0  29.0  0.227405           NaN
# 4       812       1  71.72600          2  22.0  0.150000    185.770000
# ...     ...     ...       ...        ...   ...       ...           ...
# 1246    605       1  75.67120          0  30.0  0.100000    194.840000
# 1247    912       1  74.01640          1  29.0  0.079783    170.559734
# 1248   1240       1  67.09320          1  26.0  0.100000    160.440000
# 1249    190       0  79.02190          1  27.0  0.070000    195.460000
# 1250    517       0  81.95620          2  20.0  0.080000    163.790000
#
#       Hip Correlation  Hip Variance   Hip Sum Average  ...  ERC CONTRAST  \
# 0            0.611460      79.814266         8.965251  ...    368.245672
# 1            0.559982     222.087675        41.537126  ...    267.444573
# 2                 NaN     149.860000        50.100000  ...    232.310000
# 3            0.502037     236.747564        29.247323  ...    236.821140
# 4            0.550000     205.680000        31.490000  ...    272.700000
# ...               ...            ...              ...  ...           ...
# 1246         0.550000     216.030000        41.530000  ...    196.610000
# 1247         0.510097     177.778170        41.205200  ...           NaN
# 1248         0.580000     195.760000        40.180000  ...    249.275000
# 1249         0.460000     185.520000        44.310000  ...           NaN
# 1250         0.570000     190.820000        40.530000  ...    233.065000
#
#       ERC CORRELATION  ERC VARIANCE   ERC SUM AVERAGE  ERC SUM VARIANCE  \
# 0            0.175542     216.250128        33.930873        496.754841
# 1            0.407987     227.356779        27.734884        641.982542
# 2            0.455000     214.970000        37.595000        627.575000
# 3            0.502037     236.747564        29.247323        710.169115
# 4            0.395000     223.495000        31.255000        621.290000
# ...               ...            ...              ...               ...
# 1246         0.560000     223.825000        27.970000        698.685000
# 1247         0.362826     225.434743        34.496819        608.840035
# 1248         0.450000     225.910000        30.315000        654.360000
# 1249              NaN     204.325000        27.805000               NaN
# 1250         0.460000     213.870000        30.280000        622.430000
#
#       ERC ENTROPY  ERC CLUSTER SHADE  ERCs_thicknessbaseline  \
# 0        2.455708        8151.153118                2.497000
# 1        2.747380       -2338.896143                2.685500
# 2        3.295000                NaN                2.761275
# 3        2.923999       -1418.526557                2.956000
# 4        3.030000        1717.020000                2.426235
# ...           ...                ...                     ...
# 1246     2.755000         714.190000                2.902325
# 1247     3.136683        5737.527987                3.302500
# 1248     2.860000        1550.355000                2.524620
# 1249     2.790000         825.230000                2.237680
# 1250     2.955000        3426.585000                2.369745
#
#       ERCsVolumebaseline  TOTAL_HIPPOCAMPUS_VOLUME
# 0                 2210.0                   5354.20
# 1                 1223.0                   2944.30
# 2                 1932.0                   3385.85
# 3                 2180.0                   3478.40
# 4                 1275.0                   3018.85
# ...                  ...                       ...
# 1246              1948.0                   4012.25
# 1247              1434.0                   3262.60
# 1248               981.0                   2752.00
# 1249               840.5                   2419.75
# 1250              1546.0                   3062.05
#
# [1251 rows x 24 columns]

# %%
set(dataset.columns) ^ set(dataset_ADNI.columns)
# Out:
# set()

# %%
dataset["DIAGNOSIS"].unique()
# Out:
# array([2, 1, 0])

# %%
dataset["DIAGNOSIS"].value_counts()
# Out:
# DIAGNOSIS
# 0    722
# 2    277
# 1    252
# Name: count, dtype: int64

# %%
# Export to CSV
dataset.to_csv('C:/Users/steve/Desktop/Notebooks/Thesis-Project/datasets/processed/merged_processed_dataset_leaked_train_test_check.csv', index=False)
