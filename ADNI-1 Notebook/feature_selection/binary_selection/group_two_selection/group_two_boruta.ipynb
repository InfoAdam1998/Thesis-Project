# %% [markdown]
# ## Feature selection
#
# Boruta is an advanced feature selection method that uses Random Forest as a base algorithm. Its goal is to identify all relevant features in a dataset, including those that might have a weaker impact on the model's predictive power but are still significant. It is particularly useful for datasets with many features where traditional methods of feature selection (such as mutual information or simple feature importance) might miss some important variables.
#
#
# The main steps of the Boruta algorithm are:
#
# Create Shadow Features:
#
# For each feature in the dataset, create a shadow feature by randomly permuting (shuffling) the feature’s values. This step helps in understanding how important the real features are compared to random noise.
# For example, if you have 10 original features, Boruta will create 10 shadow features.
# Train Random Forest:
#
# A Random Forest model is trained using the original features along with the shadow features. This model is used to rank the importance of each feature based on how it improves model performance.
# Ranking Features:
#
# The importance of each feature is determined by how much it contributes to reducing the impurity (e.g., Gini impurity) in the Random Forest. The higher the feature's contribution to impurity reduction, the more important the feature is considered.
# Feature Comparison:
#
# Each original feature is compared against its corresponding shadow feature’s importance. If the original feature has higher importance than its shadow feature, it is considered relevant.
# Features are ranked based on their importance, and shadow features are always considered irrelevant.
# Feature Elimination:
#
# Boruta eliminates irrelevant features and keeps features that have higher importance than the shadow features. A feature is removed if its importance is significantly less than the highest shadow feature.
# Iteration:
#
# This process is repeated multiple times (usually several hundred iterations) to refine the ranking of features. The final set of selected features is determined based on consistent importance across the iterations.
# Final Decision:
#
# Once the algorithm has iterated enough, it returns a final list of features that are either:
# Confirmed: Features that are significantly more important than their shadow counterparts.
# Rejected: Features that are consistently less important than their shadow counterparts.
# Tentative: Features that have mixed importance but may be relevant depending on the model.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from dotenv import load_dotenv
import os

from sklearn.pipeline import Pipeline
from feature_engine.selection import DropConstantFeatures, DropDuplicateFeatures, SelectByShuffling

from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from boruta import BorutaPy
from sklearn.experimental import enable_iterative_imputer
from sklearn.model_selection import train_test_split
from sklearn.impute import IterativeImputer
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import BayesianRidge

import xgboost as xgb
from xgboost import XGBClassifier
from ngboost import NGBClassifier
from ngboost.distns import k_categorical

from sklearn.model_selection import StratifiedKFold, cross_validate
from sklearn.metrics import accuracy_score, roc_auc_score, recall_score, precision_score, f1_score, balanced_accuracy_score

# %%
# Import dataset
load_dotenv()
dataset_path=os.getenv("DATASET_PATH")
dataset = pd.read_csv(dataset_path)
dataset.head()
# Out:
#    RID  Gender  Ageatscreening  Diagnosis  MMSE0m  HipsASMbaseline  \
# 0    3       0         81.3479          3    20.0              NaN
# 1    4       0         67.6904          1    27.0             0.06
# 2    5       0         73.8027          0    29.0             0.10
# 3    8       1         84.5945          0    28.0             0.08
# 4   10       1         73.9726          3    24.0             0.11
#
#    HipsContrastbaseline  HipsCorelationbaseline  HipsVariancebaseline  \
# 0                158.27                    0.63                218.30
# 1                147.64                    0.55                173.64
# 2                199.66                    0.55                222.27
# 3                184.21                    0.53                201.55
# 4                233.02                    0.48                229.88
#
#    HipsSumAveragebaseline  ...  ERCsContrastbaseline  ERCsCorelationbaseline  \
# 0                   28.37  ...                253.10                    0.40
# 1                   44.72  ...                220.88                    0.48
# 2                   41.18  ...                220.37                    0.54
# 3                   43.04  ...                198.42                    0.54
# 4                   39.46  ...                196.55                    0.53
#
#    ERCsVariancebaseline  ERCsSumAveragebaseline  ERCsSumVariancebaseline  \
# 0                208.65                   23.39                   581.50
# 1                215.70                   33.74                   641.90
# 2                232.18                   29.18                   708.36
# 3                220.48                   26.68                   683.50
# 4                210.63                   26.60                   645.95
#
#    ERCsEntropybaseline  ERCsClusterShadebaseline  ERCs_thicknessbaseline  \
# 0                  NaN                  -2568.19                    2.31
# 1                 3.33                   4113.01                    2.76
# 2                 2.87                  -1388.41                    3.18
# 3                 2.77                  -2506.55                    2.68
# 4                 2.72                  -1164.02                    2.64
#
#    ERCsVolumebaseline  HipposcampusVolumebaseline
# 0              1176.0                      3047.0
# 1              1942.0                      3449.0
# 2              2044.0                      3441.0
# 3              1959.0                      2875.0
# 4              1397.0                      2700.0
#
# [5 rows x 24 columns]

# %%
group_one = dataset[dataset["Diagnosis"] == 0]
group_two = dataset[dataset["Diagnosis"] == 3]

combined_group_two = pd.concat([group_one, group_two], ignore_index = True)
combined_group_two["Diagnosis"].unique()
# Out:
# array([0, 3])

# %%
combined_group_two
# Out:
#       RID  Gender  Ageatscreening  Diagnosis  MMSE0m  HipsASMbaseline  \
# 0       5       0         73.8027          0    29.0             0.10
# 1       8       1         84.5945          0    28.0             0.08
# 2      14       1         78.6137          0    29.0             0.12
# 3      15       0         80.9068          0    29.0             0.10
# 4      16       0         65.5205          0    28.0             0.12
# ..    ...     ...             ...        ...     ...              ...
# 319  1201       1         75.6411          3    26.0             0.18
# 320  1221       0         71.2712          3    21.0             0.22
# 321  1248       1         79.8548          3    23.0             0.19
# 322  1253       1         62.7452          3    24.0             0.05
# 323  1257       0         85.0849          3    20.0             0.15
#
#      HipsContrastbaseline  HipsCorelationbaseline  HipsVariancebaseline  \
# 0                  199.66                    0.55                222.27
# 1                  184.21                    0.53                201.55
# 2                  188.33                    0.49                183.76
# 3                  161.28                    0.54                174.53
# 4                  166.97                    0.58                202.96
# ..                    ...                     ...                   ...
# 319                173.84                    0.59                215.04
# 320                174.02                    0.58                211.07
# 321                199.31                    0.56                229.63
# 322                142.05                    0.50                147.12
# 323                147.66                    0.57                180.78
#
#      HipsSumAveragebaseline  ...  ERCsContrastbaseline  \
# 0                     41.18  ...                220.37
# 1                     43.04  ...                198.42
# 2                     39.63  ...                241.64
# 3                     35.94  ...                221.76
# 4                     38.42  ...                228.53
# ..                      ...  ...                   ...
# 319                   33.84  ...                281.15
# 320                   30.56  ...                224.78
# 321                   33.13  ...                220.41
# 322                   46.21  ...                217.38
# 323                   31.82  ...                287.61
#
#      ERCsCorelationbaseline  ERCsVariancebaseline  ERCsSumAveragebaseline  \
# 0                      0.54                232.18                   29.18
# 1                      0.54                220.48                   26.68
# 2                      0.44                226.48                   35.11
# 3                      0.45                   NaN                   30.57
# 4                      0.50                228.72                   28.98
# ..                      ...                   ...                     ...
# 319                    0.37                222.73                   27.94
# 320                    0.47                205.49                   27.36
# 321                    0.48                214.97                   27.16
# 322                    0.51                220.55                   32.54
# 323                    0.39                233.07                   29.95
#
#      ERCsSumVariancebaseline  ERCsEntropybaseline  ERCsClusterShadebaseline  \
# 0                     708.36                 2.87                  -1388.41
# 1                     683.50                 2.77                  -2506.55
# 2                     664.29                 3.10                   8478.33
# 3                        NaN                 3.12                   4287.78
# 4                     686.36                 2.90                  -1381.99
# ..                       ...                  ...                       ...
# 319                   609.75                 2.84                  -1924.49
# 320                   597.20                 2.77                   1146.39
# 321                   639.47                 2.79                   -919.84
# 322                   664.84                 3.09                   5289.89
# 323                   644.68                 2.95                   -467.36
#
#      ERCs_thicknessbaseline  ERCsVolumebaseline  HipposcampusVolumebaseline
# 0                      3.18              2044.0                      3441.0
# 1                      2.68              1959.0                      2875.0
# 2                      3.01              1809.0                      3292.0
# 3                      2.90              2188.0                      3603.0
# 4                      2.73              1829.0                      3695.0
# ..                      ...                 ...                         ...
# 319                    1.94              1112.0                      2705.0
# 320                    2.44              1526.0                      2913.0
# 321                    1.99              1215.0                      2273.0
# 322                    3.27              2321.0                      3739.0
# 323                    2.45              1819.0                      3631.0
#
# [324 rows x 24 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    combined_group_two.drop("Diagnosis", axis=1),  
    combined_group_two["Diagnosis"],  
    test_size=0.3,  
    random_state=42,  
)

X_train.shape, X_test.shape
# Out:
# ((226, 23), (98, 23))

# %%
imputer_bayes = IterativeImputer(
    estimator=BayesianRidge(),
    random_state=42,
)

imputer_bayes.fit(X_train)
X_train_bayes = imputer_bayes.transform(X_train)
X_test_bayes = imputer_bayes.transform(X_test)

# %%
X_train_bayes_t = pd.DataFrame(
    X_train_bayes, 
    columns=X_train.columns, 
    index=X_train.index  # Critical fix
)
X_test_bayes_t = pd.DataFrame(
    X_test_bayes, 
    columns=X_test.columns, 
    index=X_test.index  # Critical fix
)

# %%
pipe = Pipeline([
    ('constant', DropConstantFeatures(tol=1, variables=None, missing_values='raise')),
    ('quasi-constant', DropConstantFeatures(tol=0.998, variables=None, missing_values='raise')),
    ('duplicated', DropDuplicateFeatures()),
])

pipe.fit(X_train_bayes_t)
# Out:
# Pipeline(steps=[('constant', DropConstantFeatures()),
#                 ('quasi-constant', DropConstantFeatures(tol=0.998)),
#                 ('duplicated', DropDuplicateFeatures())])

# %%
constant_step = pipe.named_steps['constant']
quasi_constant_step = pipe.named_steps['quasi-constant']
duplicated_step = pipe.named_steps['duplicated']

print("Constant features removed:", constant_step.features_to_drop_)
print("Quasi-constant features removed:", quasi_constant_step.features_to_drop_)
print("Duplicate features removed:", duplicated_step.features_to_drop_)
# Out:
# Constant features removed: []
# Quasi-constant features removed: []
# Duplicate features removed: set()

# %%
X_train_t = pipe.transform(X_train_bayes_t)
X_test_t = pipe.transform(X_test_bayes_t)

X_train_t.shape, X_test_t.shape
# Out:
# ((226, 23), (98, 23))

# %%
model = RandomForestClassifier(random_state=42,)

# let's initialize Boruta
sel = BorutaPy(
    verbose=2,
    estimator=model,
    n_estimators='auto',
)

sel.fit(X_train_t.values, y_train.values)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	23
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	23
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	23
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	23
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	23
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	23
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	23
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	6
# Tentative: 	10
# Rejected: 	7
# Iteration: 	9 / 100
# Confirmed: 	6
# Tentative: 	10
# Rejected: 	7
# Iteration: 	10 / 100
# Confirmed: 	6
# Tentative: 	10
# Rejected: 	7
# Iteration: 	11 / 100
# Confirmed: 	6
# Tentative: 	10
# Rejected: 	7
# Iteration: 	12 / 100
# Confirmed: 	7
# Tentative: 	7
# Rejected: 	9
# Iteration: 	13 / 100
# Confirmed: 	7
# Tentative: 	7
# Rejected: 	9
# Iteration: 	14 / 100
# Confirmed: 	7
# Tentative: 	7
# Rejected: 	9
# Iteration: 	15 / 100
# Confirmed: 	7
# Tentative: 	7
# Rejected: 	9
# Iteration: 	16 / 100
# Confirmed: 	7
# Tentative: 	7
# Rejected: 	9
# Iteration: 	17 / 100
# Confirmed: 	7
# Tentative: 	7
# Rejected: 	9
# Iteration: 	18 / 100
# Confirmed: 	7
# Tentative: 	7
# Rejected: 	9
# Iteration: 	19 / 100
# Confirmed: 	7
# Tentative: 	6
# Rejected: 	10
# Iteration: 	20 / 100
# Confirmed: 	7
# Tentative: 	6
# Rejected: 	10
# Iteration: 	21 / 100
# Confirmed: 	7
# Tentative: 	6
# Rejected: 	10
# Iteration: 	22 / 100
# Confirmed: 	7
# Tentative: 	6
# Rejected: 	10
# Iteration: 	23 / 100
# Confirmed: 	7
# Tentative: 	6
# Rejected: 	10
# Iteration: 	24 / 100
# Confirmed: 	7
# Tentative: 	6
# Rejected: 	10
# Iteration: 	25 / 100
# Confirmed: 	7
# Tentative: 	6
# Rejected: 	10
# Iteration: 	26 / 100
# Confirmed: 	7
# Tentative: 	6
# Rejected: 	10
# Iteration: 	27 / 100
# Confirmed: 	7
# Tentative: 	6
# Rejected: 	10
# Iteration: 	28 / 100
# Confirmed: 	7
# Tentative: 	6
# Rejected: 	10
# Iteration: 	29 / 100
# Confirmed: 	7
# Tentative: 	6
# Rejected: 	10
# Iteration: 	30 / 100
# Confirmed: 	7
# Tentative: 	6
# Rejected: 	10
# Iteration: 	31 / 100
# Confirmed: 	7
# Tentative: 	6
# Rejected: 	10
# Iteration: 	32 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	33 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	34 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	35 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	36 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	37 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	38 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	39 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	40 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	41 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	42 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	43 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	44 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	45 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	46 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	47 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	48 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	49 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	50 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	51 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	52 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	53 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	54 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	55 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	56 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	57 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	58 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	59 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	60 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	61 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	62 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	63 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	64 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	65 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	66 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	67 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	68 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	69 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	70 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	71 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	72 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	73 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	74 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	75 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	76 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	77 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	78 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	79 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	80 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	81 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	82 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	83 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	84 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	85 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	86 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	87 / 100
# Confirmed: 	8
# Tentative: 	3
# Rejected: 	12
# Iteration: 	88 / 100
# Confirmed: 	9
# Tentative: 	2
# Rejected: 	12
# Iteration: 	89 / 100
# Confirmed: 	9
# Tentative: 	2
# Rejected: 	12
# Iteration: 	90 / 100
# Confirmed: 	9
# Tentative: 	2
# Rejected: 	12
# Iteration: 	91 / 100
# Confirmed: 	9
# Tentative: 	2
# Rejected: 	12
# Iteration: 	92 / 100
# Confirmed: 	9
# Tentative: 	2
# Rejected: 	12
# Iteration: 	93 / 100
# Confirmed: 	9
# Tentative: 	2
# Rejected: 	12
# Iteration: 	94 / 100
# Confirmed: 	9
# Tentative: 	2
# Rejected: 	12
# Iteration: 	95 / 100
# Confirmed: 	9
# Tentative: 	2
# Rejected: 	12
# Iteration: 	96 / 100
# Confirmed: 	9
# Tentative: 	2
# Rejected: 	12
# Iteration: 	97 / 100
# Confirmed: 	9
# Tentative: 	2
# Rejected: 	12
# Iteration: 	98 / 100
# Confirmed: 	9
# Tentative: 	2
# Rejected: 	12
# Iteration: 	99 / 100
# Confirmed: 	9
# Tentative: 	2
# Rejected: 	12
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	13
# BorutaPy(estimator=RandomForestClassifier(n_estimators=46,
#                                           random_state=RandomState(MT19937) at 0x1AC889F3340),
#          n_estimators='auto',
#          random_state=RandomState(MT19937) at 0x1AC889F3340, verbose=2)

# %%
# print support and ranking for each feature
print("\n------Support and Ranking for each feature------")
for i in range(len(sel.support_)):
    if sel.support_[i]:
        print("Passes the test: ", X_train_t.columns[i],
              " - Ranking: ", sel.ranking_[i])
    else:
        print("Doesn't pass the test: ",
              X_train_t.columns[i], " - Ranking: ", sel.ranking_[i])
# Out:
# ------Support and Ranking for each feature------
# Doesn't pass the test:  RID  - Ranking:  5
# Doesn't pass the test:  Gender  - Ranking:  15
# Passes the test:  Ageatscreening  - Ranking:  1
# Passes the test:  MMSE0m  - Ranking:  1
# Doesn't pass the test:  HipsASMbaseline  - Ranking:  14
# Doesn't pass the test:  HipsContrastbaseline  - Ranking:  8
# Doesn't pass the test:  HipsCorelationbaseline  - Ranking:  12
# Doesn't pass the test:  HipsVariancebaseline  - Ranking:  2
# Doesn't pass the test:  HipsSumAveragebaseline  - Ranking:  7
# Doesn't pass the test:  HipsSumVariancebaseline  - Ranking:  4
# Doesn't pass the test:  HipsEntropybaseline  - Ranking:  3
# Doesn't pass the test:  HipsClusterShadebaseline  - Ranking:  10
# Doesn't pass the test:  ERCsASMbaseline  - Ranking:  12
# Passes the test:  ERCsContrastbaseline  - Ranking:  1
# Passes the test:  ERCsCorelationbaseline  - Ranking:  1
# Doesn't pass the test:  ERCsVariancebaseline  - Ranking:  9
# Doesn't pass the test:  ERCsSumAveragebaseline  - Ranking:  5
# Passes the test:  ERCsSumVariancebaseline  - Ranking:  1
# Passes the test:  ERCsEntropybaseline  - Ranking:  1
# Doesn't pass the test:  ERCsClusterShadebaseline  - Ranking:  10
# Passes the test:  ERCs_thicknessbaseline  - Ranking:  1
# Passes the test:  ERCsVolumebaseline  - Ranking:  1
# Passes the test:  HipposcampusVolumebaseline  - Ranking:  1

# %%
# Store selected feature names before transformation
selected_features = X_train_t.columns[sel.support_]
selected_features
# Out:
# Index(['Ageatscreening', 'MMSE0m', 'ERCsContrastbaseline',
#        'ERCsCorelationbaseline', 'ERCsSumVariancebaseline',
#        'ERCsEntropybaseline', 'ERCs_thicknessbaseline', 'ERCsVolumebaseline',
#        'HipposcampusVolumebaseline'],
#       dtype='object')

# %%
ranking = sel.ranking_
plot_ranking = pd.Series(ranking)
plot_ranking.index = X_train.columns
plot_ranking.sort_values().plot(kind="bar")
# Out:
# <Axes: >

# %%
# Transform training and test sets using selected features
X_train_t = X_train_t[selected_features]
X_test_t = X_test_t[selected_features]

X_train_t.shape, X_test_t.shape
# Out:
# ((226, 9), (98, 9))

# %% [markdown]
# ## Classification Test

# %%
from ngboost.distns import Bernoulli
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

def run_model(classifier_name, X_train, y_train):
        
        columns = len(X_train.columns)

        # Initialize the model based on classifier_name
        if classifier_name == "Random Forest":
                model = RandomForestClassifier(n_estimators=100, 
                                        max_depth=5, 
                                        random_state=42, 
                                        class_weight="balanced")
                
        elif classifier_name == "XGBoost":
        # XGBClassifier sometimes issues warnings about label encoding. 
        # We disable the use_label_encoder and set an evaluation metric.
                model = XGBClassifier(n_estimators=100, 
                                max_depth=5, 
                                random_state=42,
                                eval_metric="logloss",
                                use_label_encoder=False,
                                objective="binary:logistic",
                                verbosity=0)
        
        elif classifier_name == "NGBoost":
                model = NGBClassifier(Dist=k_categorical(2),
                                      n_estimators=100,
                                      verbose=False) 
                
        elif classifier_name == "Logistic Regression":
                model = LogisticRegression(
                class_weight="balanced",
                solver="lbfgs",
                max_iter=500,
                random_state=42
                )
                
                # Scale features
                scaler = StandardScaler()
                X_train = scaler.fit_transform(X_train)

        else:
                raise ValueError("Unknown classifier")
                
        kf = StratifiedKFold(n_splits=10,
                             shuffle=True,
                             random_state=42,
        )
        
        cross_val_results = cross_validate(model,
                                           X_train,
                                           y_train,
                                           cv=kf,
                                           scoring="balanced_accuracy",
                                           return_train_score=True,
        )
               
        # Calculate the metrics for training and testing
        mean_train = [round(np.mean(cross_val_results["train_score"]), 3)]
        std_train = [round(np.std(cross_val_results["train_score"]), 3)]
        mean_test = [round(np.mean(cross_val_results["test_score"]), 3)]
        std_test = [round(np.std(cross_val_results["test_score"]), 3)]
        time = round(np.mean(cross_val_results["fit_time"]), 3)
                
        cv_metrics_df = pd.DataFrame({
                "Feature Selection": "Boruta",
                "Classifier": classifier_name,
                "Fit Time": time,
                "Total Features": columns,
                "Metric": "balanced_accuracy",
                "Mean Train": mean_train,
                "Std Train": std_train,
                "Mean Test": mean_test,
                "Std Test": std_test,
        })
        
        fit_model = model.fit(X_train, y_train)
        
        return fit_model, cv_metrics_df

# %%
from sklearn.preprocessing import LabelEncoder

# 1) Fit a label encoder on the training labels:
le_train = LabelEncoder().fit(y_train)
le_test = LabelEncoder().fit(y_test)

# 2) Transform y_train (and later y_test) to {0,1} internally:
y_train_enc = le_train.transform(y_train)
y_test_enc = le_test.transform(y_test)

# %%
trained_rf_n, metrics_rf_n = run_model("Random Forest", X_train_bayes_t, y_train_enc)
trained_rf_t, metrics_rf_t = run_model("Random Forest", X_train_t, y_train_enc)

trained_xgb_n, metrics_xgb_n = run_model("XGBoost", X_train_bayes_t, y_train_enc)
trained_xgb_t, metrics_xgb_t = run_model("XGBoost", X_train_t, y_train_enc)

trained_ngb_n, metrics_ngb_n = run_model("NGBoost", X_train_bayes_t, y_train_enc)
trained_ngb_t, metrics_ngb_t = run_model("NGBoost", X_train_t, y_train_enc)

trained_lg_n, metrics_lg_n = run_model("Logistic Regression", X_train_bayes_t, y_train_enc)
trained_lg_t, metrics_lg_t = run_model("Logistic Regression", X_train_t, y_train_enc)

# %%
validation_df = pd.concat([metrics_rf_n, metrics_rf_t, metrics_xgb_n, metrics_xgb_t, metrics_ngb_n, metrics_ngb_t, metrics_lg_n, metrics_lg_t])
validation_df_report = validation_df.set_index(["Feature Selection", "Classifier", "Fit Time", "Total Features", "Metric"])
validation_df_report
# Out:
#                                                                                  Mean Train  \
# Feature Selection Classifier          Fit Time Total Features Metric
# Boruta            Random Forest       1.085    23             balanced_accuracy       1.000
#                                       0.434    9              balanced_accuracy       1.000
#                   XGBoost             0.154    23             balanced_accuracy       1.000
#                                       0.083    9              balanced_accuracy       1.000
#                   NGBoost             1.213    23             balanced_accuracy       1.000
#                                       1.241    9              balanced_accuracy       1.000
#                   Logistic Regression 0.012    23             balanced_accuracy       0.987
#                                       0.008    9              balanced_accuracy       0.975
#
#                                                                                  Std Train  \
# Feature Selection Classifier          Fit Time Total Features Metric
# Boruta            Random Forest       1.085    23             balanced_accuracy      0.000
#                                       0.434    9              balanced_accuracy      0.000
#                   XGBoost             0.154    23             balanced_accuracy      0.000
#                                       0.083    9              balanced_accuracy      0.000
#                   NGBoost             1.213    23             balanced_accuracy      0.001
#                                       1.241    9              balanced_accuracy      0.001
#                   Logistic Regression 0.012    23             balanced_accuracy      0.002
#                                       0.008    9              balanced_accuracy      0.004
#
#                                                                                  Mean Test  \
# Feature Selection Classifier          Fit Time Total Features Metric
# Boruta            Random Forest       1.085    23             balanced_accuracy      0.973
#                                       0.434    9              balanced_accuracy      0.974
#                   XGBoost             0.154    23             balanced_accuracy      0.967
#                                       0.083    9              balanced_accuracy      0.970
#                   NGBoost             1.213    23             balanced_accuracy      0.952
#                                       1.241    9              balanced_accuracy      0.956
#                   Logistic Regression 0.012    23             balanced_accuracy      0.974
#                                       0.008    9              balanced_accuracy      0.965
#
#                                                                                  Std Test
# Feature Selection Classifier          Fit Time Total Features Metric
# Boruta            Random Forest       1.085    23             balanced_accuracy     0.031
#                                       0.434    9              balanced_accuracy     0.033
#                   XGBoost             0.154    23             balanced_accuracy     0.035
#                                       0.083    9              balanced_accuracy     0.032
#                   NGBoost             1.213    23             balanced_accuracy     0.049
#                                       1.241    9              balanced_accuracy     0.047
#                   Logistic Regression 0.012    23             balanced_accuracy     0.034
#                                       0.008    9              balanced_accuracy     0.046

# %%
import time

def eval_model(classifier_name, model, X_train, X_test, y_train, y_test):
        
        start_time = time.time()
        columns = len(X_train.columns)
        
        if classifier_name == "Logistic Regression":  
                # Scale features
                scaler = StandardScaler()
                X_train = scaler.fit_transform(X_train)
                X_test = scaler.fit_transform(X_test)
                
        # Get predicted probabilities for ROC AUC
        pred_train_proba = model.predict_proba(X_train)
        pred_test_proba = model.predict_proba(X_test)
        
        # Get predicted accuracy values
        pred_train = model.predict(X_train)
        pred_test = model.predict(X_test)
        
        # Calculate metrics
        metrics_train = {
                "accuracy": round(accuracy_score(y_train, pred_train), 3),
                "balanced_accuracy": round(balanced_accuracy_score(y_train, pred_train), 3),
                "precision": round(precision_score(y_train, pred_train, average="binary"), 3),
                "recall": round(recall_score(y_train, pred_train, average="binary"), 3),
                "f1": round(f1_score(y_train, pred_train, average="binary"), 3),
                "roc_auc_ovr": round(roc_auc_score(y_train, pred_train_proba[:, 1]),3,),
        }
        
        metrics_test = {
                "accuracy": round(accuracy_score(y_test, pred_test), 3),
                "balanced_accuracy": round(balanced_accuracy_score(y_test, pred_test), 3),
                "precision": round(precision_score(y_test, pred_test, average="binary"), 3),
                "recall": round(recall_score(y_test, pred_test, average="binary"), 3),
                "f1": round(f1_score(y_test, pred_test, average="binary"), 3),
                "roc_auc_ovr": round(roc_auc_score(y_test, pred_test_proba[:, 1]),3,),
        }
                
        elapsed_time = time.time() - start_time
    
        # Create the DataFrame without additional rounding
        pred_metrics_df = pd.DataFrame({
                "Feature Selection": "Boruta",
                "Classifier": classifier_name,
                "Classification Time": round(elapsed_time, 3),
                "Total Features": columns,
                "Metric": metrics_train.keys(),
                "Train data": metrics_train.values(),
                "Test data": metrics_test.values(),
    })
        
        return pred_metrics_df

# %%
results = "all"
prediction_df_report = None

if results == "all":
    pred_rf_n = eval_model("Random Forest", trained_rf_n, X_train_bayes_t, X_test_bayes_t, y_train_enc, y_test_enc)
    pred_rf_t = eval_model("Random Forest", trained_rf_t, X_train_t, X_test_t, y_train_enc, y_test_enc)

    pred_xgb_n = eval_model("XGBoost", trained_xgb_n, X_train_bayes_t, X_test_bayes_t, y_train_enc, y_test_enc)
    pred_xgb_t = eval_model("XGBoost", trained_xgb_t, X_train_t, X_test_t, y_train_enc, y_test_enc)

    pred_ngb_n = eval_model("NGBoost", trained_ngb_n, X_train_bayes_t, X_test_bayes_t, y_train_enc, y_test_enc)
    pred_ngb_t = eval_model("NGBoost", trained_ngb_t, X_train_t, X_test_t, y_train_enc, y_test_enc)
    
    pred_lg_n = eval_model("Logistic Regression", trained_lg_n, X_train_bayes_t, X_test_bayes_t, y_train_enc, y_test_enc)
    pred_lg_t = eval_model("Logistic Regression", trained_lg_t, X_train_t, X_test_t, y_train_enc, y_test_enc)
    
    prediction_df = pd.concat([pred_rf_n, pred_rf_t, pred_xgb_n, pred_xgb_t, pred_ngb_n, pred_ngb_t, pred_lg_n, pred_lg_t])
    prediction_df_report = prediction_df.set_index(["Feature Selection", "Classifier", "Classification Time", "Total Features", "Metric"])
        
elif results == "filtered":
    pred_rf_t = eval_model("Random Forest", trained_rf_t, X_train_t, X_test_t, y_train_enc, y_test_enc)
    pred_xgb_t = eval_model("XGBoost", trained_xgb_t, X_train_t, X_test_t, y_train_enc, y_test_enc)
    pred_ngb_t = eval_model("NGBoost", trained_ngb_t, X_train_t, X_test_t, y_train_enc, y_test_enc)
    pred_lg_t = eval_model("Logistic Regression", trained_lg_t, X_train_t, X_test_t, y_train_enc, y_test_enc)

    prediction_df = pd.concat([pred_rf_t, pred_xgb_t, pred_ngb_t, pred_lg_t])
    prediction_df_report = prediction_df.set_index(["Feature Selection", "Classifier", "Classification Time", "Total Features", "Metric"])

prediction_df_report
# Out:
#                                                                                             Train data  \
# Feature Selection Classifier          Classification Time Total Features Metric
# Boruta            Random Forest       0.275               23             accuracy                1.000
#                                                                          balanced_accuracy       1.000
#                                                                          precision               1.000
#                                                                          recall                  1.000
#                                                                          f1                      1.000
#                                                                          roc_auc_ovr             1.000
#                                       0.200               9              accuracy                1.000
#                                                                          balanced_accuracy       1.000
#                                                                          precision               1.000
#                                                                          recall                  1.000
#                                                                          f1                      1.000
#                                                                          roc_auc_ovr             1.000
#                   XGBoost             0.129               23             accuracy                1.000
#                                                                          balanced_accuracy       1.000
#                                                                          precision               1.000
#                                                                          recall                  1.000
#                                                                          f1                      1.000
#                                                                          roc_auc_ovr             1.000
#                                       0.107               9              accuracy                1.000
#                                                                          balanced_accuracy       1.000
#                                                                          precision               1.000
#                                                                          recall                  1.000
#                                                                          f1                      1.000
#                                                                          roc_auc_ovr             1.000
#                   NGBoost             0.305               23             accuracy                1.000
#                                                                          balanced_accuracy       1.000
#                                                                          precision               1.000
#                                                                          recall                  1.000
#                                                                          f1                      1.000
#                                                                          roc_auc_ovr             1.000
#                                       0.230               9              accuracy                1.000
#                                                                          balanced_accuracy       1.000
#                                                                          precision               1.000
#                                                                          recall                  1.000
#                                                                          f1                      1.000
#                                                                          roc_auc_ovr             1.000
#                   Logistic Regression 0.039               23             accuracy                0.987
#                                                                          balanced_accuracy       0.987
#                                                                          precision               0.978
#                                                                          recall                  0.989
#                                                                          f1                      0.984
#                                                                          roc_auc_ovr             0.999
#                                       0.036               9              accuracy                0.978
#                                                                          balanced_accuracy       0.978
#                                                                          precision               0.967
#                                                                          recall                  0.978
#                                                                          f1                      0.973
#                                                                          roc_auc_ovr             0.998
#
#                                                                                             Test data
# Feature Selection Classifier          Classification Time Total Features Metric
# Boruta            Random Forest       0.275               23             accuracy               0.959
#                                                                          balanced_accuracy      0.957
#                                                                          precision              0.949
#                                                                          recall                 0.949
#                                                                          f1                     0.949
#                                                                          roc_auc_ovr            0.994
#                                       0.200               9              accuracy               0.980
#                                                                          balanced_accuracy      0.983
#                                                                          precision              0.951
#                                                                          recall                 1.000
#                                                                          f1                     0.975
#                                                                          roc_auc_ovr            0.990
#                   XGBoost             0.129               23             accuracy               0.969
#                                                                          balanced_accuracy      0.970
#                                                                          precision              0.950
#                                                                          recall                 0.974
#                                                                          f1                     0.962
#                                                                          roc_auc_ovr            0.998
#                                       0.107               9              accuracy               0.959
#                                                                          balanced_accuracy      0.962
#                                                                          precision              0.927
#                                                                          recall                 0.974
#                                                                          f1                     0.950
#                                                                          roc_auc_ovr            0.995
#                   NGBoost             0.305               23             accuracy               0.980
#                                                                          balanced_accuracy      0.979
#                                                                          precision              0.974
#                                                                          recall                 0.974
#                                                                          f1                     0.974
#                                                                          roc_auc_ovr            0.989
#                                       0.230               9              accuracy               0.969
#                                                                          balanced_accuracy      0.970
#                                                                          precision              0.950
#                                                                          recall                 0.974
#                                                                          f1                     0.962
#                                                                          roc_auc_ovr            0.986
#                   Logistic Regression 0.039               23             accuracy               0.969
#                                                                          balanced_accuracy      0.970
#                                                                          precision              0.950
#                                                                          recall                 0.974
#                                                                          f1                     0.962
#                                                                          roc_auc_ovr            0.997
#                                       0.036               9              accuracy               0.990
#                                                                          balanced_accuracy      0.992
#                                                                          precision              0.975
#                                                                          recall                 1.000
#                                                                          f1                     0.987
#                                                                          roc_auc_ovr            0.998
