# %% [markdown]
# ## Correlation Analysis
#
# Lets check the correlation between variables
#
# Correlation measures the strength and direction of the linear relationship between two variables, but it is normalized to be independent of the units of the variables.

# %%
# Import basic libraries for EDA
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pingouin as pg
from dotenv import load_dotenv
import os

# %%
# Import dataset
load_dotenv()
dataset_path=os.getenv("DATASET_PATH")
dataset = pd.read_csv(dataset_path)
dataset.head()
# Out:
#    Gender  Ageatscreening  Diagnosis  MMSE0m  HipsASMbaseline  \
# 0       0         81.3479          2    20.0              NaN
# 1       0         67.6904          1    27.0             0.06
# 2       0         73.8027          0    29.0             0.10
# 3       1         84.5945          0    28.0             0.08
# 4       1         73.9726          2    24.0             0.11
#
#    HipsContrastbaseline  HipsCorelationbaseline  HipsVariancebaseline  \
# 0                158.27                    0.63                218.30
# 1                147.64                    0.55                173.64
# 2                199.66                    0.55                222.27
# 3                184.21                    0.53                201.55
# 4                233.02                    0.48                229.88
#
#    HipsSumAveragebaseline  HipsSumVariancebaseline  ...  ERCsContrastbaseline  \
# 0                   28.37                   714.92  ...                253.10
# 1                   44.72                   546.93  ...                220.88
# 2                   41.18                   689.44  ...                220.37
# 3                   43.04                   622.01  ...                198.42
# 4                   39.46                   686.51  ...                196.55
#
#    ERCsCorelationbaseline  ERCsVariancebaseline  ERCsSumAveragebaseline  \
# 0                    0.40                208.65                   23.39
# 1                    0.48                215.70                   33.74
# 2                    0.54                232.18                   29.18
# 3                    0.54                220.48                   26.68
# 4                    0.53                210.63                   26.60
#
#    ERCsSumVariancebaseline  ERCsEntropybaseline  ERCsClusterShadebaseline  \
# 0                   581.50                  NaN                  -2568.19
# 1                   641.90                 3.33                   4113.01
# 2                   708.36                 2.87                  -1388.41
# 3                   683.50                 2.77                  -2506.55
# 4                   645.95                 2.72                  -1164.02
#
#    ERCs_thicknessbaseline  ERCsVolumebaseline  HipposcampusVolumebaseline
# 0                    2.31              1176.0                      3047.0
# 1                    2.76              1942.0                      3449.0
# 2                    3.18              2044.0                      3441.0
# 3                    2.68              1959.0                      2875.0
# 4                    2.64              1397.0                      2700.0
#
# [5 rows x 23 columns]

# %%
# Create a correlation dataframe
dataset_correlation = dataset.corr()
dataset_correlation
# Out:
#                               Gender  Ageatscreening  Diagnosis    MMSE0m  \
# Gender                      1.000000       -0.052357   0.007074 -0.011871
# Ageatscreening             -0.052357        1.000000  -0.021664 -0.034351
# Diagnosis                   0.007074       -0.021664   1.000000 -0.791042
# MMSE0m                     -0.011871       -0.034351  -0.791042  1.000000
# HipsASMbaseline            -0.096972        0.191857   0.105424 -0.187896
# HipsContrastbaseline        0.040985        0.098412   0.025240 -0.048156
# HipsCorelationbaseline     -0.130417        0.106403  -0.002117  0.013085
# HipsVariancebaseline       -0.054072        0.170294   0.021558 -0.034618
# HipsSumAveragebaseline      0.116602       -0.220585  -0.105309  0.178445
# HipsSumVariancebaseline    -0.067316        0.178810   0.015023 -0.023768
# HipsEntropybaseline         0.052579       -0.217651  -0.147495  0.235702
# HipsClusterShadebaseline    0.107124       -0.194588  -0.024964  0.077423
# ERCsASMbaseline            -0.047832        0.066728   0.130449 -0.128963
# ERCsContrastbaseline        0.091889        0.127442   0.380916 -0.358900
# ERCsCorelationbaseline     -0.076312       -0.125109  -0.413272  0.420770
# ERCsVariancebaseline        0.079113        0.065098  -0.014621  0.034821
# ERCsSumAveragebaseline      0.001478       -0.043190  -0.170063  0.173287
# ERCsSumVariancebaseline    -0.029498       -0.051866  -0.280820  0.286645
# ERCsEntropybaseline        -0.015934       -0.104894  -0.248268  0.227939
# ERCsClusterShadebaseline   -0.066993       -0.019855  -0.050109  0.058372
# ERCs_thicknessbaseline     -0.048697       -0.144653  -0.371308  0.394412
# ERCsVolumebaseline         -0.227206       -0.166534  -0.498199  0.507684
# HipposcampusVolumebaseline -0.258339       -0.244618  -0.482909  0.440475
#
#                             HipsASMbaseline  HipsContrastbaseline  \
# Gender                            -0.096972              0.040985
# Ageatscreening                     0.191857              0.098412
# Diagnosis                          0.105424              0.025240
# MMSE0m                            -0.187896             -0.048156
# HipsASMbaseline                    1.000000              0.394188
# HipsContrastbaseline               0.394188              1.000000
# HipsCorelationbaseline             0.425678             -0.177471
# HipsVariancebaseline               0.713426              0.600587
# HipsSumAveragebaseline            -0.909876             -0.304364
# HipsSumVariancebaseline            0.706805              0.444900
# HipsEntropybaseline               -0.871200             -0.520228
# HipsClusterShadebaseline          -0.833630             -0.364854
# ERCsASMbaseline                    0.359056              0.193556
# ERCsContrastbaseline               0.058249              0.066435
# ERCsCorelationbaseline            -0.007552              0.064634
# ERCsVariancebaseline               0.089130              0.266862
# ERCsSumAveragebaseline            -0.360918             -0.199217
# ERCsSumVariancebaseline            0.051610              0.206855
# ERCsEntropybaseline               -0.356939             -0.250881
# ERCsClusterShadebaseline          -0.346300             -0.257901
# ERCs_thicknessbaseline            -0.067471              0.045892
# ERCsVolumebaseline                -0.046392             -0.083567
# HipposcampusVolumebaseline        -0.111686             -0.189214
#
#                             HipsCorelationbaseline  HipsVariancebaseline  \
# Gender                                   -0.130417             -0.054072
# Ageatscreening                            0.106403              0.170294
# Diagnosis                                -0.002117              0.021558
# MMSE0m                                    0.013085             -0.034618
# HipsASMbaseline                           0.425678              0.713426
# HipsContrastbaseline                     -0.177471              0.600587
# HipsCorelationbaseline                    1.000000              0.539548
# HipsVariancebaseline                      0.539548              1.000000
# HipsSumAveragebaseline                   -0.487746             -0.677421
# HipsSumVariancebaseline                   0.690933              0.980375
# HipsEntropybaseline                      -0.256500             -0.629234
# HipsClusterShadebaseline                 -0.581110             -0.811857
# ERCsASMbaseline                           0.398697              0.472534
# ERCsContrastbaseline                     -0.104247              0.026461
# ERCsCorelationbaseline                    0.121010              0.119039
# ERCsVariancebaseline                     -0.022922              0.262911
# ERCsSumAveragebaseline                   -0.377311             -0.468006
# ERCsSumVariancebaseline                   0.059852              0.260657
# ERCsEntropybaseline                      -0.312426             -0.452233
# ERCsClusterShadebaseline                 -0.344491             -0.533685
# ERCs_thicknessbaseline                   -0.072388              0.018144
# ERCsVolumebaseline                        0.082555              0.016475
# HipposcampusVolumebaseline                0.124261             -0.069226
#
#                             HipsSumAveragebaseline  HipsSumVariancebaseline  \
# Gender                                    0.116602                -0.067316
# Ageatscreening                           -0.220585                 0.178810
# Diagnosis                                -0.105309                 0.015023
# MMSE0m                                    0.178445                -0.023768
# HipsASMbaseline                          -0.909876                 0.706805
# HipsContrastbaseline                     -0.304364                 0.444900
# HipsCorelationbaseline                   -0.487746                 0.690933
# HipsVariancebaseline                     -0.677421                 0.980375
# HipsSumAveragebaseline                    1.000000                -0.684768
# HipsSumVariancebaseline                  -0.684768                 1.000000
# HipsEntropybaseline                       0.700297                -0.599966
# HipsClusterShadebaseline                  0.932030                -0.826208
# ERCsASMbaseline                          -0.456747                 0.501598
# ERCsContrastbaseline                     -0.034377                -0.005766
# ERCsCorelationbaseline                    0.027616                 0.136790
# ERCsVariancebaseline                      0.028027                 0.222132
# ERCsSumAveragebaseline                    0.477272                -0.487726
# ERCsSumVariancebaseline                   0.061606                 0.244200
# ERCsEntropybaseline                       0.431960                -0.460248
# ERCsClusterShadebaseline                  0.421432                -0.546688
# ERCs_thicknessbaseline                    0.103299                 0.003706
# ERCsVolumebaseline                        0.066608                 0.041156
# HipposcampusVolumebaseline                0.126151                -0.032838
#
#                             ...  ERCsContrastbaseline  ERCsCorelationbaseline  \
# Gender                      ...              0.091889               -0.076312
# Ageatscreening              ...              0.127442               -0.125109
# Diagnosis                   ...              0.380916               -0.413272
# MMSE0m                      ...             -0.358900                0.420770
# HipsASMbaseline             ...              0.058249               -0.007552
# HipsContrastbaseline        ...              0.066435                0.064634
# HipsCorelationbaseline      ...             -0.104247                0.121010
# HipsVariancebaseline        ...              0.026461                0.119039
# HipsSumAveragebaseline      ...             -0.034377                0.027616
# HipsSumVariancebaseline     ...             -0.005766                0.136790
# HipsEntropybaseline         ...             -0.101054                0.034767
# HipsClusterShadebaseline    ...              0.020644               -0.058174
# ERCsASMbaseline             ...             -0.255079                0.219159
# ERCsContrastbaseline        ...              1.000000               -0.870587
# ERCsCorelationbaseline      ...             -0.870587                1.000000
# ERCsVariancebaseline        ...              0.387513               -0.006975
# ERCsSumAveragebaseline      ...              0.214401               -0.162304
# ERCsSumVariancebaseline     ...             -0.174942                0.554610
# ERCsEntropybaseline         ...              0.034542               -0.008862
# ERCsClusterShadebaseline    ...              0.162546               -0.225676
# ERCs_thicknessbaseline      ...             -0.427666                0.477529
# ERCsVolumebaseline          ...             -0.535870                0.572948
# HipposcampusVolumebaseline  ...             -0.456814                0.466563
#
#                             ERCsVariancebaseline  ERCsSumAveragebaseline  \
# Gender                                  0.079113                0.001478
# Ageatscreening                          0.065098               -0.043190
# Diagnosis                              -0.014621               -0.170063
# MMSE0m                                  0.034821                0.173287
# HipsASMbaseline                         0.089130               -0.360918
# HipsContrastbaseline                    0.266862               -0.199217
# HipsCorelationbaseline                 -0.022922               -0.377311
# HipsVariancebaseline                    0.262911               -0.468006
# HipsSumAveragebaseline                  0.028027                0.477272
# HipsSumVariancebaseline                 0.222132               -0.487726
# HipsEntropybaseline                    -0.103151                0.256084
# HipsClusterShadebaseline               -0.021962                0.523219
# ERCsASMbaseline                        -0.259724               -0.939945
# ERCsContrastbaseline                    0.387513                0.214401
# ERCsCorelationbaseline                 -0.006975               -0.162304
# ERCsVariancebaseline                    1.000000                0.319598
# ERCsSumAveragebaseline                  0.319598                1.000000
# ERCsSumVariancebaseline                 0.765934                0.198233
# ERCsEntropybaseline                     0.203237                0.879149
# ERCsClusterShadebaseline                0.051203                0.863924
# ERCs_thicknessbaseline                  0.138561                0.249803
# ERCsVolumebaseline                      0.015969                0.138965
# HipposcampusVolumebaseline             -0.030061                0.125251
#
#                             ERCsSumVariancebaseline  ERCsEntropybaseline  \
# Gender                                    -0.029498            -0.015934
# Ageatscreening                            -0.051866            -0.104894
# Diagnosis                                 -0.280820            -0.248268
# MMSE0m                                     0.286645             0.227939
# HipsASMbaseline                            0.051610            -0.356939
# HipsContrastbaseline                       0.206855            -0.250881
# HipsCorelationbaseline                     0.059852            -0.312426
# HipsVariancebaseline                       0.260657            -0.452233
# HipsSumAveragebaseline                     0.061606             0.431960
# HipsSumVariancebaseline                    0.244200            -0.460248
# HipsEntropybaseline                       -0.030780             0.308545
# HipsClusterShadebaseline                  -0.033167             0.451653
# ERCsASMbaseline                           -0.109434            -0.922261
# ERCsContrastbaseline                      -0.174942             0.034542
# ERCsCorelationbaseline                     0.554610            -0.008862
# ERCsVariancebaseline                       0.765934             0.203237
# ERCsSumAveragebaseline                     0.198233             0.879149
# ERCsSumVariancebaseline                    1.000000             0.254106
# ERCsEntropybaseline                        0.254106             1.000000
# ERCsClusterShadebaseline                  -0.050674             0.673685
# ERCs_thicknessbaseline                     0.439503             0.321774
# ERCsVolumebaseline                         0.379883             0.275609
# HipposcampusVolumebaseline                 0.281172             0.234079
#
#                             ERCsClusterShadebaseline  ERCs_thicknessbaseline  \
# Gender                                     -0.066993               -0.048697
# Ageatscreening                             -0.019855               -0.144653
# Diagnosis                                  -0.050109               -0.371308
# MMSE0m                                      0.058372                0.394412
# HipsASMbaseline                            -0.346300               -0.067471
# HipsContrastbaseline                       -0.257901                0.045892
# HipsCorelationbaseline                     -0.344491               -0.072388
# HipsVariancebaseline                       -0.533685                0.018144
# HipsSumAveragebaseline                      0.421432                0.103299
# HipsSumVariancebaseline                    -0.546688                0.003706
# HipsEntropybaseline                         0.227296                0.099608
# HipsClusterShadebaseline                    0.515280                0.058917
# ERCsASMbaseline                            -0.735237               -0.190901
# ERCsContrastbaseline                        0.162546               -0.427666
# ERCsCorelationbaseline                     -0.225676                0.477529
# ERCsVariancebaseline                        0.051203                0.138561
# ERCsSumAveragebaseline                      0.863924                0.249803
# ERCsSumVariancebaseline                    -0.050674                0.439503
# ERCsEntropybaseline                         0.673685                0.321774
# ERCsClusterShadebaseline                    1.000000                0.127102
# ERCs_thicknessbaseline                      0.127102                1.000000
# ERCsVolumebaseline                          0.017840                0.553280
# HipposcampusVolumebaseline                  0.038769                0.474002
#
#                             ERCsVolumebaseline  HipposcampusVolumebaseline
# Gender                               -0.227206                   -0.258339
# Ageatscreening                       -0.166534                   -0.244618
# Diagnosis                            -0.498199                   -0.482909
# MMSE0m                                0.507684                    0.440475
# HipsASMbaseline                      -0.046392                   -0.111686
# HipsContrastbaseline                 -0.083567                   -0.189214
# HipsCorelationbaseline                0.082555                    0.124261
# HipsVariancebaseline                  0.016475                   -0.069226
# HipsSumAveragebaseline                0.066608                    0.126151
# HipsSumVariancebaseline               0.041156                   -0.032838
# HipsEntropybaseline                   0.144814                    0.232526
# HipsClusterShadebaseline             -0.000616                    0.043770
# ERCsASMbaseline                      -0.102289                   -0.092940
# ERCsContrastbaseline                 -0.535870                   -0.456814
# ERCsCorelationbaseline                0.572948                    0.466563
# ERCsVariancebaseline                  0.015969                   -0.030061
# ERCsSumAveragebaseline                0.138965                    0.125251
# ERCsSumVariancebaseline               0.379883                    0.281172
# ERCsEntropybaseline                   0.275609                    0.234079
# ERCsClusterShadebaseline              0.017840                    0.038769
# ERCs_thicknessbaseline                0.553280                    0.474002
# ERCsVolumebaseline                    1.000000                    0.649944
# HipposcampusVolumebaseline            0.649944                    1.000000
#
# [23 rows x 23 columns]

# %% [markdown]
# Now lets visualize it for better comprehension instead.

# %%
# Plot a heatmap
plt.figure(figsize=(20, 20))  

sns.heatmap(dataset_correlation, 
            annot = True, 
            fmt = ".3f", 
            cmap = "coolwarm",
            square = True,
            linewidths = 0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# This is much better. We can clearly see which variables are correlated in a positive/negative manner. How about we set a threshold and filter only the correlated variables that are above .7 and -.7?
#
# *Check what was the threshold in paper*

# %%
plt.figure(figsize=(20, 20))  

sns.heatmap(dataset_correlation, 
            annot = True, 
            fmt = ".3f", 
            cmap = "coolwarm",
            square = True,
            linewidths = 0.5,
            mask = (dataset_correlation < 0.9) & (dataset_correlation > -0.9))
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Great. Now lets create a simple pair correlation report between each variable

# %%
correlation_pairs = pg.pairwise_corr(data = dataset)

correlation_report = correlation_pairs[correlation_pairs["r"].abs() > 0.9]

correlation_report[["X", "Y", "r"]].sort_values("r", ascending = False)
# Out:
#                           X                         Y         r
# 134    HipsVariancebaseline   HipsSumVariancebaseline  0.980375
# 150  HipsSumAveragebaseline  HipsClusterShadebaseline  0.932030
# 85          HipsASMbaseline    HipsSumAveragebaseline -0.909876
# 203         ERCsASMbaseline       ERCsEntropybaseline -0.922261
# 201         ERCsASMbaseline    ERCsSumAveragebaseline -0.939945

# %%
# Set up the figure with appropriate number of subplots (5)
fig, axs = plt.subplots(2, 3, figsize=(25, 10))

# Remove the unused 6th subplot
fig.delaxes(axs[1][2])

# Plot only the high-correlation pairs you listed
sns.scatterplot(data=dataset, x="HipsSumVariancebaseline", y="HipsVariancebaseline", ax=axs[0][0])
axs[0][0].set_title("HipsSumVariance vs HipsVariance")

sns.scatterplot(data=dataset, x="HipsSumAveragebaseline", y="HipsClusterShadebaseline", ax=axs[0][1])
axs[0][1].set_title("HipsSumAverage vs HipsClusterShade")

sns.scatterplot(data=dataset, x="HipsASMbaseline", y="HipsSumAveragebaseline", ax=axs[0][2])
axs[0][2].set_title("HipsASM vs HipsSumAverage")

sns.scatterplot(data=dataset, x="ERCsASMbaseline", y="ERCsEntropybaseline", ax=axs[1][0])
axs[1][0].set_title("ERCsASM vs ERCsEntropy")

sns.scatterplot(data=dataset, x="ERCsASMbaseline", y="ERCsSumAveragebaseline", ax=axs[1][1])
axs[1][1].set_title("ERCsASM vs ERCsSumAverage")

# Improve layout
plt.tight_layout()
plt.show()

# %% [markdown]
# Now lets plot the positive and negative correlated variables first using scatterplots

# %%
# Plot scatterplot based on the above correlation report
fig, axs = plt.subplots(6,3, figsize = (25, 20))

sns.scatterplot(data = dataset, x = "HipsSumVariancebaseline", y = "HipsVariancebaseline", ax = axs[0][0])
sns.scatterplot(data = dataset, x = "HipsSumAveragebaseline", y = "HipsClusterShadebaseline", ax = axs[0][1])
sns.scatterplot(data = dataset, x = "ERCsSumAveragebaseline", y = "ERCsEntropybaseline", ax = axs[0][2])

sns.scatterplot(data = dataset, x = "ERCsSumAveragebaseline", y = "ERCsClusterShadebaseline", ax = axs[1][0])
sns.scatterplot(data = dataset, x = "ERCsVariancebaseline", y = "ERCsSumVariancebaseline", ax = axs[1][1])
sns.scatterplot(data = dataset, x = "HipsASMbaseline", y = "HipsSumVariancebaseline", ax = axs[1][2])

sns.scatterplot(data = dataset, x = "HipsASMbaseline", y = "HipsVariancebaseline", ax = axs[2][0])
sns.scatterplot(data = dataset, x = "HipsSumAveragebaseline", y = "HipsEntropybaseline", ax = axs[2][1])
sns.scatterplot(data = dataset, x = "ERCsASMbaseline", y = "ERCsClusterShadebaseline", ax = axs[2][2])

sns.scatterplot(data = dataset, x = "Diagnosis", y = "MMSE0m", ax = axs[3][0])
sns.scatterplot(data = dataset, x = "HipsVariancebaseline", y = "HipsClusterShadebaseline", ax = axs[3][1])
sns.scatterplot(data = dataset, x = "HipsSumVariancebaseline", y = "HipsClusterShadebaseline", ax = axs[3][2])

sns.scatterplot(data = dataset, x = "HipsASMbaseline", y = "HipsClusterShadebaseline", ax = axs[4][0])
sns.scatterplot(data = dataset, x = "ERCsContrastbaseline", y = "ERCsCorelationbaseline", ax = axs[4][1])
sns.scatterplot(data = dataset, x = "HipsASMbaseline", y = "HipsEntropybaseline", ax = axs[4][2])

sns.scatterplot(data = dataset, x = "HipsASMbaseline", y = "HipsSumAveragebaseline", ax = axs[5][0])
sns.scatterplot(data = dataset, x = "ERCsASMbaseline", y = "ERCsEntropybaseline", ax = axs[5][1])
sns.scatterplot(data = dataset, x = "ERCsASMbaseline", y = "ERCsSumAveragebaseline", ax = axs[5][2])

plt.grid()

# %% [markdown]
# How about by target?

# %%
# Plot scatterplot based on the above correlation report
fig, axs = plt.subplots(6,3, figsize = (25, 20))

sns.scatterplot(data = dataset, x = "HipsSumVariancebaseline", y = "HipsVariancebaseline", hue="Diagnosis", size="Diagnosis", ax = axs[0][0])
sns.scatterplot(data = dataset, x = "HipsSumAveragebaseline", y = "HipsClusterShadebaseline", hue="Diagnosis", size="Diagnosis",ax = axs[0][1])
sns.scatterplot(data = dataset, x = "ERCsSumAveragebaseline", y = "ERCsEntropybaseline", hue="Diagnosis", size="Diagnosis",ax = axs[0][2])

sns.scatterplot(data = dataset, x = "ERCsSumAveragebaseline", y = "ERCsClusterShadebaseline", hue="Diagnosis", size="Diagnosis",ax = axs[1][0])
sns.scatterplot(data = dataset, x = "ERCsVariancebaseline", y = "ERCsSumVariancebaseline", hue="Diagnosis", size="Diagnosis",ax = axs[1][1])
sns.scatterplot(data = dataset, x = "HipsASMbaseline", y = "HipsSumVariancebaseline", hue="Diagnosis", size="Diagnosis",ax = axs[1][2])

sns.scatterplot(data = dataset, x = "HipsASMbaseline", y = "HipsVariancebaseline", hue="Diagnosis", size="Diagnosis",ax = axs[2][0])
sns.scatterplot(data = dataset, x = "HipsSumAveragebaseline", y = "HipsEntropybaseline", hue="Diagnosis", size="Diagnosis",ax = axs[2][1])
sns.scatterplot(data = dataset, x = "ERCsASMbaseline", y = "ERCsClusterShadebaseline", hue="Diagnosis", size="Diagnosis",ax = axs[2][2])

sns.scatterplot(data = dataset, x = "Diagnosis", y = "MMSE0m", hue="Diagnosis", size="Diagnosis",ax = axs[3][0])
sns.scatterplot(data = dataset, x = "HipsVariancebaseline", y = "HipsClusterShadebaseline", hue="Diagnosis", size="Diagnosis",ax = axs[3][1])
sns.scatterplot(data = dataset, x = "HipsSumVariancebaseline", y = "HipsClusterShadebaseline", hue="Diagnosis", size="Diagnosis",ax = axs[3][2])

sns.scatterplot(data = dataset, x = "HipsASMbaseline", y = "HipsClusterShadebaseline", hue="Diagnosis", size="Diagnosis",ax = axs[4][0])
sns.scatterplot(data = dataset, x = "ERCsContrastbaseline", y = "ERCsCorelationbaseline", hue="Diagnosis", size="Diagnosis",ax = axs[4][1])
sns.scatterplot(data = dataset, x = "HipsASMbaseline", y = "HipsEntropybaseline", hue="Diagnosis", size="Diagnosis",ax = axs[4][2])

sns.scatterplot(data = dataset, x = "HipsASMbaseline", y = "HipsSumAveragebaseline", hue="Diagnosis", size="Diagnosis",ax = axs[5][0])
sns.scatterplot(data = dataset, x = "ERCsASMbaseline", y = "ERCsEntropybaseline", hue="Diagnosis", size="Diagnosis",ax = axs[5][1])
sns.scatterplot(data = dataset, x = "ERCsASMbaseline", y = "ERCsSumAveragebaseline", hue="Diagnosis", size="Diagnosis",ax = axs[5][2])
# Out:
# <Axes: xlabel='ERCsASMbaseline', ylabel='ERCsSumAveragebaseline'>

# %% [markdown]
# This is fantastic! Isnt this more efficient instead of manually checking each column name in the pairplot?
#
# We can now understand how each variable is affected to one another.
#
# But how about the **target**? Lets narrow it down to see which features are strongly correlated with the target

# %%
# Check correlation between each variable and target
correlation_with_target = dataset.corr()["Diagnosis"].sort_values(ascending=False)
correlation_with_target
# Out:
# Diagnosis                     1.000000
# ERCsContrastbaseline          0.380916
# ERCsASMbaseline               0.130449
# HipsASMbaseline               0.105424
# HipsContrastbaseline          0.025240
# HipsVariancebaseline          0.021558
# HipsSumVariancebaseline       0.015023
# Gender                        0.007074
# HipsCorelationbaseline       -0.002117
# ERCsVariancebaseline         -0.014621
# Ageatscreening               -0.021664
# HipsClusterShadebaseline     -0.024964
# ERCsClusterShadebaseline     -0.050109
# HipsSumAveragebaseline       -0.105309
# HipsEntropybaseline          -0.147495
# ERCsSumAveragebaseline       -0.170063
# ERCsEntropybaseline          -0.248268
# ERCsSumVariancebaseline      -0.280820
# ERCs_thicknessbaseline       -0.371308
# ERCsCorelationbaseline       -0.413272
# HipposcampusVolumebaseline   -0.482909
# ERCsVolumebaseline           -0.498199
# MMSE0m                       -0.791042
# Name: Diagnosis, dtype: float64

# %% [markdown]
# Lets plot it

# %%
# Plot target correlaton using bar
plt.figure(figsize=(15,15))

correlation_with_target.plot(kind = "barh", 
                             color = "#5e76fe",
                             edgecolor = "black")
# Out:
# <Axes: >

# %% [markdown]
# I believe we have a solid understanding now regarding our target feature. This will help us a lot when performing feature selection and further understand overall feature importance.
