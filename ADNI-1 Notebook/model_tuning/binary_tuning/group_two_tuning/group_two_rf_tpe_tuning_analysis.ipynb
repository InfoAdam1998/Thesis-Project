# %% [markdown]
# ## TPE Tuning

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from dotenv import load_dotenv
import os

from sklearn.pipeline import Pipeline
from feature_engine.selection import DropConstantFeatures, DropDuplicateFeatures, SelectByShuffling
from feature_engine.selection import DropConstantFeatures, DropDuplicateFeatures, RecursiveFeatureElimination

from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from boruta import BorutaPy
from sklearn.experimental import enable_iterative_imputer
from sklearn.model_selection import train_test_split
from sklearn.impute import IterativeImputer
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import BayesianRidge

from sklearn.tree import DecisionTreeRegressor

import xgboost as xgb
from xgboost import XGBClassifier
from ngboost import NGBClassifier
from ngboost.distns import k_categorical

from sklearn.model_selection import StratifiedKFold, cross_validate, cross_val_score
from sklearn.metrics import accuracy_score, roc_auc_score, recall_score, precision_score, f1_score, balanced_accuracy_score

import optuna

# %%
# Import dataset
load_dotenv()
dataset_path=os.getenv("DATASET_PATH")
dataset = pd.read_csv(dataset_path)
dataset.head()
# Out:
#    RID  Gender  Ageatscreening  Diagnosis  MMSE0m  HipsASMbaseline  \
# 0    3       0         81.3479          3    20.0              NaN
# 1    4       0         67.6904          1    27.0             0.06
# 2    5       0         73.8027          0    29.0             0.10
# 3    8       1         84.5945          0    28.0             0.08
# 4   10       1         73.9726          3    24.0             0.11
#
#    HipsContrastbaseline  HipsCorelationbaseline  HipsVariancebaseline  \
# 0                158.27                    0.63                218.30
# 1                147.64                    0.55                173.64
# 2                199.66                    0.55                222.27
# 3                184.21                    0.53                201.55
# 4                233.02                    0.48                229.88
#
#    HipsSumAveragebaseline  ...  ERCsContrastbaseline  ERCsCorelationbaseline  \
# 0                   28.37  ...                253.10                    0.40
# 1                   44.72  ...                220.88                    0.48
# 2                   41.18  ...                220.37                    0.54
# 3                   43.04  ...                198.42                    0.54
# 4                   39.46  ...                196.55                    0.53
#
#    ERCsVariancebaseline  ERCsSumAveragebaseline  ERCsSumVariancebaseline  \
# 0                208.65                   23.39                   581.50
# 1                215.70                   33.74                   641.90
# 2                232.18                   29.18                   708.36
# 3                220.48                   26.68                   683.50
# 4                210.63                   26.60                   645.95
#
#    ERCsEntropybaseline  ERCsClusterShadebaseline  ERCs_thicknessbaseline  \
# 0                  NaN                  -2568.19                    2.31
# 1                 3.33                   4113.01                    2.76
# 2                 2.87                  -1388.41                    3.18
# 3                 2.77                  -2506.55                    2.68
# 4                 2.72                  -1164.02                    2.64
#
#    ERCsVolumebaseline  HipposcampusVolumebaseline
# 0              1176.0                      3047.0
# 1              1942.0                      3449.0
# 2              2044.0                      3441.0
# 3              1959.0                      2875.0
# 4              1397.0                      2700.0
#
# [5 rows x 24 columns]

# %%
group_one = dataset[dataset["Diagnosis"] == 0]
group_two = dataset[dataset["Diagnosis"] == 3]

combined_group_two = pd.concat([group_one, group_two], ignore_index = True)
combined_group_two["Diagnosis"].unique()
# Out:
# array([0, 3])

# %%
combined_group_two
# Out:
#       RID  Gender  Ageatscreening  Diagnosis  MMSE0m  HipsASMbaseline  \
# 0       5       0         73.8027          0    29.0             0.10
# 1       8       1         84.5945          0    28.0             0.08
# 2      14       1         78.6137          0    29.0             0.12
# 3      15       0         80.9068          0    29.0             0.10
# 4      16       0         65.5205          0    28.0             0.12
# ..    ...     ...             ...        ...     ...              ...
# 319  1201       1         75.6411          3    26.0             0.18
# 320  1221       0         71.2712          3    21.0             0.22
# 321  1248       1         79.8548          3    23.0             0.19
# 322  1253       1         62.7452          3    24.0             0.05
# 323  1257       0         85.0849          3    20.0             0.15
#
#      HipsContrastbaseline  HipsCorelationbaseline  HipsVariancebaseline  \
# 0                  199.66                    0.55                222.27
# 1                  184.21                    0.53                201.55
# 2                  188.33                    0.49                183.76
# 3                  161.28                    0.54                174.53
# 4                  166.97                    0.58                202.96
# ..                    ...                     ...                   ...
# 319                173.84                    0.59                215.04
# 320                174.02                    0.58                211.07
# 321                199.31                    0.56                229.63
# 322                142.05                    0.50                147.12
# 323                147.66                    0.57                180.78
#
#      HipsSumAveragebaseline  ...  ERCsContrastbaseline  \
# 0                     41.18  ...                220.37
# 1                     43.04  ...                198.42
# 2                     39.63  ...                241.64
# 3                     35.94  ...                221.76
# 4                     38.42  ...                228.53
# ..                      ...  ...                   ...
# 319                   33.84  ...                281.15
# 320                   30.56  ...                224.78
# 321                   33.13  ...                220.41
# 322                   46.21  ...                217.38
# 323                   31.82  ...                287.61
#
#      ERCsCorelationbaseline  ERCsVariancebaseline  ERCsSumAveragebaseline  \
# 0                      0.54                232.18                   29.18
# 1                      0.54                220.48                   26.68
# 2                      0.44                226.48                   35.11
# 3                      0.45                   NaN                   30.57
# 4                      0.50                228.72                   28.98
# ..                      ...                   ...                     ...
# 319                    0.37                222.73                   27.94
# 320                    0.47                205.49                   27.36
# 321                    0.48                214.97                   27.16
# 322                    0.51                220.55                   32.54
# 323                    0.39                233.07                   29.95
#
#      ERCsSumVariancebaseline  ERCsEntropybaseline  ERCsClusterShadebaseline  \
# 0                     708.36                 2.87                  -1388.41
# 1                     683.50                 2.77                  -2506.55
# 2                     664.29                 3.10                   8478.33
# 3                        NaN                 3.12                   4287.78
# 4                     686.36                 2.90                  -1381.99
# ..                       ...                  ...                       ...
# 319                   609.75                 2.84                  -1924.49
# 320                   597.20                 2.77                   1146.39
# 321                   639.47                 2.79                   -919.84
# 322                   664.84                 3.09                   5289.89
# 323                   644.68                 2.95                   -467.36
#
#      ERCs_thicknessbaseline  ERCsVolumebaseline  HipposcampusVolumebaseline
# 0                      3.18              2044.0                      3441.0
# 1                      2.68              1959.0                      2875.0
# 2                      3.01              1809.0                      3292.0
# 3                      2.90              2188.0                      3603.0
# 4                      2.73              1829.0                      3695.0
# ..                      ...                 ...                         ...
# 319                    1.94              1112.0                      2705.0
# 320                    2.44              1526.0                      2913.0
# 321                    1.99              1215.0                      2273.0
# 322                    3.27              2321.0                      3739.0
# 323                    2.45              1819.0                      3631.0
#
# [324 rows x 24 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    combined_group_two.drop("Diagnosis", axis=1),  
    combined_group_two["Diagnosis"],  
    test_size=0.3,  
    random_state=42,  
)

X_train.shape, X_test.shape
# Out:
# ((226, 23), (98, 23))

# %%
imputer_bayes = IterativeImputer(
    estimator=BayesianRidge(),
    random_state=42,
)

imputer_bayes.fit(X_train)
X_train_bayes = imputer_bayes.transform(X_train)
X_test_bayes = imputer_bayes.transform(X_test)

# %%
X_train_bayes_t = pd.DataFrame(
    X_train_bayes, 
    columns=X_train.columns, 
    index=X_train.index  # Critical fix
)
X_test_bayes_t = pd.DataFrame(
    X_test_bayes, 
    columns=X_test.columns, 
    index=X_test.index  # Critical fix
)

# %%
pipe = Pipeline([
    ('constant', DropConstantFeatures(tol=1, variables=None, missing_values='raise')),
    ('quasi-constant', DropConstantFeatures(tol=0.998, variables=None, missing_values='raise')),
    ('duplicated', DropDuplicateFeatures()),
])

pipe.fit(X_train_bayes_t)
# Out:
# Pipeline(steps=[('constant', DropConstantFeatures()),
#                 ('quasi-constant', DropConstantFeatures(tol=0.998)),
#                 ('duplicated', DropDuplicateFeatures())])

# %%
X_train_t = pipe.transform(X_train_bayes_t)
X_test_t = pipe.transform(X_test_bayes_t)

X_train_t.shape, X_test_t.shape
# Out:
# ((226, 23), (98, 23))

# %%
model = RandomForestClassifier(random_state=42,)

# let's initialize Boruta
sel = BorutaPy(
    verbose=2,
    estimator=model,
    n_estimators='auto',
)

sel.fit(X_train_t.values, y_train.values)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	23
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	23
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	23
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	23
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	23
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	23
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	23
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	6
# Tentative: 	8
# Rejected: 	9
# Iteration: 	9 / 100
# Confirmed: 	6
# Tentative: 	8
# Rejected: 	9
# Iteration: 	10 / 100
# Confirmed: 	6
# Tentative: 	8
# Rejected: 	9
# Iteration: 	11 / 100
# Confirmed: 	6
# Tentative: 	8
# Rejected: 	9
# Iteration: 	12 / 100
# Confirmed: 	6
# Tentative: 	7
# Rejected: 	10
# Iteration: 	13 / 100
# Confirmed: 	6
# Tentative: 	7
# Rejected: 	10
# Iteration: 	14 / 100
# Confirmed: 	6
# Tentative: 	7
# Rejected: 	10
# Iteration: 	15 / 100
# Confirmed: 	6
# Tentative: 	7
# Rejected: 	10
# Iteration: 	16 / 100
# Confirmed: 	7
# Tentative: 	6
# Rejected: 	10
# Iteration: 	17 / 100
# Confirmed: 	7
# Tentative: 	6
# Rejected: 	10
# Iteration: 	18 / 100
# Confirmed: 	7
# Tentative: 	6
# Rejected: 	10
# Iteration: 	19 / 100
# Confirmed: 	7
# Tentative: 	6
# Rejected: 	10
# Iteration: 	20 / 100
# Confirmed: 	7
# Tentative: 	6
# Rejected: 	10
# Iteration: 	21 / 100
# Confirmed: 	7
# Tentative: 	6
# Rejected: 	10
# Iteration: 	22 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	23 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	24 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	25 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	26 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	27 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	28 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	29 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	30 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	31 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	32 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	33 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	34 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	35 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	36 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	37 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	38 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	39 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	40 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	41 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	42 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	43 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	44 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	45 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	46 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	47 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	48 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	49 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	50 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	51 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	52 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	53 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	54 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	55 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	56 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	57 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	58 / 100
# Confirmed: 	8
# Tentative: 	5
# Rejected: 	10
# Iteration: 	59 / 100
# Confirmed: 	8
# Tentative: 	4
# Rejected: 	11
# Iteration: 	60 / 100
# Confirmed: 	8
# Tentative: 	4
# Rejected: 	11
# Iteration: 	61 / 100
# Confirmed: 	8
# Tentative: 	4
# Rejected: 	11
# Iteration: 	62 / 100
# Confirmed: 	8
# Tentative: 	4
# Rejected: 	11
# Iteration: 	63 / 100
# Confirmed: 	8
# Tentative: 	4
# Rejected: 	11
# Iteration: 	64 / 100
# Confirmed: 	8
# Tentative: 	4
# Rejected: 	11
# Iteration: 	65 / 100
# Confirmed: 	8
# Tentative: 	4
# Rejected: 	11
# Iteration: 	66 / 100
# Confirmed: 	8
# Tentative: 	4
# Rejected: 	11
# Iteration: 	67 / 100
# Confirmed: 	8
# Tentative: 	4
# Rejected: 	11
# Iteration: 	68 / 100
# Confirmed: 	8
# Tentative: 	4
# Rejected: 	11
# Iteration: 	69 / 100
# Confirmed: 	8
# Tentative: 	4
# Rejected: 	11
# Iteration: 	70 / 100
# Confirmed: 	8
# Tentative: 	4
# Rejected: 	11
# Iteration: 	71 / 100
# Confirmed: 	8
# Tentative: 	4
# Rejected: 	11
# Iteration: 	72 / 100
# Confirmed: 	8
# Tentative: 	4
# Rejected: 	11
# Iteration: 	73 / 100
# Confirmed: 	8
# Tentative: 	4
# Rejected: 	11
# Iteration: 	74 / 100
# Confirmed: 	8
# Tentative: 	4
# Rejected: 	11
# Iteration: 	75 / 100
# Confirmed: 	9
# Tentative: 	3
# Rejected: 	11
# Iteration: 	76 / 100
# Confirmed: 	9
# Tentative: 	3
# Rejected: 	11
# Iteration: 	77 / 100
# Confirmed: 	9
# Tentative: 	3
# Rejected: 	11
# Iteration: 	78 / 100
# Confirmed: 	9
# Tentative: 	3
# Rejected: 	11
# Iteration: 	79 / 100
# Confirmed: 	9
# Tentative: 	3
# Rejected: 	11
# Iteration: 	80 / 100
# Confirmed: 	9
# Tentative: 	3
# Rejected: 	11
# Iteration: 	81 / 100
# Confirmed: 	9
# Tentative: 	3
# Rejected: 	11
# Iteration: 	82 / 100
# Confirmed: 	9
# Tentative: 	3
# Rejected: 	11
# Iteration: 	83 / 100
# Confirmed: 	9
# Tentative: 	3
# Rejected: 	11
# Iteration: 	84 / 100
# Confirmed: 	9
# Tentative: 	3
# Rejected: 	11
# Iteration: 	85 / 100
# Confirmed: 	9
# Tentative: 	3
# Rejected: 	11
# Iteration: 	86 / 100
# Confirmed: 	9
# Tentative: 	3
# Rejected: 	11
# Iteration: 	87 / 100
# Confirmed: 	9
# Tentative: 	3
# Rejected: 	11
# Iteration: 	88 / 100
# Confirmed: 	9
# Tentative: 	3
# Rejected: 	11
# Iteration: 	89 / 100
# Confirmed: 	9
# Tentative: 	3
# Rejected: 	11
# Iteration: 	90 / 100
# Confirmed: 	9
# Tentative: 	3
# Rejected: 	11
# Iteration: 	91 / 100
# Confirmed: 	9
# Tentative: 	3
# Rejected: 	11
# Iteration: 	92 / 100
# Confirmed: 	9
# Tentative: 	3
# Rejected: 	11
# Iteration: 	93 / 100
# Confirmed: 	9
# Tentative: 	3
# Rejected: 	11
# Iteration: 	94 / 100
# Confirmed: 	9
# Tentative: 	3
# Rejected: 	11
# Iteration: 	95 / 100
# Confirmed: 	9
# Tentative: 	3
# Rejected: 	11
# Iteration: 	96 / 100
# Confirmed: 	9
# Tentative: 	3
# Rejected: 	11
# Iteration: 	97 / 100
# Confirmed: 	9
# Tentative: 	3
# Rejected: 	11
# Iteration: 	98 / 100
# Confirmed: 	9
# Tentative: 	3
# Rejected: 	11
# Iteration: 	99 / 100
# Confirmed: 	9
# Tentative: 	3
# Rejected: 	11
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	13
# BorutaPy(estimator=RandomForestClassifier(n_estimators=48,
#                                           random_state=RandomState(MT19937) at 0x211B04F3340),
#          n_estimators='auto',
#          random_state=RandomState(MT19937) at 0x211B04F3340, verbose=2)

# %%
# Store selected feature names before transformation
selected_features = X_train_t.columns[sel.support_]
selected_features
# Out:
# Index(['Ageatscreening', 'MMSE0m', 'ERCsContrastbaseline',
#        'ERCsCorelationbaseline', 'ERCsSumVariancebaseline',
#        'ERCsEntropybaseline', 'ERCs_thicknessbaseline', 'ERCsVolumebaseline',
#        'HipposcampusVolumebaseline'],
#       dtype='object')

# %%
# Transform training and test sets using selected features
X_train_t = X_train_t[selected_features]
X_test_t = X_test_t[selected_features]

X_train_t.shape, X_test_t.shape
# Out:
# ((226, 9), (98, 9))

# %% [markdown]
# ## TPE

# %%
from sklearn.preprocessing import LabelEncoder

# 1) Fit a label encoder on the training labels:
le_train = LabelEncoder().fit(y_train)
le_test = LabelEncoder().fit(y_test)

# 2) Transform y_train (and later y_test) to {0,1} internally:
y_train_enc = le_train.transform(y_train)
y_test_enc = le_test.transform(y_test)

# %%
def objective(trial):
    
    
    skf = StratifiedKFold(n_splits=10,
                             shuffle=True,
                             random_state=42,
        )
        
    rf_n_estimators = trial.suggest_int("rf_n_estimators", 100, 500)
    rf_criterion = trial.suggest_categorical("rf_criterion", ['gini', 'entropy'])
    rf_max_depth = trial.suggest_int("rf_max_depth", 3, 4)
    rf_min_samples_split = trial.suggest_float("rf_min_samples_split", 0.001, 0.2)
    rf_max_features = trial.suggest_categorical("rf_max_features", ["sqrt", "log2"])
    rf_min_samples_leaf = trial.suggest_float("rf_min_samples_leaf", 0.001, 0.1)
    rf_class_weight = trial.suggest_categorical("rf_class_weight", ["balanced", "balanced_subsample"])
        
    model = RandomForestClassifier(n_estimators=rf_n_estimators, 
                                   criterion=rf_criterion,
                                   max_depth=rf_max_depth,
                                   min_samples_split=rf_min_samples_split,
                                   max_features=rf_max_features,
                                   min_samples_leaf=rf_min_samples_leaf,
                                   random_state=42, 
                                   class_weight=rf_class_weight)

    score = cross_val_score(model, X_train_t, y_train_enc, scoring="accuracy", cv=skf)
    
    accuracy = score.mean()
    
    return accuracy

# %%
study = optuna.create_study(
    direction="maximize",
    sampler=optuna.samplers.TPESampler(),
)

study.optimize(objective, n_trials=10)
# Out:
# [I 2025-05-13 21:00:07,056] A new study created in memory with name: no-name-ac32584f-1da5-45fb-96ce-2051efcb8ee4
# [I 2025-05-13 21:00:36,845] Trial 0 finished with value: 0.9557312252964427 and parameters: {'rf_n_estimators': 486, 'rf_criterion': 'gini', 'rf_max_depth': 3, 'rf_min_samples_split': 0.03996936857888901, 'rf_max_features': 'log2', 'rf_min_samples_leaf': 0.07982763763626208, 'rf_class_weight': 'balanced_subsample'}. Best is trial 0 with value: 0.9557312252964427.
# [I 2025-05-13 21:00:45,436] Trial 1 finished with value: 0.9644268774703558 and parameters: {'rf_n_estimators': 168, 'rf_criterion': 'gini', 'rf_max_depth': 4, 'rf_min_samples_split': 0.09778534601105351, 'rf_max_features': 'log2', 'rf_min_samples_leaf': 0.0545655292839688, 'rf_class_weight': 'balanced'}. Best is trial 1 with value: 0.9644268774703558.
# [I 2025-05-13 21:00:59,324] Trial 2 finished with value: 0.9644268774703558 and parameters: {'rf_n_estimators': 310, 'rf_criterion': 'gini', 'rf_max_depth': 4, 'rf_min_samples_split': 0.010479606437563481, 'rf_max_features': 'sqrt', 'rf_min_samples_leaf': 0.06257057012369402, 'rf_class_weight': 'balanced_subsample'}. Best is trial 1 with value: 0.9644268774703558.
# [I 2025-05-13 21:01:11,630] Trial 3 finished with value: 0.9644268774703558 and parameters: {'rf_n_estimators': 455, 'rf_criterion': 'entropy', 'rf_max_depth': 3, 'rf_min_samples_split': 0.05181775414048539, 'rf_max_features': 'sqrt', 'rf_min_samples_leaf': 0.044399908215401844, 'rf_class_weight': 'balanced'}. Best is trial 1 with value: 0.9644268774703558.
# [I 2025-05-13 21:01:22,281] Trial 4 finished with value: 0.9644268774703558 and parameters: {'rf_n_estimators': 402, 'rf_criterion': 'gini', 'rf_max_depth': 3, 'rf_min_samples_split': 0.1921289925692125, 'rf_max_features': 'log2', 'rf_min_samples_leaf': 0.05582855980276121, 'rf_class_weight': 'balanced'}. Best is trial 1 with value: 0.9644268774703558.
# [I 2025-05-13 21:01:35,823] Trial 5 finished with value: 0.9644268774703558 and parameters: {'rf_n_estimators': 378, 'rf_criterion': 'entropy', 'rf_max_depth': 4, 'rf_min_samples_split': 0.14414028905432388, 'rf_max_features': 'log2', 'rf_min_samples_leaf': 0.04795159723362486, 'rf_class_weight': 'balanced_subsample'}. Best is trial 1 with value: 0.9644268774703558.
# [I 2025-05-13 21:01:40,897] Trial 6 finished with value: 0.9644268774703558 and parameters: {'rf_n_estimators': 181, 'rf_criterion': 'entropy', 'rf_max_depth': 3, 'rf_min_samples_split': 0.116608718965414, 'rf_max_features': 'sqrt', 'rf_min_samples_leaf': 0.016901741379490975, 'rf_class_weight': 'balanced'}. Best is trial 1 with value: 0.9644268774703558.
# [I 2025-05-13 21:01:53,828] Trial 7 finished with value: 0.9644268774703558 and parameters: {'rf_n_estimators': 402, 'rf_criterion': 'gini', 'rf_max_depth': 3, 'rf_min_samples_split': 0.07861103832765043, 'rf_max_features': 'sqrt', 'rf_min_samples_leaf': 0.04265190003791834, 'rf_class_weight': 'balanced'}. Best is trial 1 with value: 0.9644268774703558.
# [I 2025-05-13 21:02:06,191] Trial 8 finished with value: 0.9644268774703558 and parameters: {'rf_n_estimators': 407, 'rf_criterion': 'entropy', 'rf_max_depth': 3, 'rf_min_samples_split': 0.0356557538543355, 'rf_max_features': 'log2', 'rf_min_samples_leaf': 0.04962476967339884, 'rf_class_weight': 'balanced'}. Best is trial 1 with value: 0.9644268774703558.
# [I 2025-05-13 21:02:10,999] Trial 9 finished with value: 0.9644268774703558 and parameters: {'rf_n_estimators': 178, 'rf_criterion': 'gini', 'rf_max_depth': 3, 'rf_min_samples_split': 0.18351295509705384, 'rf_max_features': 'log2', 'rf_min_samples_leaf': 0.05167591797759745, 'rf_class_weight': 'balanced'}. Best is trial 1 with value: 0.9644268774703558.

# %%
study.best_params
# Out:
# {'rf_n_estimators': 168,
#  'rf_criterion': 'gini',
#  'rf_max_depth': 4,
#  'rf_min_samples_split': 0.09778534601105351,
#  'rf_max_features': 'log2',
#  'rf_min_samples_leaf': 0.0545655292839688,
#  'rf_class_weight': 'balanced'}

# %%
study.best_value
# Out:
# 0.9644268774703558

# %%
r = study.trials_dataframe()
r.head()
# Out:
#    number     value             datetime_start          datetime_complete  \
# 0       0  0.955731 2025-05-13 21:00:07.089202 2025-05-13 21:00:36.828328
# 1       1  0.964427 2025-05-13 21:00:36.845013 2025-05-13 21:00:45.435119
# 2       2  0.964427 2025-05-13 21:00:45.437115 2025-05-13 21:00:59.323209
# 3       3  0.964427 2025-05-13 21:00:59.325210 2025-05-13 21:01:11.630728
# 4       4  0.964427 2025-05-13 21:01:11.631721 2025-05-13 21:01:22.280421
#
#                 duration params_rf_class_weight params_rf_criterion  \
# 0 0 days 00:00:29.739126     balanced_subsample                gini
# 1 0 days 00:00:08.590106               balanced                gini
# 2 0 days 00:00:13.886094     balanced_subsample                gini
# 3 0 days 00:00:12.305518               balanced             entropy
# 4 0 days 00:00:10.648700               balanced                gini
#
#    params_rf_max_depth params_rf_max_features  params_rf_min_samples_leaf  \
# 0                    3                   log2                    0.079828
# 1                    4                   log2                    0.054566
# 2                    4                   sqrt                    0.062571
# 3                    3                   sqrt                    0.044400
# 4                    3                   log2                    0.055829
#
#    params_rf_min_samples_split  params_rf_n_estimators     state
# 0                     0.039969                     486  COMPLETE
# 1                     0.097785                     168  COMPLETE
# 2                     0.010480                     310  COMPLETE
# 3                     0.051818                     455  COMPLETE
# 4                     0.192129                     402  COMPLETE

# %%
fig = optuna.visualization.matplotlib.plot_optimization_history(study)
# Out:
# C:\Users\steve\AppData\Local\Temp\ipykernel_17952\2278197192.py:1: ExperimentalWarning: plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.
#   fig = optuna.visualization.matplotlib.plot_optimization_history(study)

# %%
optuna.visualization.matplotlib.plot_param_importances(study)
# Out:
# C:\Users\steve\AppData\Local\Temp\ipykernel_17952\1036994904.py:1: ExperimentalWarning: plot_param_importances is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_param_importances(study)
# <Axes: title={'left': 'Hyperparameter Importances'}, xlabel='Hyperparameter Importance', ylabel='Hyperparameter'>

# %%
optuna.visualization.matplotlib.plot_slice(
    study,
    params=["rf_n_estimators", "rf_criterion", "rf_max_depth", 
            'rf_min_samples_split', 'rf_max_features', 'rf_min_samples_leaf',
            'rf_class_weight'],
)
# Out:
# C:\Users\steve\AppData\Local\Temp\ipykernel_17952\3879122787.py:1: ExperimentalWarning: plot_slice is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_slice(
# array([<Axes: xlabel='rf_class_weight', ylabel='Objective Value'>,
#        <Axes: xlabel='rf_criterion'>, <Axes: xlabel='rf_max_depth'>,
#        <Axes: xlabel='rf_max_features'>,
#        <Axes: xlabel='rf_min_samples_leaf'>,
#        <Axes: xlabel='rf_min_samples_split'>,
#        <Axes: xlabel='rf_n_estimators'>], dtype=object)

# %%
optuna.visualization.matplotlib.plot_edf([study])
# Out:
# C:\Users\steve\AppData\Local\Temp\ipykernel_17952\2601326980.py:1: ExperimentalWarning: plot_edf is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_edf([study])
# <Axes: title={'center': 'Empirical Distribution Function Plot'}, xlabel='Objective Value', ylabel='Cumulative Probability'>

# %% [markdown]
# ## Classification

# %%
def run_model(classifier_name, sel_method, X_train, y_train):
        
        model = RandomForestClassifier(n_estimators=study.best_params["rf_n_estimators"], 
                                       criterion=study.best_params["rf_criterion"],
                                       max_depth=study.best_params["rf_max_depth"],
                                       min_samples_split=study.best_params["rf_min_samples_split"],
                                       max_features=study.best_params["rf_max_features"],
                                       min_samples_leaf=study.best_params["rf_min_samples_leaf"],
                                       random_state=42, 
                                       class_weight=study.best_params["rf_class_weight"])
        
        if sel_method == "Boruta":
                sel_method = "Boruta" 
        else: 
                sel_method = "Complete"
        
        skf = StratifiedKFold(n_splits=10,
                             shuffle=True,
                             random_state=42,
        )
        
        cross_val_results = cross_validate(model,
                                           X_train,
                                           y_train,
                                           cv=skf,
                                           scoring="balanced_accuracy",
                                           return_train_score=True,
        )
               
        # Calculate the metrics for training and testing
        mean_train = [round(np.mean(cross_val_results["train_score"]), 3)]
        std_train = [round(np.std(cross_val_results["train_score"]), 3)]
        mean_test = [round(np.mean(cross_val_results["test_score"]), 3)]
        std_test = [round(np.std(cross_val_results["test_score"]), 3)]
        time = round(np.mean(cross_val_results["fit_time"]), 3)
                
        cv_metrics_df = pd.DataFrame({
                "Feature Selection": sel_method,
                "Classifier": classifier_name,
                "Fit Time": time,
                "Total Features": len(X_train.columns),
                "Metric": "balanced_accuracy",
                "Mean Train": mean_train,
                "Std Train": std_train,
                "Mean Test": mean_test,
                "Std Test": std_test,
        })
        
        fit_model = model.fit(X_train, y_train)
        
        return fit_model, cv_metrics_df

# %%
trained_rf_n, metrics_rf_n = run_model("Random Forest", "Complete", X_train_bayes_t, y_train_enc)
trained_rf_t, metrics_rf_t = run_model("Random Forest", "Boruta", X_train_t, y_train_enc)

# %%
validation_df = pd.concat([metrics_rf_n, metrics_rf_t])
validation_df_report = validation_df.set_index(["Classifier", "Metric", "Feature Selection", "Fit Time", "Total Features"])
validation_df_report
# Out:
#                                                                            Mean Train  \
# Classifier    Metric            Feature Selection Fit Time Total Features
# Random Forest balanced_accuracy Complete          0.544    23                   0.968
#                                 Boruta            0.439    9                    0.978
#
#                                                                            Std Train  \
# Classifier    Metric            Feature Selection Fit Time Total Features
# Random Forest balanced_accuracy Complete          0.544    23                  0.007
#                                 Boruta            0.439    9                   0.003
#
#                                                                            Mean Test  \
# Classifier    Metric            Feature Selection Fit Time Total Features
# Random Forest balanced_accuracy Complete          0.544    23                  0.939
#                                 Boruta            0.439    9                   0.967
#
#                                                                            Std Test
# Classifier    Metric            Feature Selection Fit Time Total Features
# Random Forest balanced_accuracy Complete          0.544    23                 0.055
#                                 Boruta            0.439    9                  0.035

# %%
import time

def eval_model(classifier_name, model, X_train, X_test, y_train, y_test):
        
        start_time = time.time()
        # Get predicted probabilities for ROC AUC
        pred_train_proba = model.predict_proba(X_train)
        pred_test_proba = model.predict_proba(X_test)
        
        # Get predicted accuracy values
        pred_train = model.predict(X_train)
        pred_test = model.predict(X_test)
        
        # Calculate metrics
        metrics_train = {
                "accuracy": round(accuracy_score(y_train, pred_train), 3),
                "balanced_accuracy": round(balanced_accuracy_score(y_train, pred_train), 3),
                "precision": round(precision_score(y_train, pred_train), 3),
                "recall": round(recall_score(y_train, pred_train), 3),
                "f1": round(f1_score(y_train, pred_train), 3),
                "roc_auc_ovr": round(roc_auc_score(y_train, pred_train_proba[:, 1]),3,),
        }
        
        metrics_test = {
                "accuracy": round(accuracy_score(y_test, pred_test), 3),
                "balanced_accuracy": round(balanced_accuracy_score(y_test, pred_test), 3),
                "precision": round(precision_score(y_test, pred_test), 3),
                "recall": round(recall_score(y_test, pred_test), 3),
                "f1": round(f1_score(y_test, pred_test), 3),
                "roc_auc_ovr": round(roc_auc_score(y_test, pred_test_proba[:, 1]), 3,),
        }
                
        elapsed_time = time.time() - start_time
    
        # Create the DataFrame without additional rounding
        pred_metrics_df = pd.DataFrame({
                "Feature Selection": "Boruta",
                "Classifier": classifier_name,
                "Classification Time": round(elapsed_time, 3),
                "Total Features": len(X_train.columns),
                "Metric": metrics_train.keys(),
                "Train data": metrics_train.values(),
                "Test data": metrics_test.values(),
    })
        
        return pred_metrics_df

# %%
results = "all"
prediction_df_report = None

if results == "all":
    
    pred_rf_n = eval_model("Random Forest", trained_rf_n, X_train_bayes_t, X_test_bayes_t, y_train_enc, y_test_enc)
    pred_rf_t = eval_model("Random Forest", trained_rf_t, X_train_t, X_test_t, y_train_enc, y_test_enc)
    
    prediction_df = pd.concat([pred_rf_n, pred_rf_t])
    prediction_df_report = prediction_df.set_index(["Feature Selection", "Classifier", "Classification Time", "Total Features", "Metric"])
        
elif results == "filtered":
    
    pred_rf_t = eval_model("Random Forest", trained_rf_t, X_train_t, X_test_t, y_train_enc, y_test_enc)
  
    prediction_df = pd.concat([pred_rf_t])
    prediction_df_report = prediction_df.set_index(["Feature Selection", "Classifier", "Classification Time", "Total Features", "Metric"])

prediction_df_report
# Out:
#                                                                                       Train data  \
# Feature Selection Classifier    Classification Time Total Features Metric
# Boruta            Random Forest 0.194               23             accuracy                0.960
#                                                                    balanced_accuracy       0.961
#                                                                    precision               0.936
#                                                                    recall                  0.967
#                                                                    f1                      0.951
#                                                                    roc_auc_ovr             0.997
#                                 0.153               9              accuracy                0.978
#                                                                    balanced_accuracy       0.980
#                                                                    precision               0.957
#                                                                    recall                  0.989
#                                                                    f1                      0.973
#                                                                    roc_auc_ovr             0.998
#
#                                                                                       Test data
# Feature Selection Classifier    Classification Time Total Features Metric
# Boruta            Random Forest 0.194               23             accuracy               0.939
#                                                                    balanced_accuracy      0.936
#                                                                    precision              0.923
#                                                                    recall                 0.923
#                                                                    f1                     0.923
#                                                                    roc_auc_ovr            0.983
#                                 0.153               9              accuracy               0.980
#                                                                    balanced_accuracy      0.983
#                                                                    precision              0.951
#                                                                    recall                 1.000
#                                                                    f1                     0.975
#                                                                    roc_auc_ovr            0.993

# %% [markdown]
# ### Export model

# %%
trained_rf_t
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=4,
#                        max_features='log2', min_samples_leaf=0.0545655292839688,
#                        min_samples_split=0.09778534601105351, n_estimators=168,
#                        random_state=42)

# %%
import pickle

with open("rf_model_group_two.pkl", "wb") as file:
    pickle.dump(trained_rf_t, file)
    
print("Random Forest model saved successfully!")
# Out:
# Random Forest model saved successfully!
