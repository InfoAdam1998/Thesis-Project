# %% [markdown]
# ## Correlation Analysis
#
# Lets check the correlation between variables

# %%
# Import basic libraries for EDA
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pingouin as pg
from dotenv import load_dotenv
import os

# %%
# Import dataset
load_dotenv()
dataset_path=os.getenv("DATASET_PATH")
dataset = pd.read_csv(dataset_path)
dataset.head()
# Out:
#    RID  Gender  Ageatscreening  Diagnosis  MMSE0m  HipsASMbaseline  \
# 0    3       0         81.3479          3    20.0              NaN
# 1    4       0         67.6904          1    27.0             0.06
# 2    5       0         73.8027          0    29.0             0.10
# 3    8       1         84.5945          0    28.0             0.08
# 4   10       1         73.9726          3    24.0             0.11
#
#    HipsContrastbaseline  HipsCorelationbaseline  HipsVariancebaseline  \
# 0                158.27                    0.63                218.30
# 1                147.64                    0.55                173.64
# 2                199.66                    0.55                222.27
# 3                184.21                    0.53                201.55
# 4                233.02                    0.48                229.88
#
#    HipsSumAveragebaseline  ...  ERCsContrastbaseline  ERCsCorelationbaseline  \
# 0                   28.37  ...                253.10                    0.40
# 1                   44.72  ...                220.88                    0.48
# 2                   41.18  ...                220.37                    0.54
# 3                   43.04  ...                198.42                    0.54
# 4                   39.46  ...                196.55                    0.53
#
#    ERCsVariancebaseline  ERCsSumAveragebaseline  ERCsSumVariancebaseline  \
# 0                208.65                   23.39                   581.50
# 1                215.70                   33.74                   641.90
# 2                232.18                   29.18                   708.36
# 3                220.48                   26.68                   683.50
# 4                210.63                   26.60                   645.95
#
#    ERCsEntropybaseline  ERCsClusterShadebaseline  ERCs_thicknessbaseline  \
# 0                  NaN                  -2568.19                    2.31
# 1                 3.33                   4113.01                    2.76
# 2                 2.87                  -1388.41                    3.18
# 3                 2.77                  -2506.55                    2.68
# 4                 2.72                  -1164.02                    2.64
#
#    ERCsVolumebaseline  HipposcampusVolumebaseline
# 0              1176.0                      3047.0
# 1              1942.0                      3449.0
# 2              2044.0                      3441.0
# 3              1959.0                      2875.0
# 4              1397.0                      2700.0
#
# [5 rows x 24 columns]

# %%
# Create a correlation dataframe
dataset_correlation = dataset.corr()
dataset_correlation
# Out:
#                                  RID    Gender  Ageatscreening  Diagnosis  \
# RID                         1.000000  0.080148       -0.009286   0.137855
# Gender                      0.080148  1.000000       -0.063439   0.026303
# Ageatscreening             -0.009286 -0.063439        1.000000  -0.010435
# Diagnosis                   0.137855  0.026303       -0.010435   1.000000
# MMSE0m                     -0.074361 -0.024733       -0.046081  -0.769074
# HipsASMbaseline             0.022206 -0.114271        0.171116   0.161644
# HipsContrastbaseline        0.011583  0.047816        0.081108   0.050656
# HipsCorelationbaseline      0.002456 -0.126088        0.080212   0.028586
# HipsVariancebaseline        0.021008 -0.058449        0.138873   0.076798
# HipsSumAveragebaseline     -0.024147  0.126187       -0.209063  -0.150871
# HipsSumVariancebaseline     0.006230 -0.065591        0.141446   0.064319
# HipsEntropybaseline        -0.009197  0.059070       -0.201422  -0.190084
# HipsClusterShadebaseline    0.002780  0.115583       -0.177423  -0.079930
# ERCsASMbaseline            -0.017126 -0.055925        0.067819   0.131076
# ERCsContrastbaseline        0.085044  0.103712        0.108401   0.371118
# ERCsCorelationbaseline     -0.067923 -0.106451       -0.128812  -0.396683
# ERCsVariancebaseline        0.074849  0.063666        0.003857  -0.002202
# ERCsSumAveragebaseline      0.022301  0.022149       -0.051587  -0.176878
# ERCsSumVariancebaseline     0.027127 -0.041507       -0.087386  -0.259807
# ERCsEntropybaseline        -0.010068  0.001777       -0.102410  -0.251645
# ERCsClusterShadebaseline   -0.012835 -0.037031       -0.004624  -0.109483
# ERCs_thicknessbaseline      0.000363 -0.030360       -0.172548  -0.386723
# ERCsVolumebaseline         -0.031664 -0.225969       -0.166680  -0.490807
# HipposcampusVolumebaseline -0.088220 -0.253714       -0.243270  -0.481997
#
#                               MMSE0m  HipsASMbaseline  HipsContrastbaseline  \
# RID                        -0.074361         0.022206              0.011583
# Gender                     -0.024733        -0.114271              0.047816
# Ageatscreening             -0.046081         0.171116              0.081108
# Diagnosis                  -0.769074         0.161644              0.050656
# MMSE0m                      1.000000        -0.180974             -0.043255
# HipsASMbaseline            -0.180974         1.000000              0.369151
# HipsContrastbaseline       -0.043255         0.369151              1.000000
# HipsCorelationbaseline      0.003445         0.438901             -0.213878
# HipsVariancebaseline       -0.035550         0.707023              0.585634
# HipsSumAveragebaseline      0.176276        -0.908694             -0.290294
# HipsSumVariancebaseline    -0.029371         0.708751              0.426734
# HipsEntropybaseline         0.221749        -0.874186             -0.493175
# HipsClusterShadebaseline    0.080981        -0.830744             -0.354140
# ERCsASMbaseline            -0.138909         0.381475              0.183494
# ERCsContrastbaseline       -0.309767         0.034664              0.096635
# ERCsCorelationbaseline      0.379750         0.007291              0.022449
# ERCsVariancebaseline        0.050553         0.041890              0.247559
# ERCsSumAveragebaseline      0.180286        -0.389602             -0.198925
# ERCsSumVariancebaseline     0.270776         0.013679              0.164140
# ERCsEntropybaseline         0.224791        -0.381533             -0.240574
# ERCsClusterShadebaseline    0.066390        -0.372764             -0.256628
# ERCs_thicknessbaseline      0.367094        -0.099781              0.011580
# ERCsVolumebaseline          0.476335        -0.070861             -0.113079
# HipposcampusVolumebaseline  0.411464        -0.131030             -0.227186
#
#                             HipsCorelationbaseline  HipsVariancebaseline  \
# RID                                       0.002456              0.021008
# Gender                                   -0.126088             -0.058449
# Ageatscreening                            0.080212              0.138873
# Diagnosis                                 0.028586              0.076798
# MMSE0m                                    0.003445             -0.035550
# HipsASMbaseline                           0.438901              0.707023
# HipsContrastbaseline                     -0.213878              0.585634
# HipsCorelationbaseline                    1.000000              0.530166
# HipsVariancebaseline                      0.530166              1.000000
# HipsSumAveragebaseline                   -0.491929             -0.676242
# HipsSumVariancebaseline                   0.691032              0.979153
# HipsEntropybaseline                      -0.264154             -0.628380
# HipsClusterShadebaseline                 -0.577808             -0.810661
# ERCsASMbaseline                           0.403005              0.476662
# ERCsContrastbaseline                     -0.128572              0.028061
# ERCsCorelationbaseline                    0.144517              0.105554
# ERCsVariancebaseline                     -0.049317              0.225321
# ERCsSumAveragebaseline                   -0.382378             -0.478412
# ERCsSumVariancebaseline                   0.060078              0.222544
# ERCsEntropybaseline                      -0.319003             -0.456672
# ERCsClusterShadebaseline                 -0.353171             -0.542723
# ERCs_thicknessbaseline                   -0.057790             -0.010743
# ERCsVolumebaseline                        0.081994             -0.010580
# HipposcampusVolumebaseline                0.117134             -0.106391
#
#                             HipsSumAveragebaseline  ...  ERCsContrastbaseline  \
# RID                                      -0.024147  ...              0.085044
# Gender                                    0.126187  ...              0.103712
# Ageatscreening                           -0.209063  ...              0.108401
# Diagnosis                                -0.150871  ...              0.371118
# MMSE0m                                    0.176276  ...             -0.309767
# HipsASMbaseline                          -0.908694  ...              0.034664
# HipsContrastbaseline                     -0.290294  ...              0.096635
# HipsCorelationbaseline                   -0.491929  ...             -0.128572
# HipsVariancebaseline                     -0.676242  ...              0.028061
# HipsSumAveragebaseline                    1.000000  ...             -0.025844
# HipsSumVariancebaseline                  -0.683653  ...             -0.019246
# HipsEntropybaseline                       0.706447  ...             -0.085406
# HipsClusterShadebaseline                  0.932525  ...              0.021455
# ERCsASMbaseline                          -0.462969  ...             -0.263302
# ERCsContrastbaseline                     -0.025844  ...              1.000000
# ERCsCorelationbaseline                    0.026581  ...             -0.867886
# ERCsVariancebaseline                      0.058279  ...              0.393596
# ERCsSumAveragebaseline                    0.488416  ...              0.216315
# ERCsSumVariancebaseline                   0.088224  ...             -0.167110
# ERCsEntropybaseline                       0.443482  ...              0.031505
# ERCsClusterShadebaseline                  0.436390  ...              0.142173
# ERCs_thicknessbaseline                    0.131429  ...             -0.416948
# ERCsVolumebaseline                        0.086546  ...             -0.539241
# HipposcampusVolumebaseline                0.145818  ...             -0.451462
#
#                             ERCsCorelationbaseline  ERCsVariancebaseline  \
# RID                                      -0.067923              0.074849
# Gender                                   -0.106451              0.063666
# Ageatscreening                           -0.128812              0.003857
# Diagnosis                                -0.396683             -0.002202
# MMSE0m                                    0.379750              0.050553
# HipsASMbaseline                           0.007291              0.041890
# HipsContrastbaseline                      0.022449              0.247559
# HipsCorelationbaseline                    0.144517             -0.049317
# HipsVariancebaseline                      0.105554              0.225321
# HipsSumAveragebaseline                    0.026581              0.058279
# HipsSumVariancebaseline                   0.142325              0.181443
# HipsEntropybaseline                       0.033247             -0.057027
# HipsClusterShadebaseline                 -0.049559              0.007772
# ERCsASMbaseline                           0.227626             -0.283672
# ERCsContrastbaseline                     -0.867886              0.393596
# ERCsCorelationbaseline                    1.000000             -0.012209
# ERCsVariancebaseline                     -0.012209              1.000000
# ERCsSumAveragebaseline                   -0.166298              0.341000
# ERCsSumVariancebaseline                   0.548161              0.765535
# ERCsEntropybaseline                      -0.012185              0.226257
# ERCsClusterShadebaseline                 -0.201695              0.057468
# ERCs_thicknessbaseline                    0.481813              0.160764
# ERCsVolumebaseline                        0.578714              0.029936
# HipposcampusVolumebaseline                0.478645             -0.004510
#
#                             ERCsSumAveragebaseline  ERCsSumVariancebaseline  \
# RID                                       0.022301                 0.027127
# Gender                                    0.022149                -0.041507
# Ageatscreening                           -0.051587                -0.087386
# Diagnosis                                -0.176878                -0.259807
# MMSE0m                                    0.180286                 0.270776
# HipsASMbaseline                          -0.389602                 0.013679
# HipsContrastbaseline                     -0.198925                 0.164140
# HipsCorelationbaseline                   -0.382378                 0.060078
# HipsVariancebaseline                     -0.478412                 0.222544
# HipsSumAveragebaseline                    0.488416                 0.088224
# HipsSumVariancebaseline                  -0.502846                 0.215912
# HipsEntropybaseline                       0.291176                 0.009327
# HipsClusterShadebaseline                  0.531669                -0.004547
# ERCsASMbaseline                          -0.939054                -0.121266
# ERCsContrastbaseline                      0.216315                -0.167110
# ERCsCorelationbaseline                   -0.166298                 0.548161
# ERCsVariancebaseline                      0.341000                 0.765535
# ERCsSumAveragebaseline                    1.000000                 0.212369
# ERCsSumVariancebaseline                   0.212369                 1.000000
# ERCsEntropybaseline                       0.878621                 0.263142
# ERCsClusterShadebaseline                  0.861514                -0.031372
# ERCs_thicknessbaseline                    0.265741                 0.454154
# ERCsVolumebaseline                        0.146721                 0.385914
# HipposcampusVolumebaseline                0.143269                 0.300006
#
#                             ERCsEntropybaseline  ERCsClusterShadebaseline  \
# RID                                   -0.010068                 -0.012835
# Gender                                 0.001777                 -0.037031
# Ageatscreening                        -0.102410                 -0.004624
# Diagnosis                             -0.251645                 -0.109483
# MMSE0m                                 0.224791                  0.066390
# HipsASMbaseline                       -0.381533                 -0.372764
# HipsContrastbaseline                  -0.240574                 -0.256628
# HipsCorelationbaseline                -0.319003                 -0.353171
# HipsVariancebaseline                  -0.456672                 -0.542723
# HipsSumAveragebaseline                 0.443482                  0.436390
# HipsSumVariancebaseline               -0.467813                 -0.556266
# HipsEntropybaseline                    0.335679                  0.255240
# HipsClusterShadebaseline               0.460874                  0.527080
# ERCsASMbaseline                       -0.920889                 -0.726813
# ERCsContrastbaseline                   0.031505                  0.142173
# ERCsCorelationbaseline                -0.012185                 -0.201695
# ERCsVariancebaseline                   0.226257                  0.057468
# ERCsSumAveragebaseline                 0.878621                  0.861514
# ERCsSumVariancebaseline                0.263142                 -0.031372
# ERCsEntropybaseline                    1.000000                  0.672031
# ERCsClusterShadebaseline               0.672031                  1.000000
# ERCs_thicknessbaseline                 0.334115                  0.159460
# ERCsVolumebaseline                     0.282003                  0.045513
# HipposcampusVolumebaseline             0.246884                  0.074705
#
#                             ERCs_thicknessbaseline  ERCsVolumebaseline  \
# RID                                       0.000363           -0.031664
# Gender                                   -0.030360           -0.225969
# Ageatscreening                           -0.172548           -0.166680
# Diagnosis                                -0.386723           -0.490807
# MMSE0m                                    0.367094            0.476335
# HipsASMbaseline                          -0.099781           -0.070861
# HipsContrastbaseline                      0.011580           -0.113079
# HipsCorelationbaseline                   -0.057790            0.081994
# HipsVariancebaseline                     -0.010743           -0.010580
# HipsSumAveragebaseline                    0.131429            0.086546
# HipsSumVariancebaseline                  -0.010335            0.020221
# HipsEntropybaseline                       0.127076            0.164955
# HipsClusterShadebaseline                  0.083154            0.020170
# ERCsASMbaseline                          -0.201403           -0.106183
# ERCsContrastbaseline                     -0.416948           -0.539241
# ERCsCorelationbaseline                    0.481813            0.578714
# ERCsVariancebaseline                      0.160764            0.029936
# ERCsSumAveragebaseline                    0.265741            0.146721
# ERCsSumVariancebaseline                   0.454154            0.385914
# ERCsEntropybaseline                       0.334115            0.282003
# ERCsClusterShadebaseline                  0.159460            0.045513
# ERCs_thicknessbaseline                    1.000000            0.563442
# ERCsVolumebaseline                        0.563442            1.000000
# HipposcampusVolumebaseline                0.494985            0.654659
#
#                             HipposcampusVolumebaseline
# RID                                          -0.088220
# Gender                                       -0.253714
# Ageatscreening                               -0.243270
# Diagnosis                                    -0.481997
# MMSE0m                                        0.411464
# HipsASMbaseline                              -0.131030
# HipsContrastbaseline                         -0.227186
# HipsCorelationbaseline                        0.117134
# HipsVariancebaseline                         -0.106391
# HipsSumAveragebaseline                        0.145818
# HipsSumVariancebaseline                      -0.058046
# HipsEntropybaseline                           0.251120
# HipsClusterShadebaseline                      0.073267
# ERCsASMbaseline                              -0.106818
# ERCsContrastbaseline                         -0.451462
# ERCsCorelationbaseline                        0.478645
# ERCsVariancebaseline                         -0.004510
# ERCsSumAveragebaseline                        0.143269
# ERCsSumVariancebaseline                       0.300006
# ERCsEntropybaseline                           0.246884
# ERCsClusterShadebaseline                      0.074705
# ERCs_thicknessbaseline                        0.494985
# ERCsVolumebaseline                            0.654659
# HipposcampusVolumebaseline                    1.000000
#
# [24 rows x 24 columns]

# %% [markdown]
# Now lets visualize it for better comprehension instead.

# %%
# Plot a heatmap
plt.figure(figsize=(20, 20))  

sns.heatmap(dataset_correlation, 
            annot = True, 
            fmt = ".3f", 
            cmap = "coolwarm",
            square = True,
            linewidths = 0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# This is much better. We can clearly see which variables are correlated in a positive/negative manner. How about we set a threshold and filter only the correlated variables that are above .7 and -.7?
#
# *Check what was the threshold in paper*

# %%
plt.figure(figsize=(20, 20))  

sns.heatmap(dataset_correlation, 
            annot = True, 
            fmt = ".3f", 
            cmap = "coolwarm",
            square = True,
            linewidths = 0.5,
            mask = (dataset_correlation < 0.7) & (dataset_correlation > -0.7))
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Great. Now lets create a simple pair correlation report between each variable

# %%
correlation_pairs = pg.pairwise_corr(data = dataset)

correlation_report = correlation_pairs[correlation_pairs["r"].abs() > 0.7]

correlation_report[["X", "Y", "r"]].sort_values("r", ascending = False)
# Out:
#                            X                         Y         r
# 157     HipsVariancebaseline   HipsSumVariancebaseline  0.979153
# 173   HipsSumAveragebaseline  HipsClusterShadebaseline  0.932525
# 256   ERCsSumAveragebaseline       ERCsEntropybaseline  0.878621
# 257   ERCsSumAveragebaseline  ERCsClusterShadebaseline  0.861514
# 249     ERCsVariancebaseline   ERCsSumVariancebaseline  0.765535
# 109          HipsASMbaseline   HipsSumVariancebaseline  0.708751
# 107          HipsASMbaseline      HipsVariancebaseline  0.707023
# 172   HipsSumAveragebaseline       HipsEntropybaseline  0.706447
# 227          ERCsASMbaseline  ERCsClusterShadebaseline -0.726813
# 66                 Diagnosis                    MMSE0m -0.769074
# 159     HipsVariancebaseline  HipsClusterShadebaseline -0.810661
# 186  HipsSumVariancebaseline  HipsClusterShadebaseline -0.823130
# 111          HipsASMbaseline  HipsClusterShadebaseline -0.830744
# 231     ERCsContrastbaseline    ERCsCorelationbaseline -0.867886
# 110          HipsASMbaseline       HipsEntropybaseline -0.874186
# 108          HipsASMbaseline    HipsSumAveragebaseline -0.908694
# 226          ERCsASMbaseline       ERCsEntropybaseline -0.920889
# 224          ERCsASMbaseline    ERCsSumAveragebaseline -0.939054

# %% [markdown]
# Now lets plot the positive and negative correlated variables first using scatterplots

# %%
# Plot scatterplot based on the above correlation report
fig, axs = plt.subplots(6,3, figsize = (25, 20))

sns.scatterplot(data = dataset, x = "HipsSumVariancebaseline", y = "HipsVariancebaseline", ax = axs[0][0])
sns.scatterplot(data = dataset, x = "HipsSumAveragebaseline", y = "HipsClusterShadebaseline", ax = axs[0][1])
sns.scatterplot(data = dataset, x = "ERCsSumAveragebaseline", y = "ERCsEntropybaseline", ax = axs[0][2])

sns.scatterplot(data = dataset, x = "ERCsSumAveragebaseline", y = "ERCsClusterShadebaseline", ax = axs[1][0])
sns.scatterplot(data = dataset, x = "ERCsVariancebaseline", y = "ERCsSumVariancebaseline", ax = axs[1][1])
sns.scatterplot(data = dataset, x = "HipsASMbaseline", y = "HipsSumVariancebaseline", ax = axs[1][2])

sns.scatterplot(data = dataset, x = "HipsASMbaseline", y = "HipsVariancebaseline", ax = axs[2][0])
sns.scatterplot(data = dataset, x = "HipsSumAveragebaseline", y = "HipsEntropybaseline", ax = axs[2][1])
sns.scatterplot(data = dataset, x = "ERCsASMbaseline", y = "ERCsClusterShadebaseline", ax = axs[2][2])

sns.scatterplot(data = dataset, x = "Diagnosis", y = "MMSE0m", ax = axs[3][0])
sns.scatterplot(data = dataset, x = "HipsVariancebaseline", y = "HipsClusterShadebaseline", ax = axs[3][1])
sns.scatterplot(data = dataset, x = "HipsSumVariancebaseline", y = "HipsClusterShadebaseline", ax = axs[3][2])

sns.scatterplot(data = dataset, x = "HipsASMbaseline", y = "HipsClusterShadebaseline", ax = axs[4][0])
sns.scatterplot(data = dataset, x = "ERCsContrastbaseline", y = "ERCsCorelationbaseline", ax = axs[4][1])
sns.scatterplot(data = dataset, x = "HipsASMbaseline", y = "HipsEntropybaseline", ax = axs[4][2])

sns.scatterplot(data = dataset, x = "HipsASMbaseline", y = "HipsSumAveragebaseline", ax = axs[5][0])
sns.scatterplot(data = dataset, x = "ERCsASMbaseline", y = "ERCsEntropybaseline", ax = axs[5][1])
sns.scatterplot(data = dataset, x = "ERCsASMbaseline", y = "ERCsSumAveragebaseline", ax = axs[5][2])

plt.grid()

# %% [markdown]
# How about by target?

# %%
# Plot scatterplot based on the above correlation report
fig, axs = plt.subplots(6,3, figsize = (25, 20))

sns.scatterplot(data = dataset, x = "HipsSumVariancebaseline", y = "HipsVariancebaseline", hue="Diagnosis", size="Diagnosis", ax = axs[0][0])
sns.scatterplot(data = dataset, x = "HipsSumAveragebaseline", y = "HipsClusterShadebaseline", hue="Diagnosis", size="Diagnosis",ax = axs[0][1])
sns.scatterplot(data = dataset, x = "ERCsSumAveragebaseline", y = "ERCsEntropybaseline", hue="Diagnosis", size="Diagnosis",ax = axs[0][2])

sns.scatterplot(data = dataset, x = "ERCsSumAveragebaseline", y = "ERCsClusterShadebaseline", hue="Diagnosis", size="Diagnosis",ax = axs[1][0])
sns.scatterplot(data = dataset, x = "ERCsVariancebaseline", y = "ERCsSumVariancebaseline", hue="Diagnosis", size="Diagnosis",ax = axs[1][1])
sns.scatterplot(data = dataset, x = "HipsASMbaseline", y = "HipsSumVariancebaseline", hue="Diagnosis", size="Diagnosis",ax = axs[1][2])

sns.scatterplot(data = dataset, x = "HipsASMbaseline", y = "HipsVariancebaseline", hue="Diagnosis", size="Diagnosis",ax = axs[2][0])
sns.scatterplot(data = dataset, x = "HipsSumAveragebaseline", y = "HipsEntropybaseline", hue="Diagnosis", size="Diagnosis",ax = axs[2][1])
sns.scatterplot(data = dataset, x = "ERCsASMbaseline", y = "ERCsClusterShadebaseline", hue="Diagnosis", size="Diagnosis",ax = axs[2][2])

sns.scatterplot(data = dataset, x = "Diagnosis", y = "MMSE0m", hue="Diagnosis", size="Diagnosis",ax = axs[3][0])
sns.scatterplot(data = dataset, x = "HipsVariancebaseline", y = "HipsClusterShadebaseline", hue="Diagnosis", size="Diagnosis",ax = axs[3][1])
sns.scatterplot(data = dataset, x = "HipsSumVariancebaseline", y = "HipsClusterShadebaseline", hue="Diagnosis", size="Diagnosis",ax = axs[3][2])

sns.scatterplot(data = dataset, x = "HipsASMbaseline", y = "HipsClusterShadebaseline", hue="Diagnosis", size="Diagnosis",ax = axs[4][0])
sns.scatterplot(data = dataset, x = "ERCsContrastbaseline", y = "ERCsCorelationbaseline", hue="Diagnosis", size="Diagnosis",ax = axs[4][1])
sns.scatterplot(data = dataset, x = "HipsASMbaseline", y = "HipsEntropybaseline", hue="Diagnosis", size="Diagnosis",ax = axs[4][2])

sns.scatterplot(data = dataset, x = "HipsASMbaseline", y = "HipsSumAveragebaseline", hue="Diagnosis", size="Diagnosis",ax = axs[5][0])
sns.scatterplot(data = dataset, x = "ERCsASMbaseline", y = "ERCsEntropybaseline", hue="Diagnosis", size="Diagnosis",ax = axs[5][1])
sns.scatterplot(data = dataset, x = "ERCsASMbaseline", y = "ERCsSumAveragebaseline", hue="Diagnosis", size="Diagnosis",ax = axs[5][2])
# Out:
# <Axes: xlabel='ERCsASMbaseline', ylabel='ERCsSumAveragebaseline'>

# %% [markdown]
# This is fantastic! Isnt this more efficient instead of manually checking each column name in the pairplot?
#
# We can now understand how each variable is affected to one another.
#
# But how about the **target**? Lets narrow it down to see which features are strongly correlated with the target

# %%
# Check correlation between each variable and target
correlation_with_target = dataset.corr()["Diagnosis"].sort_values(ascending=False)
correlation_with_target
# Out:
# Diagnosis                     1.000000
# ERCsContrastbaseline          0.371118
# HipsASMbaseline               0.161644
# RID                           0.137855
# ERCsASMbaseline               0.131076
# HipsVariancebaseline          0.076798
# HipsSumVariancebaseline       0.064319
# HipsContrastbaseline          0.050656
# HipsCorelationbaseline        0.028586
# Gender                        0.026303
# ERCsVariancebaseline         -0.002202
# Ageatscreening               -0.010435
# HipsClusterShadebaseline     -0.079930
# ERCsClusterShadebaseline     -0.109483
# HipsSumAveragebaseline       -0.150871
# ERCsSumAveragebaseline       -0.176878
# HipsEntropybaseline          -0.190084
# ERCsEntropybaseline          -0.251645
# ERCsSumVariancebaseline      -0.259807
# ERCs_thicknessbaseline       -0.386723
# ERCsCorelationbaseline       -0.396683
# HipposcampusVolumebaseline   -0.481997
# ERCsVolumebaseline           -0.490807
# MMSE0m                       -0.769074
# Name: Diagnosis, dtype: float64

# %% [markdown]
# Lets plot it

# %%
# Plot target correlaton using bar
plt.figure(figsize=(15,15))

correlation_with_target.plot(kind = "barh", 
                             color = "#5e76fe",
                             edgecolor = "black")
# Out:
# <Axes: >

# %% [markdown]
# I believe we have a solid understanding now regarding our target feature. This will help us a lot when performing feature selection and further understand overall feature importance.
