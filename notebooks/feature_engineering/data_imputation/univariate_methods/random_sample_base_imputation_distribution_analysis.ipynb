# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from feature_engine.imputation import RandomSampleImputer
import matplotlib.pyplot as plt
import seaborn as sns
from dotenv import load_dotenv
import os

# %%
# Import dataset
load_dotenv()
dataset_path=os.getenv("DATASET_PATH")
dataset = pd.read_csv(dataset_path)
dataset.head()
# Out:
#    RID  Gender  Ageatscreening  Diagnosis  MMSE0m  HipsASMbaseline  \
# 0    3       0         81.3479          3    20.0              NaN
# 1    4       0         67.6904          1    27.0             0.06
# 2    5       0         73.8027          0    29.0             0.10
# 3    8       1         84.5945          0    28.0             0.08
# 4   10       1         73.9726          3    24.0             0.11
#
#    HipsContrastbaseline  HipsCorelationbaseline  HipsVariancebaseline  \
# 0                158.27                    0.63                218.30
# 1                147.64                    0.55                173.64
# 2                199.66                    0.55                222.27
# 3                184.21                    0.53                201.55
# 4                233.02                    0.48                229.88
#
#    HipsSumAveragebaseline  ...  ERCsContrastbaseline  ERCsCorelationbaseline  \
# 0                   28.37  ...                253.10                    0.40
# 1                   44.72  ...                220.88                    0.48
# 2                   41.18  ...                220.37                    0.54
# 3                   43.04  ...                198.42                    0.54
# 4                   39.46  ...                196.55                    0.53
#
#    ERCsVariancebaseline  ERCsSumAveragebaseline  ERCsSumVariancebaseline  \
# 0                208.65                   23.39                   581.50
# 1                215.70                   33.74                   641.90
# 2                232.18                   29.18                   708.36
# 3                220.48                   26.68                   683.50
# 4                210.63                   26.60                   645.95
#
#    ERCsEntropybaseline  ERCsClusterShadebaseline  ERCs_thicknessbaseline  \
# 0                  NaN                  -2568.19                    2.31
# 1                 3.33                   4113.01                    2.76
# 2                 2.87                  -1388.41                    3.18
# 3                 2.77                  -2506.55                    2.68
# 4                 2.72                  -1164.02                    2.64
#
#    ERCsVolumebaseline  HipposcampusVolumebaseline
# 0              1176.0                      3047.0
# 1              1942.0                      3449.0
# 2              2044.0                      3441.0
# 3              1959.0                      2875.0
# 4              1397.0                      2700.0
#
# [5 rows x 24 columns]

# %% [markdown]
# Lets visualize how many data points are we missing

# %%
missing_data = dataset.isna().sum().sort_values()
missing_data
# Out:
# RID                            0
# Gender                         0
# Ageatscreening                 0
# Diagnosis                      0
# HipsSumAveragebaseline         1
# MMSE0m                         3
# ERCsASMbaseline                4
# HipsSumVariancebaseline        7
# HipsVariancebaseline           8
# ERCsEntropybaseline            9
# ERCsSumAveragebaseline        11
# ERCsSumVariancebaseline       13
# ERCsVariancebaseline          14
# HipsContrastbaseline          14
# ERCsVolumebaseline            14
# ERCsContrastbaseline          18
# HipsClusterShadebaseline      18
# HipposcampusVolumebaseline    19
# HipsCorelationbaseline        20
# HipsEntropybaseline           23
# HipsASMbaseline               25
# ERCsCorelationbaseline        28
# ERCsClusterShadebaseline      34
# ERCs_thicknessbaseline        37
# dtype: int64

# %% [markdown]
# ### Split the data

# %%
X_train, X_test, y_train, y_test = train_test_split(
    dataset.drop("Diagnosis", axis=1),  
    dataset["Diagnosis"],  
    test_size=0.3,  
    random_state=42,  
)

X_train_copy = X_train.copy()
X_test_copy = X_test.copy()

X_train.shape, X_test.shape
# Out:
# ((425, 23), (183, 23))

# %%
imputer  = RandomSampleImputer(random_state=42)
imputer.fit(X_train)
# Out:
# RandomSampleImputer(random_state=42)

# %% [markdown]
# Great. lets see if our imputation method worked

# %%
X_train_t = imputer.transform(X_train)
X_test_t = imputer.transform(X_test)

dataframes = [
    X_train_t, X_test_t, 
]

for df in dataframes:
    if df.isna().any().all() == False:
        print("No missing values in any dataframe")
        break
    else:
        print("Still missing values")
# Out:
# No missing values in any dataframe

# %% [markdown]
# ### Check for normal distribution and skewness change

# %%
from scipy.stats import shapiro
from scipy.stats import skew, kurtosis

def check_normality(dataset):
    
    results = {}

    for column in dataset.columns:  
        stat, p = shapiro(dataset[column].dropna())
        skewness = skew(dataset[column].dropna())
        kurt = kurtosis(dataset[column].dropna())
        results[column] = {'Statistic': stat, 'p-value': p, 'Skewness': skewness, 'Kurtosis': kurt, 'Normal': p > 0.05} 

    # Convert results to DataFrame for better visualization
    results_df = pd.DataFrame(results).T
    return results_df

# %%
X_train_norm = check_normality(X_train)
X_test_norm = check_normality(X_test)

X_train_norm_rs = check_normality(X_train_t)
X_test_norm_rs = check_normality(X_test_t)

# %%
normal_train_df = pd.DataFrame({"Statistic": X_train_norm["Statistic"],
                                "p-value": X_train_norm["p-value"],
                                "Skewness": X_train_norm["Skewness"],
                                "Kurtosis": X_train_norm["Kurtosis"],
                                "X_train_norm": X_train_norm["Normal"],
                                "Statistic_rs": X_train_norm_rs["Statistic"],
                                "p-value_rs": X_train_norm_rs["p-value"],
                                "Skewness_rs": X_train_norm_rs["Skewness"],
                                "Kurtosis_rs": X_train_norm_rs["Kurtosis"],
                                "X_train_rs": X_train_norm_rs["Normal"],
})

normal_test_df = pd.DataFrame({"Statistic": X_test_norm["Statistic"],
                                "p-value": X_test_norm["p-value"],
                                "Skewness": X_test_norm["Skewness"],
                                "Kurtosis": X_test_norm["Kurtosis"],
                                "X_test_norm": X_test_norm["Normal"],
                                "Statistic_rs": X_test_norm_rs["Statistic"],
                                "p-value_rs": X_test_norm_rs["p-value"],
                                "Skewness_rs": X_test_norm_rs["Skewness"],
                                "Kurtosis_rs": X_test_norm_rs["Kurtosis"],
                               "X_test_rs": X_test_norm_rs["Normal"]
})

# %%
normal_train_df
# Out:
#                            Statistic   p-value  Skewness  Kurtosis  \
# RID                         0.960571       0.0 -0.191996 -1.042352
# Gender                      0.629481       0.0  0.280362 -1.921397
# Ageatscreening               0.98636  0.000507 -0.352696  0.074891
# MMSE0m                      0.899325       0.0  -0.86101  0.089239
# HipsASMbaseline             0.962064       0.0  0.527045 -0.234448
# HipsContrastbaseline        0.991863  0.022984   0.21891 -0.294576
# HipsCorelationbaseline      0.973015  0.000001 -0.465003 -0.239129
# HipsVariancebaseline         0.93952       0.0 -0.707282 -0.345891
# HipsSumAveragebaseline      0.992093  0.023528 -0.087851 -0.465718
# HipsSumVariancebaseline      0.93146       0.0 -0.775533 -0.258937
# HipsEntropybaseline         0.985185  0.000364 -0.437947  0.259399
# HipsClusterShadebaseline    0.939881       0.0  0.733428 -0.261643
# ERCsASMbaseline             0.991125  0.012372  0.024402 -0.394275
# ERCsContrastbaseline        0.991243  0.015613  0.271914 -0.153239
# ERCsCorelationbaseline      0.989264  0.004573 -0.223249 -0.186838
# ERCsVariancebaseline        0.993937  0.095953 -0.181171 -0.313634
# ERCsSumAveragebaseline       0.99146  0.016941  0.235502 -0.315199
# ERCsSumVariancebaseline     0.979104  0.000011 -0.470747 -0.192017
# ERCsEntropybaseline         0.995839  0.334306 -0.062424 -0.326166
# ERCsClusterShadebaseline    0.965231       0.0  0.582851 -0.282262
# ERCs_thicknessbaseline      0.993942  0.117112  0.082401  0.006588
# ERCsVolumebaseline          0.989861  0.005604 -0.075964 -0.655122
# HipposcampusVolumebaseline  0.991296   0.01597  0.036785 -0.621942
#
#                            X_train_norm Statistic_rs p-value_rs Skewness_rs  \
# RID                               False     0.960571        0.0   -0.191996
# Gender                            False     0.629481        0.0    0.280362
# Ageatscreening                    False      0.98636   0.000507   -0.352696
# MMSE0m                            False     0.898894        0.0   -0.861211
# HipsASMbaseline                   False     0.960033        0.0    0.544107
# HipsContrastbaseline              False     0.991269   0.013139    0.225918
# HipsCorelationbaseline            False     0.970947        0.0   -0.494831
# HipsVariancebaseline              False     0.939503        0.0   -0.711424
# HipsSumAveragebaseline            False     0.992093   0.023528   -0.087851
# HipsSumVariancebaseline           False     0.931714        0.0   -0.776704
# HipsEntropybaseline               False     0.986869   0.000697   -0.404251
# HipsClusterShadebaseline          False     0.940672        0.0    0.723236
# ERCsASMbaseline                   False     0.990702   0.008837    0.015639
# ERCsContrastbaseline              False     0.990913   0.010237    0.275198
# ERCsCorelationbaseline            False     0.989557    0.00403    -0.21771
# ERCsVariancebaseline               True     0.994223   0.108107    -0.16975
# ERCsSumAveragebaseline            False      0.99113   0.011912    0.249561
# ERCsSumVariancebaseline           False     0.978493   0.000006   -0.482142
# ERCsEntropybaseline                True     0.995997   0.358836   -0.057834
# ERCsClusterShadebaseline          False     0.964904        0.0    0.575836
# ERCs_thicknessbaseline             True     0.995036   0.190825    0.058972
# ERCsVolumebaseline                False     0.990346   0.006906   -0.057467
# HipposcampusVolumebaseline        False     0.991092     0.0116    0.044709
#
#                            Kurtosis_rs X_train_rs
# RID                          -1.042352      False
# Gender                       -1.921397      False
# Ageatscreening                0.074891      False
# MMSE0m                        0.086653      False
# HipsASMbaseline              -0.228272      False
# HipsContrastbaseline         -0.296896      False
# HipsCorelationbaseline       -0.211043      False
# HipsVariancebaseline          -0.33148      False
# HipsSumAveragebaseline       -0.465718      False
# HipsSumVariancebaseline      -0.251152      False
# HipsEntropybaseline           0.237419      False
# HipsClusterShadebaseline     -0.283836      False
# ERCsASMbaseline              -0.414684      False
# ERCsContrastbaseline         -0.173661      False
# ERCsCorelationbaseline       -0.170746      False
# ERCsVariancebaseline         -0.328132       True
# ERCsSumAveragebaseline       -0.314765      False
# ERCsSumVariancebaseline      -0.166437      False
# ERCsEntropybaseline          -0.318942       True
# ERCsClusterShadebaseline     -0.311685      False
# ERCs_thicknessbaseline       -0.054254       True
# ERCsVolumebaseline           -0.653625      False
# HipposcampusVolumebaseline   -0.624833      False

# %%
print("Total normal distribution count for X_train_norm")
print(normal_train_df["X_train_norm"].value_counts())

print("Total normal distribution count for X_train_rs")
print(normal_train_df["X_train_rs"].value_counts())
# Out:
# Total normal distribution count for X_train_norm
# X_train_norm
# False    20
# True      3
# Name: count, dtype: int64
# Total normal distribution count for X_train_rs
# X_train_rs
# False    20
# True      3
# Name: count, dtype: int64

# %%
normal_test_df
# Out:
#                            Statistic   p-value  Skewness  Kurtosis  \
# RID                         0.960508  0.000051 -0.016388  -1.13125
# Gender                      0.636327       0.0 -0.032791 -1.998925
# Ageatscreening              0.980514  0.011678 -0.433128 -0.042661
# MMSE0m                      0.917092       0.0 -0.833102  0.252238
# HipsASMbaseline             0.969407  0.000648  0.426523 -0.261149
# HipsContrastbaseline        0.993728  0.641145 -0.093392 -0.423827
# HipsCorelationbaseline      0.966959  0.000316  -0.54832 -0.180166
# HipsVariancebaseline        0.941051  0.000001 -0.751652 -0.130158
# HipsSumAveragebaseline      0.984341  0.039599  -0.17071 -0.360171
# HipsSumVariancebaseline     0.942657  0.000001 -0.758671  -0.07304
# HipsEntropybaseline         0.986012  0.071759 -0.323357  0.114272
# HipsClusterShadebaseline    0.936002       0.0  0.689001  -0.34437
# ERCsASMbaseline             0.988638  0.153673  0.107384 -0.152869
# ERCsContrastbaseline        0.992409  0.474336   0.15774 -0.377578
# ERCsCorelationbaseline      0.972238  0.001428 -0.362293  -0.56009
# ERCsVariancebaseline         0.98952  0.214511 -0.194723 -0.444791
# ERCsSumAveragebaseline      0.993564   0.61466  0.180396 -0.230598
# ERCsSumVariancebaseline     0.990351  0.266233 -0.262913 -0.296273
# ERCsEntropybaseline         0.993623  0.630968 -0.123512 -0.229104
# ERCsClusterShadebaseline    0.961089  0.000083  0.594137 -0.338237
# ERCs_thicknessbaseline      0.988257  0.151926 -0.216879 -0.174475
# ERCsVolumebaseline          0.982245  0.023579  0.086643 -0.833693
# HipposcampusVolumebaseline  0.993272  0.592427 -0.015105 -0.267084
#
#                            X_test_norm Statistic_rs p-value_rs Skewness_rs  \
# RID                              False     0.960508   0.000051   -0.016388
# Gender                           False     0.636327        0.0   -0.032791
# Ageatscreening                   False     0.980514   0.011678   -0.433128
# MMSE0m                           False     0.917092        0.0   -0.833102
# HipsASMbaseline                  False     0.966465   0.000223    0.486737
# HipsContrastbaseline              True      0.99392   0.655554   -0.068039
# HipsCorelationbaseline           False     0.965221   0.000163   -0.569192
# HipsVariancebaseline             False      0.94174   0.000001   -0.746675
# HipsSumAveragebaseline           False     0.984681   0.043037   -0.178433
# HipsSumVariancebaseline          False     0.943734   0.000001   -0.757655
# HipsEntropybaseline               True     0.986806    0.08467   -0.297514
# HipsClusterShadebaseline         False     0.933502        0.0      0.7117
# ERCsASMbaseline                   True     0.988953   0.166618    0.088145
# ERCsContrastbaseline              True     0.992117   0.422801     0.17833
# ERCsCorelationbaseline           False     0.974099   0.001754   -0.355394
# ERCsVariancebaseline              True     0.989902   0.223092   -0.179353
# ERCsSumAveragebaseline            True     0.993323   0.573606    0.184806
# ERCsSumVariancebaseline           True     0.990179   0.242532   -0.269202
# ERCsEntropybaseline               True     0.993809    0.64011   -0.107114
# ERCsClusterShadebaseline         False     0.963947   0.000118    0.569238
# ERCs_thicknessbaseline            True     0.988012   0.124064     -0.2313
# ERCsVolumebaseline               False     0.981864   0.017731     0.10798
# HipposcampusVolumebaseline        True     0.992841   0.510421   -0.007141
#
#                            Kurtosis_rs X_test_rs
# RID                           -1.13125     False
# Gender                       -1.998925     False
# Ageatscreening               -0.042661     False
# MMSE0m                        0.252238     False
# HipsASMbaseline              -0.123075     False
# HipsContrastbaseline         -0.404184      True
# HipsCorelationbaseline       -0.165566     False
# HipsVariancebaseline          -0.13119     False
# HipsSumAveragebaseline       -0.350813     False
# HipsSumVariancebaseline      -0.057771     False
# HipsEntropybaseline           0.080298      True
# HipsClusterShadebaseline     -0.306758     False
# ERCsASMbaseline              -0.163898      True
# ERCsContrastbaseline         -0.327347      True
# ERCsCorelationbaseline       -0.539658     False
# ERCsVariancebaseline         -0.482453      True
# ERCsSumAveragebaseline       -0.259601      True
# ERCsSumVariancebaseline      -0.276494      True
# ERCsEntropybaseline          -0.221111      True
# ERCsClusterShadebaseline      -0.35135     False
# ERCs_thicknessbaseline       -0.174865      True
# ERCsVolumebaseline           -0.831323     False
# HipposcampusVolumebaseline    -0.32348      True

# %%
print("\nTotal normal distribution count for X_test_norm")
print(normal_test_df["X_test_norm"].value_counts())

print("\nTotal normal distribution count for X_test_rs")
print(normal_test_df["X_test_rs"].value_counts())
# Out:
# Total normal distribution count for X_test_norm
# X_test_norm
# False    13
# True     10
# Name: count, dtype: int64
#
# Total normal distribution count for X_test_rs
# X_test_rs
# False    13
# True     10
# Name: count, dtype: int64

# %%
plt.figure(figsize=(20,10))
plt.suptitle("Normal distribution count & analysis")

plt.subplot(2, 2, 1)
normal_train_df["X_train_norm"].value_counts().plot(kind="bar",
                                             color = "#5e76fe",
                                             edgecolor = "black",
                                             label = "X_train_norm")
plt.title("X_train_norm")

plt.subplot(2, 2, 2)
normal_train_df["X_train_rs"].value_counts().plot(kind="bar",
                                             color = "#5e76fe",
                                             edgecolor = "black",
                                             label = "X_train_norm")
plt.title("X_train_norm_rs")

plt.subplot(2, 2, 3)
normal_test_df["X_test_norm"].value_counts().plot(kind="bar",
                                             color = "#5e76fe",
                                             edgecolor = "black",
                                             label = "X_test_norm")
plt.title("X_test_norm")

plt.subplot(2, 2, 4)
normal_test_df["X_test_rs"].value_counts().plot(kind="bar",
                                             color = "#5e76fe",
                                             edgecolor = "black",
                                             label = "X_test_norm")
plt.title("X_test_norm_rs")

plt.tight_layout()

# %% [markdown]
# #### Comparison of Imputed and Original X_train Dataset

# %%
# Plot each column using histograms
plt.figure(figsize=(20, 45))

for i in range(len(X_train_copy.columns)):
    plt.subplot(12,3,i+1)
    sns.kdeplot(X_train_copy[X_train_copy.columns[i]], color="#5e76fe", multiple="stack")

    plt.subplot(12,3,i+1)
    sns.kdeplot(X_train_t[X_train_t.columns[i]], color= "red")

# %%
# Plot each column using histograms
plt.figure(figsize=(20, 45))

for i in range(len(X_train_copy.columns)):
    plt.subplot(12,3,i+1)
    sns.boxenplot(X_train_copy[X_train_copy.columns[i]], hue=X_train_t[X_train_t.columns[i]], color="#5e76fe")

    plt.subplot(12,3,i+1)
    sns.boxenplot(X_train_t[X_train_t.columns[i]], color= "red")
# Out:
# C:\Users\steve\AppData\Local\Temp\ipykernel_12552\4173905350.py:4: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#5e76fe'` for the same effect.
#
#   sns.boxenplot(x=X_train_copy[X_train_copy.columns[i]], hue=X_train_t[X_train_t.columns[i]], color="#5e76fe")
# C:\Users\steve\AppData\Local\Temp\ipykernel_12552\4173905350.py:4: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#5e76fe'` for the same effect.
#
#   sns.boxenplot(x=X_train_copy[X_train_copy.columns[i]], hue=X_train_t[X_train_t.columns[i]], color="#5e76fe")
# C:\Users\steve\AppData\Local\Temp\ipykernel_12552\4173905350.py:4: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#5e76fe'` for the same effect.
#
#   sns.boxenplot(x=X_train_copy[X_train_copy.columns[i]], hue=X_train_t[X_train_t.columns[i]], color="#5e76fe")
# C:\Users\steve\AppData\Local\Temp\ipykernel_12552\4173905350.py:4: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#5e76fe'` for the same effect.
#
#   sns.boxenplot(x=X_train_copy[X_train_copy.columns[i]], hue=X_train_t[X_train_t.columns[i]], color="#5e76fe")
# C:\Users\steve\AppData\Local\Temp\ipykernel_12552\4173905350.py:4: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#5e76fe'` for the same effect.
#
#   sns.boxenplot(x=X_train_copy[X_train_copy.columns[i]], hue=X_train_t[X_train_t.columns[i]], color="#5e76fe")
# C:\Users\steve\AppData\Local\Temp\ipykernel_12552\4173905350.py:4: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#5e76fe'` for the same effect.
#
#   sns.boxenplot(x=X_train_copy[X_train_copy.columns[i]], hue=X_train_t[X_train_t.columns[i]], color="#5e76fe")
# C:\Users\steve\AppData\Local\Temp\ipykernel_12552\4173905350.py:4: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#5e76fe'` for the same effect.
#
#   sns.boxenplot(x=X_train_copy[X_train_copy.columns[i]], hue=X_train_t[X_train_t.columns[i]], color="#5e76fe")
# C:\Users\steve\AppData\Local\Temp\ipykernel_12552\4173905350.py:4: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#5e76fe'` for the same effect.
#
#   sns.boxenplot(x=X_train_copy[X_train_copy.columns[i]], hue=X_train_t[X_train_t.columns[i]], color="#5e76fe")
# C:\Users\steve\AppData\Local\Temp\ipykernel_12552\4173905350.py:4: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#5e76fe'` for the same effect.
#
#   sns.boxenplot(x=X_train_copy[X_train_copy.columns[i]], hue=X_train_t[X_train_t.columns[i]], color="#5e76fe")
# C:\Users\steve\AppData\Local\Temp\ipykernel_12552\4173905350.py:4: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#5e76fe'` for the same effect.
#
#   sns.boxenplot(x=X_train_copy[X_train_copy.columns[i]], hue=X_train_t[X_train_t.columns[i]], color="#5e76fe")
# C:\Users\steve\AppData\Local\Temp\ipykernel_12552\4173905350.py:4: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#5e76fe'` for the same effect.
#
#   sns.boxenplot(x=X_train_copy[X_train_copy.columns[i]], hue=X_train_t[X_train_t.columns[i]], color="#5e76fe")
# C:\Users\steve\AppData\Local\Temp\ipykernel_12552\4173905350.py:4: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#5e76fe'` for the same effect.
#
#   sns.boxenplot(x=X_train_copy[X_train_copy.columns[i]], hue=X_train_t[X_train_t.columns[i]], color="#5e76fe")
# C:\Users\steve\AppData\Local\Temp\ipykernel_12552\4173905350.py:4: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#5e76fe'` for the same effect.
#
#   sns.boxenplot(x=X_train_copy[X_train_copy.columns[i]], hue=X_train_t[X_train_t.columns[i]], color="#5e76fe")
# C:\Users\steve\AppData\Local\Temp\ipykernel_12552\4173905350.py:4: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#5e76fe'` for the same effect.
#
#   sns.boxenplot(x=X_train_copy[X_train_copy.columns[i]], hue=X_train_t[X_train_t.columns[i]], color="#5e76fe")
# C:\Users\steve\AppData\Local\Temp\ipykernel_12552\4173905350.py:4: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#5e76fe'` for the same effect.
#
#   sns.boxenplot(x=X_train_copy[X_train_copy.columns[i]], hue=X_train_t[X_train_t.columns[i]], color="#5e76fe")
# C:\Users\steve\AppData\Local\Temp\ipykernel_12552\4173905350.py:4: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#5e76fe'` for the same effect.
#
#   sns.boxenplot(x=X_train_copy[X_train_copy.columns[i]], hue=X_train_t[X_train_t.columns[i]], color="#5e76fe")
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 4
#       1 for i in range(len(X_train_copy.columns)):
#       2     # First boxenplot (with hue from X_train_t)
#       3     plt.subplot(12, 3, 2*i + 1)  # Position on the left side of the subplot grid
# ----> 4     sns.boxenplot(x=X_train_copy[X_train_copy.columns[i]], hue=X_train_t[X_train_t.columns[i]], color="#5e76fe")
#       5     plt.title(f"Boxenplot for {X_train_copy.columns[i]} with hue")
#       7     # Second boxenplot (in red)
#
# File c:\Users\steve\Desktop\Notebooks\Thesis-Project\venv\Lib\site-packages\seaborn\categorical.py:1955, in boxenplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, linewidth, linecolor, width_method, k_depth, outlier_prop, trust_alpha, showfliers, hue_norm, log_scale, native_scale, formatter, legend, scale, box_kws, flier_kws, line_kws, ax, **kwargs)
#    1947 color = _default_color(
#    1948     ax.fill_between, hue, color,
#    1949     {},  # TODO how to get default color?
#    1950     # {k: v for k, v in kwargs.items() if k in ["c", "color", "fc", "facecolor"]},
#    1951     saturation=saturation,
#    1952 )
#    1953 linecolor = p._complement_color(linecolor, color, p._hue_map)
# -> 1955 p.plot_boxens(
#    1956     width=width,
#    1957     dodge=dodge,
#    1958     gap=gap,
#    1959     fill=fill,
#    1960     color=color,
#    1961     linecolor=linecolor,
#    1962     linewidth=linewidth,
#    1963     width_method=width_method,
#    1964     k_depth=k_depth,
#    1965     outlier_prop=outlier_prop,
#    1966     trust_alpha=trust_alpha,
#    1967     showfliers=showfliers,
#    1968     box_kws=box_kws,
#    1969     flier_kws=flier_kws,
#    1970     line_kws=line_kws,
#    1971     plot_kws=kwargs,
#    1972 )
#    1974 p._add_axis_labels(ax)
#    1975 p._adjust_cat_axis(ax, axis=p.orient)
#
# File c:\Users\steve\Desktop\Notebooks\Thesis-Project\venv\Lib\site-packages\seaborn\categorical.py:834, in _CategoricalPlotter.plot_boxens(self, width, dodge, gap, fill, color, linecolor, linewidth, width_method, k_depth, outlier_prop, trust_alpha, showfliers, box_kws, flier_kws, line_kws, plot_kws)
#     832 if fill:
#     833     cmap = light_palette(maincolor, as_cmap=True)
# --> 834     boxcolors = cmap(2 ** ((exponent + 2) / 3))
#     835 else:
#     836     boxcolors = maincolor
#
# File c:\Users\steve\Desktop\Notebooks\Thesis-Project\venv\Lib\site-packages\matplotlib\colors.py:737, in Colormap.__call__(self, X, alpha, bytes)
#     714 r"""
#     715 Parameters
#     716 ----------
#    (...)
#     734 RGBA values with a shape of ``X.shape + (4, )``.
#     735 """
#     736 if not self._isinit:
# --> 737     self._init()
#     739 xa = np.array(X, copy=True)
#     740 if not xa.dtype.isnative:
#     741     # Native byteorder is faster.
#
# File c:\Users\steve\Desktop\Notebooks\Thesis-Project\venv\Lib\site-packages\matplotlib\colors.py:1031, in LinearSegmentedColormap._init(self)
#    1030 def _init(self):
# -> 1031     self._lut = np.ones((self.N + 3, 4), float)
#    1032     self._lut[:-3, 0] = _create_lookup_table(
#    1033         self.N, self._segmentdata['red'], self._gamma)
#    1034     self._lut[:-3, 1] = _create_lookup_table(
#    1035         self.N, self._segmentdata['green'], self._gamma)
#
# File c:\Users\steve\Desktop\Notebooks\Thesis-Project\venv\Lib\site-packages\numpy\_core\numeric.py:205, in ones(shape, dtype, order, device, like)
#     200     return _ones_with_like(
#     201         like, shape, dtype=dtype, order=order, device=device
#     202     )
#     204 a = empty(shape, dtype, order, device=device)
# --> 205 multiarray.copyto(a, 1, casting='unsafe')
#     206 return a
#
# KeyboardInterrupt:

# %% [markdown]
# It appears that we have succesfuly preserved our original variance/normal distribution using out imputation method on our training set. How about we check the difference in our testing set?

# %% [markdown]
# #### Comparison of Imputed and Original X_test Dataset

# %%
# Plot each column using histograms
plt.figure(figsize=(20, 45))

for i in range(len(X_test_copy.columns)):
    plt.subplot(12,3,i+1)
    sns.kdeplot(X_test_copy[X_test_copy.columns[i]], color="#5e76fe", multiple="stack")

    plt.subplot(12,3,i+1)
    sns.kdeplot(X_test_t[X_test_t.columns[i]], color= "red")

# %% [markdown]
# It appears that in the testing set, the data imputation method has been affected a lot. How about we check the normal distribution of both the transformed train and test set?

# %%
from scipy import stats

# Plot Q-Q plots for each column
plt.figure(figsize=(20, 45))

for i in range(len(X_train_t.columns)):
    plt.subplot(10, 4, i + 1)
    stats.probplot(X_train_t[X_train_t.columns[i]], 
                   dist='norm', plot=plt)
    plt.title(X_train_t.columns[i])

plt.tight_layout()

# %%
# Plot Q-Q plots for each column
plt.figure(figsize=(20, 45))

for i in range(len(X_test_t.columns)):
    plt.subplot(10, 4, i + 1)
    stats.probplot(X_test_t[X_test_t.columns[i]], 
                   dist='norm', plot=plt)
    plt.title(X_test_t.columns[i])

plt.tight_layout()

# %% [markdown]
# ### Check for variance change

# %%
variance_train_df = pd.DataFrame({"X_train_std": X_train.var(),
              "X_train_rs std": X_train_t.var(),
            }
)

variance_train_df["Changed_train"] = (variance_train_df.nunique(axis=1) > 1)

variance_test_df = pd.DataFrame({"X_test": X_test.var(),
              "X_test_rs std": X_test_t.var(),
            }
)

variance_test_df["Changed_rs"] = (variance_test_df.nunique(axis=1) > 1)

variance_df_report = pd.concat([variance_train_df, variance_test_df], axis=1)
variance_df_report
# Out:
#                              X_train_std  X_train_rs std  Changed_train  \
# RID                         1.563815e+05    1.563815e+05          False
# Gender                      2.457603e-01    2.457603e-01          False
# Ageatscreening              4.307941e+01    4.307941e+01          False
# MMSE0m                      7.689551e+00    7.675993e+00           True
# HipsASMbaseline             1.686332e-03    1.720180e-03           True
# HipsContrastbaseline        4.227328e+02    4.255094e+02           True
# HipsCorelationbaseline      2.584648e-03    2.599376e-03           True
# HipsVariancebaseline        5.847527e+02    5.800135e+02           True
# HipsSumAveragebaseline      2.642004e+01    2.642004e+01          False
# HipsSumVariancebaseline     7.585556e+03    7.564001e+03           True
# HipsEntropybaseline         5.476122e-02    5.466602e-02           True
# HipsClusterShadebaseline    8.405372e+07    8.363623e+07           True
# ERCsASMbaseline             2.287387e-03    2.329603e-03           True
# ERCsContrastbaseline        5.702779e+02    5.711648e+02           True
# ERCsCorelationbaseline      2.180605e-03    2.134587e-03           True
# ERCsVariancebaseline        1.035335e+02    1.031961e+02           True
# ERCsSumAveragebaseline      1.089198e+01    1.086910e+01           True
# ERCsSumVariancebaseline     1.418196e+03    1.410842e+03           True
# ERCsEntropybaseline         4.459491e-02    4.435166e-02           True
# ERCsClusterShadebaseline    9.292218e+06    9.380484e+06           True
# ERCs_thicknessbaseline      1.007516e-01    1.008056e-01           True
# ERCsVolumebaseline          1.512812e+05    1.530602e+05           True
# HipposcampusVolumebaseline  2.712605e+05    2.693523e+05           True
#
#                                   X_test  X_test_rs std  Changed_rs
# RID                         1.654556e+05   1.654556e+05       False
# Gender                      2.513061e-01   2.513061e-01       False
# Ageatscreening              4.862086e+01   4.862086e+01       False
# MMSE0m                      7.112112e+00   7.112112e+00       False
# HipsASMbaseline             1.611935e-03   1.655053e-03        True
# HipsContrastbaseline        4.375496e+02   4.456304e+02        True
# HipsCorelationbaseline      2.353091e-03   2.338287e-03        True
# HipsVariancebaseline        6.732886e+02   6.693425e+02        True
# HipsSumAveragebaseline      2.277794e+01   2.268464e+01        True
# HipsSumVariancebaseline     7.896207e+03   7.832129e+03        True
# HipsEntropybaseline         5.791106e-02   5.845428e-02        True
# HipsClusterShadebaseline    8.288471e+07   8.212473e+07        True
# ERCsASMbaseline             2.145787e-03   2.185972e-03        True
# ERCsContrastbaseline        5.977853e+02   5.861141e+02        True
# ERCsCorelationbaseline      2.389970e-03   2.348286e-03        True
# ERCsVariancebaseline        8.839479e+01   8.912574e+01        True
# ERCsSumAveragebaseline      9.477683e+00   9.600520e+00        True
# ERCsSumVariancebaseline     1.397985e+03   1.384559e+03        True
# ERCsEntropybaseline         4.205052e-02   4.165989e-02        True
# ERCsClusterShadebaseline    1.006329e+07   9.875553e+06        True
# ERCs_thicknessbaseline      1.081159e-01   1.070319e-01        True
# ERCsVolumebaseline          1.581768e+05   1.605717e+05        True
# HipposcampusVolumebaseline  2.517439e+05   2.553169e+05        True

# %%
print(variance_df_report["Changed_train"].value_counts())
# Out:
# Changed_train
# True     19
# False     4
# Name: count, dtype: int64

# %%
print(variance_df_report["Changed_rs"].value_counts())
# Out:
# Changed_rs
# True     19
# False     4
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,5))

plt.subplot(1,2,1)
variance_df_report["Changed_train"].value_counts().plot(kind="bar",
                                           color = "#5e76fe",
                                           edgecolor = "black",
)

plt.title("variance_train_df")

plt.subplot(1,2,2)
variance_df_report["Changed_rs"].value_counts().plot(kind="bar",
                                           color = "#5e76fe",
                                           edgecolor = "black",
)

plt.title("variance_test_df")

plt.tight_layout()

# %%
plt.figure(figsize=(20, 45))

for i in range(len(variance_train_df)):
    plt.subplot(12,3,i+1)
    variance_train_df.iloc[i].drop("Changed_train").plot(kind="line",
                                             color="#1e2c78",
    )
    
plt.tight_layout()

# %%
plt.figure(figsize=(20, 45))

for i in range(len(variance_test_df)):
    plt.subplot(12,3,i+1)
    variance_test_df.iloc[i].drop("Changed_rs").plot(kind="line",
                                             color="#1e2c78",
    )
    
plt.tight_layout()
