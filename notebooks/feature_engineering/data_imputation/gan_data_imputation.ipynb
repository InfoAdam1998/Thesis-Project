# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from dotenv import load_dotenv
import os

from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
# Import dataset
load_dotenv()
dataset_path=os.getenv("DATASET_PATH")
dataset = pd.read_csv(dataset_path)
dataset.head()
# Out:
#    RID  Gender  Ageatscreening  Diagnosis  MMSE0m  HipsASMbaseline  \
# 0    3       0         81.3479          3    20.0              NaN
# 1    4       0         67.6904          1    27.0             0.06
# 2    5       0         73.8027          0    29.0             0.10
# 3    8       1         84.5945          0    28.0             0.08
# 4   10       1         73.9726          3    24.0             0.11
#
#    HipsContrastbaseline  HipsCorelationbaseline  HipsVariancebaseline  \
# 0                158.27                    0.63                218.30
# 1                147.64                    0.55                173.64
# 2                199.66                    0.55                222.27
# 3                184.21                    0.53                201.55
# 4                233.02                    0.48                229.88
#
#    HipsSumAveragebaseline  ...  ERCsContrastbaseline  ERCsCorelationbaseline  \
# 0                   28.37  ...                253.10                    0.40
# 1                   44.72  ...                220.88                    0.48
# 2                   41.18  ...                220.37                    0.54
# 3                   43.04  ...                198.42                    0.54
# 4                   39.46  ...                196.55                    0.53
#
#    ERCsVariancebaseline  ERCsSumAveragebaseline  ERCsSumVariancebaseline  \
# 0                208.65                   23.39                   581.50
# 1                215.70                   33.74                   641.90
# 2                232.18                   29.18                   708.36
# 3                220.48                   26.68                   683.50
# 4                210.63                   26.60                   645.95
#
#    ERCsEntropybaseline  ERCsClusterShadebaseline  ERCs_thicknessbaseline  \
# 0                  NaN                  -2568.19                    2.31
# 1                 3.33                   4113.01                    2.76
# 2                 2.87                  -1388.41                    3.18
# 3                 2.77                  -2506.55                    2.68
# 4                 2.72                  -1164.02                    2.64
#
#    ERCsVolumebaseline  HipposcampusVolumebaseline
# 0              1176.0                      3047.0
# 1              1942.0                      3449.0
# 2              2044.0                      3441.0
# 3              1959.0                      2875.0
# 4              1397.0                      2700.0
#
# [5 rows x 24 columns]

# %%
missing_data = dataset.isna().sum().sort_values()
missing_data
# Out:
# RID                            0
# Gender                         0
# Ageatscreening                 0
# Diagnosis                      0
# HipsSumAveragebaseline         1
# MMSE0m                         3
# ERCsASMbaseline                4
# HipsSumVariancebaseline        7
# HipsVariancebaseline           8
# ERCsEntropybaseline            9
# ERCsSumAveragebaseline        11
# ERCsSumVariancebaseline       13
# ERCsVariancebaseline          14
# HipsContrastbaseline          14
# ERCsVolumebaseline            14
# ERCsContrastbaseline          18
# HipsClusterShadebaseline      18
# HipposcampusVolumebaseline    19
# HipsCorelationbaseline        20
# HipsEntropybaseline           23
# HipsASMbaseline               25
# ERCsCorelationbaseline        28
# ERCsClusterShadebaseline      34
# ERCs_thicknessbaseline        37
# dtype: int64

# %%
# Step 1: split the dataset
X_train, X_test, y_train, y_test = train_test_split(
    dataset.drop("Diagnosis", axis=1),  
    dataset["Diagnosis"],  
    test_size=0.3,  
    random_state=42,  
)

X_train_copy = X_train.copy()
X_test_copy = X_test.copy()
y_train_copy = y_train.copy()
y_test_copy = y_test.copy()

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((425, 23), (183, 23), (425,), (183,))

# %%
# Step 2: fill data temp using mean from training set
X_train_filled = X_train.fillna(X_train.mean())
X_test_filled = X_test.fillna(X_test.mean())

# Step 3: normalize features
scaler = MinMaxScaler()
X_train_s = scaler.fit_transform(X_train_filled)
X_test_s = scaler.transform(X_test_filled)

# Step 4: add gaussian noise
noise_factor = 0.1
X_train_noise = X_train_s + noise_factor * np.random.normal(loc=0.0, scale=0.1, size=X_train_s.shape)
X_train_noise = np.clip(X_train_noise, 0., 1.)

X_test_noise = X_test_s + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=X_test_s.shape)
X_test_noise = np.clip(X_test_noise, 0., 1.)

# %%
tf.random.set_seed(42)

# Define Variational Autoencoder (VAE) function
def variational_autoencoder(input_dim):
    inputs = layers.Input(shape=(input_dim,))
    x = layers.Dense(64, activation="relu")(inputs)
    z_mean = layers.Dense(32)(x)
    z_log_var = layers.Dense(32)(x)
    
    def sampling(args):
        z_mean, z_log_var = args
        epsilon = tf.random.normal(shape=tf.shape(z_mean))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon
    
    z = layers.Lambda(sampling)([z_mean, z_log_var])
    
    # Decoder
    decoder = layers.Dense(64, activation="relu")(z)
    outputs = layers.Dense(input_dim, activation="linear")(decoder)
    
    vae = models.Model(inputs, outputs)
    return vae

# %%
# Step 5: Create and train the Variational Autoencoder (VAE)
input_dim = X_train_s.shape[1]  # Number of features
vae = variational_autoencoder(input_dim)

vae.compile(optimizer='adam', loss='mse')  # Mean squared error for reconstruction loss

# Train the VAE using the noisy training data
vae.fit(X_train_noise, X_train_noise, epochs=50, batch_size=50, validation_data=(X_test_noise, X_test_noise))

# Step 6: Get the reconstructed data from the VAE
X_train_reconstructed = vae.predict(X_train_noise)
X_test_reconstructed = vae.predict(X_test_noise)

# Step 7: Inverse transform the reconstructed data to the original scale
X_train_reconstructed_descaled = scaler.inverse_transform(X_train_reconstructed)
X_test_reconstructed_descaled = scaler.inverse_transform(X_test_reconstructed)

# Step 8: Convert the descaled numpy arrays back to pandas DataFrames
X_train_d = pd.DataFrame(X_train_reconstructed_descaled, columns=X_train_copy.columns)
X_test_d = pd.DataFrame(X_test_reconstructed_descaled, columns=X_test_copy.columns)
# Out:
# Epoch 1/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.7449 - val_loss: 0.4683
# Epoch 2/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.4280 - val_loss: 0.3036
# Epoch 3/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2689 - val_loss: 0.2230
# Epoch 4/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2068 - val_loss: 0.1659
# Epoch 5/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1592 - val_loss: 0.1395
# Epoch 6/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1243 - val_loss: 0.1122
# Epoch 7/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1021 - val_loss: 0.0989
# Epoch 8/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0858 - val_loss: 0.0870
# Epoch 9/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0781 - val_loss: 0.0796
# Epoch 10/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0693 - val_loss: 0.0735
# Epoch 11/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0624 - val_loss: 0.0662
# Epoch 12/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0569 - val_loss: 0.0604
# Epoch 13/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0522 - val_loss: 0.0564
# Epoch 14/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0474 - val_loss: 0.0509
# Epoch 15/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0427 - val_loss: 0.0471
# Epoch 16/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0406 - val_loss: 0.0436
# Epoch 17/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0368 - val_loss: 0.0401
# Epoch 18/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0341 - val_loss: 0.0389
# Epoch 19/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0318 - val_loss: 0.0362
# Epoch 20/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0300 - val_loss: 0.0350
# Epoch 21/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0274 - val_loss: 0.0329
# Epoch 22/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0263 - val_loss: 0.0310
# Epoch 23/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0244 - val_loss: 0.0294
# Epoch 24/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0236 - val_loss: 0.0286
# Epoch 25/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0221 - val_loss: 0.0278
# Epoch 26/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0212 - val_loss: 0.0267
# Epoch 27/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0202 - val_loss: 0.0258
# Epoch 28/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0196 - val_loss: 0.0248
# Epoch 29/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0187 - val_loss: 0.0241
# Epoch 30/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0179 - val_loss: 0.0235
# Epoch 31/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0172 - val_loss: 0.0229
# Epoch 32/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0167 - val_loss: 0.0224
# Epoch 33/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0161 - val_loss: 0.0217
# Epoch 34/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0157 - val_loss: 0.0212
# Epoch 35/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0151 - val_loss: 0.0209
# Epoch 36/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0147 - val_loss: 0.0202
# Epoch 37/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0143 - val_loss: 0.0199
# Epoch 38/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0137 - val_loss: 0.0195
# Epoch 39/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0134 - val_loss: 0.0188
# Epoch 40/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0130 - val_loss: 0.0182
# Epoch 41/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0124 - val_loss: 0.0178
# Epoch 42/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0119 - val_loss: 0.0173
# Epoch 43/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0116 - val_loss: 0.0168
# Epoch 44/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0112 - val_loss: 0.0164
# Epoch 45/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0108 - val_loss: 0.0161
# Epoch 46/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0105 - val_loss: 0.0157
# Epoch 47/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0101 - val_loss: 0.0154
# Epoch 48/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0098 - val_loss: 0.0153
# Epoch 49/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0095 - val_loss: 0.0149
# Epoch 50/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0093 - val_loss: 0.0145
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %% [markdown]
# ### Visualize

# %%
# Plot each column using histograms
plt.figure(figsize=(20, 45))

for i in range(len(X_train_copy.columns)):
    plt.subplot(12,3,i+1)
    sns.kdeplot(X_train_copy[X_train_copy.columns[i]], color="#5e76fe", multiple="stack")

    plt.subplot(12,3,i+1)
    sns.kdeplot(X_train_d[X_train_d.columns[i]], color= "red")
    
    labels = ['original', 'auto_enc']
    plt.legend(labels, loc='upper left')

# %%
# Plot each column using histograms
plt.figure(figsize=(20, 45))

for i in range(len(X_train_copy.columns)):
    plt.subplot(12,3,i+1)
    sns.kdeplot(X_test_copy[X_test_copy.columns[i]], color="#5e76fe", multiple="stack")

    plt.subplot(12,3,i+1)
    sns.kdeplot(X_test_d[X_test_d.columns[i]], color= "red")
    
    labels = ['original', 'auto_enc']
    plt.legend(labels, loc='upper left')

# %%
# Plot each column using histograms
plt.figure(figsize=(20, 45))

for i in range(len(X_train_copy.columns)):
    plt.subplot(12,3,i+1)
    sns.kdeplot(X_train_d[X_train_d.columns[i]], color="#5e76fe", multiple="stack")

    plt.subplot(12,3,i+1)
    sns.kdeplot(X_test_d[X_test_d.columns[i]], color= "red")
    
    labels = ['auto_enc_train', 'auto_enc_test']
    plt.legend(labels, loc='upper left')

# %% [markdown]
# ### Validation Section

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (accuracy_score, roc_auc_score)

def run_random_forest(X_train, X_test, y_train, y_test):

        # Initialize the Random Forest with class weight balancing
        rf = RandomForestClassifier(n_estimators=100,
                                    max_depth=5,
                                    random_state=42,
                                    class_weight="balanced",
        )
        
        # Fit the model
        rf.fit(X_train, y_train)
        
        # Get predicted probabilities for ROC AUC
        pred_train_proba = rf.predict_proba(X_train)
        pred_test_proba = rf.predict_proba(X_test)
        
        # Get predicted accuracy values
        pred_train_norm = rf.predict(X_train)
        pred_test_norm = rf.predict(X_test)
        
        # Calculate ROC-AUC
        roc_score_train = roc_auc_score(y_train, 
                                        pred_train_proba, 
                                        average="weighted", 
                                        multi_class="ovr",
        )
        roc_score_test = roc_auc_score(y_test,
                                    pred_test_proba,  
                                    average="weighted", 
                                    multi_class="ovr",
        )
        
        # Calculate accuracies
        accuracy_train = accuracy_score(y_train, pred_train_norm)
        accuracy_test = accuracy_score(y_test, pred_test_norm)
        
        # Print results
        print(f"Train ROC-AUC: {roc_score_train}")
        print(f"Train Accuracy: {accuracy_train}")
        print(f"Test ROC-AUC: {roc_score_test}")
        print(f"Test Accuracy: {accuracy_test}")
        
run_random_forest(X_train_d, X_test_d, y_train, y_test)
# Out:
# Train ROC-AUC: 0.9650361537836365
# Train Accuracy: 0.8376470588235294
# Test ROC-AUC: 0.7562522863641412
# Test Accuracy: 0.5245901639344263
